# %% [markdown]
# <a href="https://colab.research.google.com/github/kmtsui/SummerProject2021/blob/pwagh/TKI_variables_plotting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! git clone https://github.com/kmtsui/SummerProject2021
# Out:
# Cloning into 'SummerProject2021'...
# remote: Enumerating objects: 8, done.
# remote: Counting objects: 100% (8/8), done.
# remote: Compressing objects: 100% (8/8), done.
# remote: Total 8 (delta 1), reused 4 (delta 0), pack-reused 0
# Unpacking objects: 100% (8/8), done.

# %%
! pip install uproot
# Out:
# ...
#      |████████████████████████████████| 245 kB 5.0 MB/s
# ...

# %%
import numpy as np
import uproot
import matplotlib.pyplot as plt


#%matplotlib inline

# %%
# dptt plots

def getarray(filename):
    f = uproot.open(filename)
    t = f["selectedEvents"]
    array = np.transpose(np.asarray(t.arrays(["dptt_rec", "weight", "topology", "cutBranch"], library="np", how=tuple)))
    return array
  

neut_array_dptt = getarray("SummerProject2021/neut_flattree.root")
#print(neut_array_dptt)

# Specify arguments for the histogram function here
bins_all = [-700,-300,-100,100,300,700]
colors_all = ['red', 'tan', 'lime']
labels_all = ["CC0pi", "CC1pi+0p", "CC1pi+1p", "CC1pi+Np", "CC1pi+1pi-", "CC1pi+Xpi0", "CC-other-Xpi0", "CC-other-0pi0", "background", "OOFV", "OOPS"]




cutbranch_zero = neut_array_dptt[neut_array_dptt[:,3]==0]             # This is for the signal sample: cutBranch = 0
#print("This is the signal sample", cutbranch_zero)

cb0_topology0 = cutbranch_zero[cutbranch_zero[:,2]==0][:,0] 
cb0_topology1 = cutbranch_zero[cutbranch_zero[:,2]==1][:,0] 
cb0_topology2 = cutbranch_zero[cutbranch_zero[:,2]==2][:,0]           # Specify the topology: For cutBranch = 0, topology = 2 is selected
cb0_topology3 = cutbranch_zero[cutbranch_zero[:,2]==3][:,0] 
cb0_topology4 = cutbranch_zero[cutbranch_zero[:,2]==4][:,0] 
cb0_topology5 = cutbranch_zero[cutbranch_zero[:,2]==5][:,0] 
cb0_topology6 = cutbranch_zero[cutbranch_zero[:,2]==6][:,0] 
cb0_topology7 = cutbranch_zero[cutbranch_zero[:,2]==7][:,0] 
cb0_topology8 = cutbranch_zero[cutbranch_zero[:,2]==8][:,0] 
cb0_topology9 = cutbranch_zero[cutbranch_zero[:,2]==9][:,0] 
cb0_topology10 = cutbranch_zero[cutbranch_zero[:,2]==10][:,0] 
cb0_topology11 = cutbranch_zero[cutbranch_zero[:,2]==11][:,0] 
#print("This is the topology 2", cb0_topology2)

weights_cb0_top0 = cutbranch_zero[cutbranch_zero[:,2]==0][:,1]
weights_cb0_top1 = cutbranch_zero[cutbranch_zero[:,2]==1][:,1]
weights_cb0_top2 = cutbranch_zero[cutbranch_zero[:,2]==2][:,1]        # Specify the weights for the topology
weights_cb0_top3 = cutbranch_zero[cutbranch_zero[:,2]==3][:,1]
weights_cb0_top4 = cutbranch_zero[cutbranch_zero[:,2]==4][:,1]
weights_cb0_top5 = cutbranch_zero[cutbranch_zero[:,2]==5][:,1]
weights_cb0_top6 = cutbranch_zero[cutbranch_zero[:,2]==6][:,1]
weights_cb0_top7 = cutbranch_zero[cutbranch_zero[:,2]==7][:,1]
weights_cb0_top8 = cutbranch_zero[cutbranch_zero[:,2]==8][:,1]
weights_cb0_top9 = cutbranch_zero[cutbranch_zero[:,2]==9][:,1]
weights_cb0_top10 = cutbranch_zero[cutbranch_zero[:,2]==10][:,1]
weights_cb0_top11 = cutbranch_zero[cutbranch_zero[:,2]==11][:,1]
#print(weights_cb0_top2)

x_cb0 = [cb0_topology0, cb0_topology1, cb0_topology2, cb0_topology3, cb0_topology4, cb0_topology5, cb0_topology6, cb0_topology7, cb0_topology8, cb0_topology9, cb0_topology10, cb0_topology11]
weights_cb0 = [weights_cb0_top0, weights_cb0_top1, weights_cb0_top2, weights_cb0_top3, weights_cb0_top4, weights_cb0_top5, weights_cb0_top6, weights_cb0_top7, weights_cb0_top8, weights_cb0_top9, weights_cb0_top10, weights_cb0_top11]

fig, ax = plt.subplots()
ax.hist(x_cb0, bins = bins_all, weights = weights_cb0, stacked = True, label=labels_all)
ax.legend(prop={'size': 10})
ax.set_xlim(-700,700)
#ax.set_ylim(0,250)
plt.title('Signal sample')
plt.xlabel('Reconstructed ' r'$\delta$$p_{TT}$ (MeV/c)')
plt.ylabel('Events per bin')







cutbranch_one = neut_array_dptt[neut_array_dptt[:,3]==1]             # This is for the CC1pi+1pi- enriched sample: cutBranch = 1
#print("This is the signal sample", cutbranch_zero)

cb1_topology0 = cutbranch_one[cutbranch_one[:,2]==0][:,0] 
cb1_topology1 = cutbranch_one[cutbranch_one[:,2]==1][:,0] 
cb1_topology2 = cutbranch_one[cutbranch_one[:,2]==2][:,0]           # Specify the topology: For cutBranch = 0, topology = 2 is selected
cb1_topology3 = cutbranch_one[cutbranch_one[:,2]==3][:,0] 
cb1_topology4 = cutbranch_one[cutbranch_one[:,2]==4][:,0] 
cb1_topology5 = cutbranch_one[cutbranch_one[:,2]==5][:,0] 
cb1_topology6 = cutbranch_one[cutbranch_one[:,2]==6][:,0] 
cb1_topology7 = cutbranch_one[cutbranch_one[:,2]==7][:,0] 
cb1_topology8 = cutbranch_one[cutbranch_one[:,2]==8][:,0] 
cb1_topology9 = cutbranch_one[cutbranch_one[:,2]==9][:,0] 
cb1_topology10 = cutbranch_one[cutbranch_one[:,2]==10][:,0] 
cb1_topology11 = cutbranch_one[cutbranch_one[:,2]==11][:,0] 
#print("This is the topology 2", cb0_topology2)

weights_cb1_top0 = cutbranch_one[cutbranch_one[:,2]==0][:,1]
weights_cb1_top1 = cutbranch_one[cutbranch_one[:,2]==1][:,1]
weights_cb1_top2 = cutbranch_one[cutbranch_one[:,2]==2][:,1]        # Specify the weights for the topology
weights_cb1_top3 = cutbranch_one[cutbranch_one[:,2]==3][:,1]
weights_cb1_top4 = cutbranch_one[cutbranch_one[:,2]==4][:,1]
weights_cb1_top5 = cutbranch_one[cutbranch_one[:,2]==5][:,1]
weights_cb1_top6 = cutbranch_one[cutbranch_one[:,2]==6][:,1]
weights_cb1_top7 = cutbranch_one[cutbranch_one[:,2]==7][:,1]
weights_cb1_top8 = cutbranch_one[cutbranch_one[:,2]==8][:,1]
weights_cb1_top9 = cutbranch_one[cutbranch_one[:,2]==9][:,1]
weights_cb1_top10 = cutbranch_one[cutbranch_one[:,2]==10][:,1]
weights_cb1_top11 = cutbranch_one[cutbranch_one[:,2]==11][:,1]
#print(weights_cb0_top2)

x_cb1 = [cb1_topology0, cb1_topology1, cb1_topology2, cb1_topology3, cb1_topology4, cb1_topology5, cb1_topology6, cb1_topology7, cb1_topology8, cb1_topology9, cb1_topology10, cb1_topology11]
weights_cb1 = [weights_cb1_top0, weights_cb1_top1, weights_cb1_top2, weights_cb1_top3, weights_cb1_top4, weights_cb1_top5, weights_cb1_top6, weights_cb1_top7, weights_cb1_top8, weights_cb1_top9, weights_cb1_top10, weights_cb1_top11]

fig, ax = plt.subplots()
ax.hist(x_cb1, bins = bins_all, weights = weights_cb1, stacked = True, label=labels_all)
ax.legend(prop={'size': 10})
ax.set_xlim(-700,700)
ax.set_ylim(0,70)
plt.title('CC1pi+1pi- enriched sample')
plt.xlabel('Reconstructed ' r'$\delta$$p_{TT}$ (MeV/c)')
plt.ylabel('Events per bin')






cutbranch_two = neut_array_dptt[neut_array_dptt[:,3]==2]             # This is for the CC1pi+Xpi0 enriched sample: cutBranch = 2
#print("This is the signal sample", cutbranch_zero)

cb2_topology0 = cutbranch_two[cutbranch_two[:,2]==0][:,0] 
cb2_topology1 = cutbranch_two[cutbranch_two[:,2]==1][:,0] 
cb2_topology2 = cutbranch_two[cutbranch_two[:,2]==2][:,0]           # Specify the topology: For cutBranch = 0, topology = 2 is selected
cb2_topology3 = cutbranch_two[cutbranch_two[:,2]==3][:,0] 
cb2_topology4 = cutbranch_two[cutbranch_two[:,2]==4][:,0] 
cb2_topology5 = cutbranch_two[cutbranch_two[:,2]==5][:,0] 
cb2_topology6 = cutbranch_two[cutbranch_two[:,2]==6][:,0] 
cb2_topology7 = cutbranch_two[cutbranch_two[:,2]==7][:,0] 
cb2_topology8 = cutbranch_two[cutbranch_two[:,2]==8][:,0] 
cb2_topology9 = cutbranch_two[cutbranch_two[:,2]==9][:,0] 
cb2_topology10 = cutbranch_two[cutbranch_two[:,2]==10][:,0] 
cb2_topology11 = cutbranch_two[cutbranch_two[:,2]==11][:,0] 
#print("This is the topology 2", cb0_topology2)

weights_cb2_top0 = cutbranch_two[cutbranch_two[:,2]==0][:,1]
weights_cb2_top1 = cutbranch_two[cutbranch_two[:,2]==1][:,1]
weights_cb2_top2 = cutbranch_two[cutbranch_two[:,2]==2][:,1]        # Specify the weights for the topology
weights_cb2_top3 = cutbranch_two[cutbranch_two[:,2]==3][:,1]
weights_cb2_top4 = cutbranch_two[cutbranch_two[:,2]==4][:,1]
weights_cb2_top5 = cutbranch_two[cutbranch_two[:,2]==5][:,1]
weights_cb2_top6 = cutbranch_two[cutbranch_two[:,2]==6][:,1]
weights_cb2_top7 = cutbranch_two[cutbranch_two[:,2]==7][:,1]
weights_cb2_top8 = cutbranch_two[cutbranch_two[:,2]==8][:,1]
weights_cb2_top9 = cutbranch_two[cutbranch_two[:,2]==9][:,1]
weights_cb2_top10 = cutbranch_two[cutbranch_two[:,2]==10][:,1]
weights_cb2_top11 = cutbranch_two[cutbranch_two[:,2]==11][:,1]
#print(weights_cb0_top2)

x_cb2 = [cb2_topology0, cb2_topology1, cb2_topology2, cb2_topology3, cb2_topology4, cb2_topology5, cb2_topology6, cb2_topology7, cb2_topology8, cb2_topology9, cb2_topology10, cb2_topology11]
weights_cb2 = [weights_cb2_top0, weights_cb2_top1, weights_cb2_top2, weights_cb2_top3, weights_cb2_top4, weights_cb2_top5, weights_cb2_top6, weights_cb2_top7, weights_cb2_top8, weights_cb2_top9, weights_cb2_top10, weights_cb2_top11]

fig, ax = plt.subplots()
ax.hist(x_cb2, bins = bins_all, weights = weights_cb2, stacked = True, label=labels_all)
ax.legend(prop={'size': 10})
ax.set_xlim(-700,700)
ax.set_ylim(0,140)
plt.title('CC1pi+Xpi0 enriched sample')
plt.xlabel('Reconstructed ' r'$\delta$$p_{TT}$ (MeV/c)')
plt.ylabel('Events per bin')





cutbranch_three = neut_array_dptt[neut_array_dptt[:,3]==3]             # This is for the CC-other-Xpi0 enriched sample: cutBranch = 3
#print("This is the signal sample", cutbranch_zero)

cb3_topology0 = cutbranch_three[cutbranch_three[:,2]==0][:,0] 
cb3_topology1 = cutbranch_three[cutbranch_three[:,2]==1][:,0] 
cb3_topology2 = cutbranch_three[cutbranch_three[:,2]==2][:,0]           # Specify the topology: For cutBranch = 0, topology = 2 is selected
cb3_topology3 = cutbranch_three[cutbranch_three[:,2]==3][:,0] 
cb3_topology4 = cutbranch_three[cutbranch_three[:,2]==4][:,0] 
cb3_topology5 = cutbranch_three[cutbranch_three[:,2]==5][:,0] 
cb3_topology6 = cutbranch_three[cutbranch_three[:,2]==6][:,0] 
cb3_topology7 = cutbranch_three[cutbranch_three[:,2]==7][:,0] 
cb3_topology8 = cutbranch_three[cutbranch_three[:,2]==8][:,0] 
cb3_topology9 = cutbranch_three[cutbranch_three[:,2]==9][:,0] 
cb3_topology10 = cutbranch_three[cutbranch_three[:,2]==10][:,0] 
cb3_topology11 = cutbranch_three[cutbranch_three[:,2]==11][:,0] 
#print("This is the topology 2", cb0_topology2)

weights_cb3_top0 = cutbranch_three[cutbranch_three[:,2]==0][:,1]
weights_cb3_top1 = cutbranch_three[cutbranch_three[:,2]==1][:,1]
weights_cb3_top2 = cutbranch_three[cutbranch_three[:,2]==2][:,1]        # Specify the weights for the topology
weights_cb3_top3 = cutbranch_three[cutbranch_three[:,2]==3][:,1]
weights_cb3_top4 = cutbranch_three[cutbranch_three[:,2]==4][:,1]
weights_cb3_top5 = cutbranch_three[cutbranch_three[:,2]==5][:,1]
weights_cb3_top6 = cutbranch_three[cutbranch_three[:,2]==6][:,1]
weights_cb3_top7 = cutbranch_three[cutbranch_three[:,2]==7][:,1]
weights_cb3_top8 = cutbranch_three[cutbranch_three[:,2]==8][:,1]
weights_cb3_top9 = cutbranch_three[cutbranch_three[:,2]==9][:,1]
weights_cb3_top10 = cutbranch_three[cutbranch_three[:,2]==10][:,1]
weights_cb3_top11 = cutbranch_three[cutbranch_three[:,2]==11][:,1]
#print(weights_cb0_top2)

x_cb3 = [cb3_topology0, cb3_topology1, cb3_topology2, cb3_topology3, cb3_topology4, cb3_topology5, cb3_topology6, cb3_topology7, cb3_topology8, cb3_topology9, cb3_topology10, cb3_topology11]
weights_cb3 = [weights_cb3_top0, weights_cb3_top1, weights_cb3_top2, weights_cb3_top3, weights_cb3_top4, weights_cb3_top5, weights_cb3_top6, weights_cb3_top7, weights_cb3_top8, weights_cb3_top9, weights_cb3_top10, weights_cb3_top11]

fig, ax = plt.subplots()
ax.hist(x_cb3, bins = bins_all, weights = weights_cb3, stacked = True, label=labels_all)
ax.legend(prop={'size': 10})
ax.set_xlim(-700,700)
ax.set_ylim(0,100)
plt.title('CC-other-Xpi0 enriched sample')
plt.xlabel('Reconstructed ' r'$\delta$$p_{TT}$ (MeV/c)')
plt.ylabel('Events per bin')





cutbranch_four = neut_array_dptt[neut_array_dptt[:,3]==4]             # This is for the CC-other-0pi0 enriched sample: cutBranch = 4
#print("This is the signal sample", cutbranch_zero)

cb4_topology0 = cutbranch_four[cutbranch_four[:,2]==0][:,0] 
cb4_topology1 = cutbranch_four[cutbranch_four[:,2]==1][:,0] 
cb4_topology2 = cutbranch_four[cutbranch_four[:,2]==2][:,0]           # Specify the topology: For cutBranch = 0, topology = 2 is selected
cb4_topology3 = cutbranch_four[cutbranch_four[:,2]==3][:,0] 
cb4_topology4 = cutbranch_four[cutbranch_four[:,2]==4][:,0] 
cb4_topology5 = cutbranch_four[cutbranch_four[:,2]==5][:,0] 
cb4_topology6 = cutbranch_four[cutbranch_four[:,2]==6][:,0] 
cb4_topology7 = cutbranch_four[cutbranch_four[:,2]==7][:,0] 
cb4_topology8 = cutbranch_four[cutbranch_four[:,2]==8][:,0] 
cb4_topology9 = cutbranch_four[cutbranch_four[:,2]==9][:,0] 
cb4_topology10 = cutbranch_four[cutbranch_four[:,2]==10][:,0] 
cb4_topology11 = cutbranch_four[cutbranch_four[:,2]==11][:,0] 
#print("This is the topology 2", cb0_topology2)

weights_cb4_top0 = cutbranch_four[cutbranch_four[:,2]==0][:,1]
weights_cb4_top1 = cutbranch_four[cutbranch_four[:,2]==1][:,1]
weights_cb4_top2 = cutbranch_four[cutbranch_four[:,2]==2][:,1]        # Specify the weights for the topology
weights_cb4_top3 = cutbranch_four[cutbranch_four[:,2]==3][:,1]
weights_cb4_top4 = cutbranch_four[cutbranch_four[:,2]==4][:,1]
weights_cb4_top5 = cutbranch_four[cutbranch_four[:,2]==5][:,1]
weights_cb4_top6 = cutbranch_four[cutbranch_four[:,2]==6][:,1]
weights_cb4_top7 = cutbranch_four[cutbranch_four[:,2]==7][:,1]
weights_cb4_top8 = cutbranch_four[cutbranch_four[:,2]==8][:,1]
weights_cb4_top9 = cutbranch_four[cutbranch_four[:,2]==9][:,1]
weights_cb4_top10 = cutbranch_four[cutbranch_four[:,2]==10][:,1]
weights_cb4_top11 = cutbranch_four[cutbranch_four[:,2]==11][:,1]
#print(weights_cb0_top2)

x_cb4 = [cb4_topology0, cb4_topology1, cb4_topology2, cb4_topology3, cb4_topology4, cb4_topology5, cb4_topology6, cb4_topology7, cb4_topology8, cb4_topology9, cb4_topology10, cb4_topology11]
weights_cb4 = [weights_cb4_top0, weights_cb4_top1, weights_cb4_top2, weights_cb4_top3, weights_cb4_top4, weights_cb4_top5, weights_cb4_top6, weights_cb4_top7, weights_cb4_top8, weights_cb4_top9, weights_cb4_top10, weights_cb4_top11]

fig, ax = plt.subplots()
ax.hist(x_cb4, bins = bins_all, weights = weights_cb4, stacked = True, label=labels_all)
ax.legend(prop={'size': 10})
ax.set_xlim(-700,700)
ax.set_ylim(0,35)
plt.title('CC-other-0pi0 enriched sample')
plt.xlabel('Reconstructed ' r'$\delta$$p_{TT}$ (MeV/c)')
plt.ylabel('Events per bin')
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# Text(0, 0.5, 'Events per bin')

# %%
# pn histograms

def getarray(filename):
    f = uproot.open(filename)
    t = f["selectedEvents"]
    array = np.transpose(np.asarray(t.arrays(["pN_rec", "weight", "topology", "cutBranch"], library="np", how=tuple)))
    return array
  

neut_array_pn = getarray("SummerProject2021/neut_flattree.root")
#print(neut_array_pn)

# Specify arguments for the histogram function here
bins_all = [0,125,250,600,1500]
colors_all = ['red', 'tan', 'lime']
labels_all = ["CC0pi", "CC1pi+0p", "CC1pi+1p", "CC1pi+Np", "CC1pi+1pi-", "CC1pi+Xpi0", "CC-other-Xpi0", "CC-other-0pi0", "background", "OOFV", "OOPS"]




cutbranch_zero = neut_array_pn[neut_array_pn[:,3]==0]             # This is for the signal sample: cutBranch = 0
#print("This is the signal sample", cutbranch_zero)

cb0_topology0 = cutbranch_zero[cutbranch_zero[:,2]==0][:,0] 
cb0_topology1 = cutbranch_zero[cutbranch_zero[:,2]==1][:,0] 
cb0_topology2 = cutbranch_zero[cutbranch_zero[:,2]==2][:,0]           # Specify the topology: For cutBranch = 0, topology = 2 is selected
cb0_topology3 = cutbranch_zero[cutbranch_zero[:,2]==3][:,0] 
cb0_topology4 = cutbranch_zero[cutbranch_zero[:,2]==4][:,0] 
cb0_topology5 = cutbranch_zero[cutbranch_zero[:,2]==5][:,0] 
cb0_topology6 = cutbranch_zero[cutbranch_zero[:,2]==6][:,0] 
cb0_topology7 = cutbranch_zero[cutbranch_zero[:,2]==7][:,0] 
cb0_topology8 = cutbranch_zero[cutbranch_zero[:,2]==8][:,0] 
cb0_topology9 = cutbranch_zero[cutbranch_zero[:,2]==9][:,0] 
cb0_topology10 = cutbranch_zero[cutbranch_zero[:,2]==10][:,0] 
cb0_topology11 = cutbranch_zero[cutbranch_zero[:,2]==11][:,0] 
#print("This is the topology 2", cb0_topology2)

weights_cb0_top0 = cutbranch_zero[cutbranch_zero[:,2]==0][:,1]
weights_cb0_top1 = cutbranch_zero[cutbranch_zero[:,2]==1][:,1]
weights_cb0_top2 = cutbranch_zero[cutbranch_zero[:,2]==2][:,1]        # Specify the weights for the topology
weights_cb0_top3 = cutbranch_zero[cutbranch_zero[:,2]==3][:,1]
weights_cb0_top4 = cutbranch_zero[cutbranch_zero[:,2]==4][:,1]
weights_cb0_top5 = cutbranch_zero[cutbranch_zero[:,2]==5][:,1]
weights_cb0_top6 = cutbranch_zero[cutbranch_zero[:,2]==6][:,1]
weights_cb0_top7 = cutbranch_zero[cutbranch_zero[:,2]==7][:,1]
weights_cb0_top8 = cutbranch_zero[cutbranch_zero[:,2]==8][:,1]
weights_cb0_top9 = cutbranch_zero[cutbranch_zero[:,2]==9][:,1]
weights_cb0_top10 = cutbranch_zero[cutbranch_zero[:,2]==10][:,1]
weights_cb0_top11 = cutbranch_zero[cutbranch_zero[:,2]==11][:,1]
#print(weights_cb0_top2)

x_cb0 = [cb0_topology0, cb0_topology1, cb0_topology2, cb0_topology3, cb0_topology4, cb0_topology5, cb0_topology6, cb0_topology7, cb0_topology8, cb0_topology9, cb0_topology10, cb0_topology11]
weights_cb0 = [weights_cb0_top0, weights_cb0_top1, weights_cb0_top2, weights_cb0_top3, weights_cb0_top4, weights_cb0_top5, weights_cb0_top6, weights_cb0_top7, weights_cb0_top8, weights_cb0_top9, weights_cb0_top10, weights_cb0_top11]

fig, ax = plt.subplots()
ax.hist(x_cb0, bins = bins_all, weights = weights_cb0, stacked = True, label=labels_all)
ax.legend(prop={'size': 10})
ax.set_xlim(0, 1500)
#ax.set_ylim(0,200)
plt.title('Signal sample')
plt.xlabel('Reconstructed ' '$p_{N}$ (MeV/c)')
plt.ylabel('Events per bin')







cutbranch_one = neut_array_pn[neut_array_pn[:,3]==1]             # This is for the CC1pi+1pi- enriched sample: cutBranch = 1
#print("This is the signal sample", cutbranch_zero)

cb1_topology0 = cutbranch_one[cutbranch_one[:,2]==0][:,0] 
cb1_topology1 = cutbranch_one[cutbranch_one[:,2]==1][:,0] 
cb1_topology2 = cutbranch_one[cutbranch_one[:,2]==2][:,0]           # Specify the topology: For cutBranch = 0, topology = 2 is selected
cb1_topology3 = cutbranch_one[cutbranch_one[:,2]==3][:,0] 
cb1_topology4 = cutbranch_one[cutbranch_one[:,2]==4][:,0] 
cb1_topology5 = cutbranch_one[cutbranch_one[:,2]==5][:,0] 
cb1_topology6 = cutbranch_one[cutbranch_one[:,2]==6][:,0] 
cb1_topology7 = cutbranch_one[cutbranch_one[:,2]==7][:,0] 
cb1_topology8 = cutbranch_one[cutbranch_one[:,2]==8][:,0] 
cb1_topology9 = cutbranch_one[cutbranch_one[:,2]==9][:,0] 
cb1_topology10 = cutbranch_one[cutbranch_one[:,2]==10][:,0] 
cb1_topology11 = cutbranch_one[cutbranch_one[:,2]==11][:,0] 
#print("This is the topology 2", cb0_topology2)

weights_cb1_top0 = cutbranch_one[cutbranch_one[:,2]==0][:,1]
weights_cb1_top1 = cutbranch_one[cutbranch_one[:,2]==1][:,1]
weights_cb1_top2 = cutbranch_one[cutbranch_one[:,2]==2][:,1]        # Specify the weights for the topology
weights_cb1_top3 = cutbranch_one[cutbranch_one[:,2]==3][:,1]
weights_cb1_top4 = cutbranch_one[cutbranch_one[:,2]==4][:,1]
weights_cb1_top5 = cutbranch_one[cutbranch_one[:,2]==5][:,1]
weights_cb1_top6 = cutbranch_one[cutbranch_one[:,2]==6][:,1]
weights_cb1_top7 = cutbranch_one[cutbranch_one[:,2]==7][:,1]
weights_cb1_top8 = cutbranch_one[cutbranch_one[:,2]==8][:,1]
weights_cb1_top9 = cutbranch_one[cutbranch_one[:,2]==9][:,1]
weights_cb1_top10 = cutbranch_one[cutbranch_one[:,2]==10][:,1]
weights_cb1_top11 = cutbranch_one[cutbranch_one[:,2]==11][:,1]
#print(weights_cb0_top2)

x_cb1 = [cb1_topology0, cb1_topology1, cb1_topology2, cb1_topology3, cb1_topology4, cb1_topology5, cb1_topology6, cb1_topology7, cb1_topology8, cb1_topology9, cb1_topology10, cb1_topology11]
weights_cb1 = [weights_cb1_top0, weights_cb1_top1, weights_cb1_top2, weights_cb1_top3, weights_cb1_top4, weights_cb1_top5, weights_cb1_top6, weights_cb1_top7, weights_cb1_top8, weights_cb1_top9, weights_cb1_top10, weights_cb1_top11]

fig, ax = plt.subplots()
ax.hist(x_cb1, bins = bins_all, weights = weights_cb1, stacked = True, label=labels_all)
ax.legend(prop={'size': 10})
ax.set_xlim(0, 1500)
ax.set_ylim(0,150)
plt.title('CC1pi+1pi- enriched sample')
plt.xlabel('Reconstructed ' '$p_{N}$ (MeV/c)')
plt.ylabel('Events per bin')






cutbranch_two = neut_array_pn[neut_array_pn[:,3]==2]             # This is for the CC1pi+Xpi0 enriched sample: cutBranch = 2
#print("This is the signal sample", cutbranch_zero)

cb2_topology0 = cutbranch_two[cutbranch_two[:,2]==0][:,0] 
cb2_topology1 = cutbranch_two[cutbranch_two[:,2]==1][:,0] 
cb2_topology2 = cutbranch_two[cutbranch_two[:,2]==2][:,0]           # Specify the topology: For cutBranch = 0, topology = 2 is selected
cb2_topology3 = cutbranch_two[cutbranch_two[:,2]==3][:,0] 
cb2_topology4 = cutbranch_two[cutbranch_two[:,2]==4][:,0] 
cb2_topology5 = cutbranch_two[cutbranch_two[:,2]==5][:,0] 
cb2_topology6 = cutbranch_two[cutbranch_two[:,2]==6][:,0] 
cb2_topology7 = cutbranch_two[cutbranch_two[:,2]==7][:,0] 
cb2_topology8 = cutbranch_two[cutbranch_two[:,2]==8][:,0] 
cb2_topology9 = cutbranch_two[cutbranch_two[:,2]==9][:,0] 
cb2_topology10 = cutbranch_two[cutbranch_two[:,2]==10][:,0] 
cb2_topology11 = cutbranch_two[cutbranch_two[:,2]==11][:,0] 
#print("This is the topology 2", cb0_topology2)

weights_cb2_top0 = cutbranch_two[cutbranch_two[:,2]==0][:,1]
weights_cb2_top1 = cutbranch_two[cutbranch_two[:,2]==1][:,1]
weights_cb2_top2 = cutbranch_two[cutbranch_two[:,2]==2][:,1]        # Specify the weights for the topology
weights_cb2_top3 = cutbranch_two[cutbranch_two[:,2]==3][:,1]
weights_cb2_top4 = cutbranch_two[cutbranch_two[:,2]==4][:,1]
weights_cb2_top5 = cutbranch_two[cutbranch_two[:,2]==5][:,1]
weights_cb2_top6 = cutbranch_two[cutbranch_two[:,2]==6][:,1]
weights_cb2_top7 = cutbranch_two[cutbranch_two[:,2]==7][:,1]
weights_cb2_top8 = cutbranch_two[cutbranch_two[:,2]==8][:,1]
weights_cb2_top9 = cutbranch_two[cutbranch_two[:,2]==9][:,1]
weights_cb2_top10 = cutbranch_two[cutbranch_two[:,2]==10][:,1]
weights_cb2_top11 = cutbranch_two[cutbranch_two[:,2]==11][:,1]
#print(weights_cb0_top2)

x_cb2 = [cb2_topology0, cb2_topology1, cb2_topology2, cb2_topology3, cb2_topology4, cb2_topology5, cb2_topology6, cb2_topology7, cb2_topology8, cb2_topology9, cb2_topology10, cb2_topology11]
weights_cb2 = [weights_cb2_top0, weights_cb2_top1, weights_cb2_top2, weights_cb2_top3, weights_cb2_top4, weights_cb2_top5, weights_cb2_top6, weights_cb2_top7, weights_cb2_top8, weights_cb2_top9, weights_cb2_top10, weights_cb2_top11]

fig, ax = plt.subplots()
ax.hist(x_cb2, bins = bins_all, weights = weights_cb2, stacked = True, label=labels_all)
ax.legend(prop={'size': 10})
ax.set_xlim(0, 1500)
ax.set_ylim(0,220)
plt.title('CC1pi+Xpi0 enriched sample')
plt.xlabel('Reconstructed ' '$p_{N}$ (MeV/c)')
plt.ylabel('Events per bin')





cutbranch_three = neut_array_pn[neut_array_pn[:,3]==3]             # This is for the CC-other-Xpi0 enriched sample: cutBranch = 3
#print("This is the signal sample", cutbranch_zero)

cb3_topology0 = cutbranch_three[cutbranch_three[:,2]==0][:,0] 
cb3_topology1 = cutbranch_three[cutbranch_three[:,2]==1][:,0] 
cb3_topology2 = cutbranch_three[cutbranch_three[:,2]==2][:,0]           # Specify the topology: For cutBranch = 0, topology = 2 is selected
cb3_topology3 = cutbranch_three[cutbranch_three[:,2]==3][:,0] 
cb3_topology4 = cutbranch_three[cutbranch_three[:,2]==4][:,0] 
cb3_topology5 = cutbranch_three[cutbranch_three[:,2]==5][:,0] 
cb3_topology6 = cutbranch_three[cutbranch_three[:,2]==6][:,0] 
cb3_topology7 = cutbranch_three[cutbranch_three[:,2]==7][:,0] 
cb3_topology8 = cutbranch_three[cutbranch_three[:,2]==8][:,0] 
cb3_topology9 = cutbranch_three[cutbranch_three[:,2]==9][:,0] 
cb3_topology10 = cutbranch_three[cutbranch_three[:,2]==10][:,0] 
cb3_topology11 = cutbranch_three[cutbranch_three[:,2]==11][:,0] 
#print("This is the topology 2", cb0_topology2)

weights_cb3_top0 = cutbranch_three[cutbranch_three[:,2]==0][:,1]
weights_cb3_top1 = cutbranch_three[cutbranch_three[:,2]==1][:,1]
weights_cb3_top2 = cutbranch_three[cutbranch_three[:,2]==2][:,1]        # Specify the weights for the topology
weights_cb3_top3 = cutbranch_three[cutbranch_three[:,2]==3][:,1]
weights_cb3_top4 = cutbranch_three[cutbranch_three[:,2]==4][:,1]
weights_cb3_top5 = cutbranch_three[cutbranch_three[:,2]==5][:,1]
weights_cb3_top6 = cutbranch_three[cutbranch_three[:,2]==6][:,1]
weights_cb3_top7 = cutbranch_three[cutbranch_three[:,2]==7][:,1]
weights_cb3_top8 = cutbranch_three[cutbranch_three[:,2]==8][:,1]
weights_cb3_top9 = cutbranch_three[cutbranch_three[:,2]==9][:,1]
weights_cb3_top10 = cutbranch_three[cutbranch_three[:,2]==10][:,1]
weights_cb3_top11 = cutbranch_three[cutbranch_three[:,2]==11][:,1]
#print(weights_cb0_top2)

x_cb3 = [cb3_topology0, cb3_topology1, cb3_topology2, cb3_topology3, cb3_topology4, cb3_topology5, cb3_topology6, cb3_topology7, cb3_topology8, cb3_topology9, cb3_topology10, cb3_topology11]
weights_cb3 = [weights_cb3_top0, weights_cb3_top1, weights_cb3_top2, weights_cb3_top3, weights_cb3_top4, weights_cb3_top5, weights_cb3_top6, weights_cb3_top7, weights_cb3_top8, weights_cb3_top9, weights_cb3_top10, weights_cb3_top11]

fig, ax = plt.subplots()
ax.hist(x_cb3, bins = bins_all, weights = weights_cb3, stacked = True, label=labels_all)
ax.legend(prop={'size': 10})
ax.set_xlim(0, 1500)
ax.set_ylim(0,180)
plt.title('CC-other-Xpi0 enriched sample')
plt.xlabel('Reconstructed ' '$p_{N}$ (MeV/c)')
plt.ylabel('Events per bin')





cutbranch_four = neut_array_pn[neut_array_pn[:,3]==4]             # This is for the CC-other-0pi0 enriched sample: cutBranch = 4
#print("This is the signal sample", cutbranch_zero)

cb4_topology0 = cutbranch_four[cutbranch_four[:,2]==0][:,0] 
cb4_topology1 = cutbranch_four[cutbranch_four[:,2]==1][:,0] 
cb4_topology2 = cutbranch_four[cutbranch_four[:,2]==2][:,0]           # Specify the topology: For cutBranch = 0, topology = 2 is selected
cb4_topology3 = cutbranch_four[cutbranch_four[:,2]==3][:,0] 
cb4_topology4 = cutbranch_four[cutbranch_four[:,2]==4][:,0] 
cb4_topology5 = cutbranch_four[cutbranch_four[:,2]==5][:,0] 
cb4_topology6 = cutbranch_four[cutbranch_four[:,2]==6][:,0] 
cb4_topology7 = cutbranch_four[cutbranch_four[:,2]==7][:,0] 
cb4_topology8 = cutbranch_four[cutbranch_four[:,2]==8][:,0] 
cb4_topology9 = cutbranch_four[cutbranch_four[:,2]==9][:,0] 
cb4_topology10 = cutbranch_four[cutbranch_four[:,2]==10][:,0] 
cb4_topology11 = cutbranch_four[cutbranch_four[:,2]==11][:,0] 
#print("This is the topology 2", cb0_topology2)

weights_cb4_top0 = cutbranch_four[cutbranch_four[:,2]==0][:,1]
weights_cb4_top1 = cutbranch_four[cutbranch_four[:,2]==1][:,1]
weights_cb4_top2 = cutbranch_four[cutbranch_four[:,2]==2][:,1]        # Specify the weights for the topology
weights_cb4_top3 = cutbranch_four[cutbranch_four[:,2]==3][:,1]
weights_cb4_top4 = cutbranch_four[cutbranch_four[:,2]==4][:,1]
weights_cb4_top5 = cutbranch_four[cutbranch_four[:,2]==5][:,1]
weights_cb4_top6 = cutbranch_four[cutbranch_four[:,2]==6][:,1]
weights_cb4_top7 = cutbranch_four[cutbranch_four[:,2]==7][:,1]
weights_cb4_top8 = cutbranch_four[cutbranch_four[:,2]==8][:,1]
weights_cb4_top9 = cutbranch_four[cutbranch_four[:,2]==9][:,1]
weights_cb4_top10 = cutbranch_four[cutbranch_four[:,2]==10][:,1]
weights_cb4_top11 = cutbranch_four[cutbranch_four[:,2]==11][:,1]
#print(weights_cb0_top2)

x_cb4 = [cb4_topology0, cb4_topology1, cb4_topology2, cb4_topology3, cb4_topology4, cb4_topology5, cb4_topology6, cb4_topology7, cb4_topology8, cb4_topology9, cb4_topology10, cb4_topology11]
weights_cb4 = [weights_cb4_top0, weights_cb4_top1, weights_cb4_top2, weights_cb4_top3, weights_cb4_top4, weights_cb4_top5, weights_cb4_top6, weights_cb4_top7, weights_cb4_top8, weights_cb4_top9, weights_cb4_top10, weights_cb4_top11]

fig, ax = plt.subplots()
ax.hist(x_cb4, bins = bins_all, weights = weights_cb4, stacked = True, label=labels_all)
ax.legend(prop={'size': 10})
ax.set_xlim(0, 1500)
ax.set_ylim(0,70)
plt.title('CC-other-0pi0 enriched sample')
plt.xlabel('Reconstructed ' '$p_{N}$ (MeV/c)')
plt.ylabel('Events per bin')
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# Text(0, 0.5, 'Events per bin')

# %%
# daT histograms

def getarray(filename):
    f = uproot.open(filename)
    t = f["selectedEvents"]
    array = np.transpose(np.asarray(t.arrays(["daT_rec", "weight", "topology", "cutBranch"], library="np", how=tuple)))
    return array
  

neut_array_dat = getarray("SummerProject2021/neut_flattree.root")
#print(neut_array_dat)

# Specify arguments for the histogram function here
bins_all = [0,60,120,180]
colors_all = ['red', 'tan', 'lime']
labels_all = ["CC0pi", "CC1pi+0p", "CC1pi+1p", "CC1pi+Np", "CC1pi+1pi-", "CC1pi+Xpi0", "CC-other-Xpi0", "CC-other-0pi0", "background", "OOFV", "OOPS"]




cutbranch_zero = neut_array_dat[neut_array_dat[:,3]==0]             # This is for the signal sample: cutBranch = 0
#print("This is the signal sample", cutbranch_zero)

cb0_topology0 = cutbranch_zero[cutbranch_zero[:,2]==0][:,0] 
cb0_topology1 = cutbranch_zero[cutbranch_zero[:,2]==1][:,0] 
cb0_topology2 = cutbranch_zero[cutbranch_zero[:,2]==2][:,0]           # Specify the topology: For cutBranch = 0, topology = 2 is selected
cb0_topology3 = cutbranch_zero[cutbranch_zero[:,2]==3][:,0] 
cb0_topology4 = cutbranch_zero[cutbranch_zero[:,2]==4][:,0] 
cb0_topology5 = cutbranch_zero[cutbranch_zero[:,2]==5][:,0] 
cb0_topology6 = cutbranch_zero[cutbranch_zero[:,2]==6][:,0] 
cb0_topology7 = cutbranch_zero[cutbranch_zero[:,2]==7][:,0] 
cb0_topology8 = cutbranch_zero[cutbranch_zero[:,2]==8][:,0] 
cb0_topology9 = cutbranch_zero[cutbranch_zero[:,2]==9][:,0] 
cb0_topology10 = cutbranch_zero[cutbranch_zero[:,2]==10][:,0] 
cb0_topology11 = cutbranch_zero[cutbranch_zero[:,2]==11][:,0] 
#print("This is the topology 2", cb0_topology2)

weights_cb0_top0 = cutbranch_zero[cutbranch_zero[:,2]==0][:,1]
weights_cb0_top1 = cutbranch_zero[cutbranch_zero[:,2]==1][:,1]
weights_cb0_top2 = cutbranch_zero[cutbranch_zero[:,2]==2][:,1]        # Specify the weights for the topology
weights_cb0_top3 = cutbranch_zero[cutbranch_zero[:,2]==3][:,1]
weights_cb0_top4 = cutbranch_zero[cutbranch_zero[:,2]==4][:,1]
weights_cb0_top5 = cutbranch_zero[cutbranch_zero[:,2]==5][:,1]
weights_cb0_top6 = cutbranch_zero[cutbranch_zero[:,2]==6][:,1]
weights_cb0_top7 = cutbranch_zero[cutbranch_zero[:,2]==7][:,1]
weights_cb0_top8 = cutbranch_zero[cutbranch_zero[:,2]==8][:,1]
weights_cb0_top9 = cutbranch_zero[cutbranch_zero[:,2]==9][:,1]
weights_cb0_top10 = cutbranch_zero[cutbranch_zero[:,2]==10][:,1]
weights_cb0_top11 = cutbranch_zero[cutbranch_zero[:,2]==11][:,1]
#print(weights_cb0_top2)

x_cb0 = [cb0_topology0, cb0_topology1, cb0_topology2, cb0_topology3, cb0_topology4, cb0_topology5, cb0_topology6, cb0_topology7, cb0_topology8, cb0_topology9, cb0_topology10, cb0_topology11]
weights_cb0 = [weights_cb0_top0, weights_cb0_top1, weights_cb0_top2, weights_cb0_top3, weights_cb0_top4, weights_cb0_top5, weights_cb0_top6, weights_cb0_top7, weights_cb0_top8, weights_cb0_top9, weights_cb0_top10, weights_cb0_top11]

fig, ax = plt.subplots()
ax.hist(x_cb0, bins = bins_all, weights = weights_cb0, stacked = True, label=labels_all)
ax.legend(prop={'size': 10})
ax.set_xlim(0,180)
#ax.set_ylim(0,250)
plt.title('Signal sample')
plt.xlabel('Reconstructed ' r'$\delta$$\alpha_{T}$ (deg)')
plt.ylabel('Events per bin')







cutbranch_one = neut_array_dat[neut_array_dat[:,3]==1]             # This is for the CC1pi+1pi- enriched sample: cutBranch = 1
#print("This is the signal sample", cutbranch_zero)

cb1_topology0 = cutbranch_one[cutbranch_one[:,2]==0][:,0] 
cb1_topology1 = cutbranch_one[cutbranch_one[:,2]==1][:,0] 
cb1_topology2 = cutbranch_one[cutbranch_one[:,2]==2][:,0]           # Specify the topology: For cutBranch = 0, topology = 2 is selected
cb1_topology3 = cutbranch_one[cutbranch_one[:,2]==3][:,0] 
cb1_topology4 = cutbranch_one[cutbranch_one[:,2]==4][:,0] 
cb1_topology5 = cutbranch_one[cutbranch_one[:,2]==5][:,0] 
cb1_topology6 = cutbranch_one[cutbranch_one[:,2]==6][:,0] 
cb1_topology7 = cutbranch_one[cutbranch_one[:,2]==7][:,0] 
cb1_topology8 = cutbranch_one[cutbranch_one[:,2]==8][:,0] 
cb1_topology9 = cutbranch_one[cutbranch_one[:,2]==9][:,0] 
cb1_topology10 = cutbranch_one[cutbranch_one[:,2]==10][:,0] 
cb1_topology11 = cutbranch_one[cutbranch_one[:,2]==11][:,0] 
#print("This is the topology 2", cb0_topology2)

weights_cb1_top0 = cutbranch_one[cutbranch_one[:,2]==0][:,1]
weights_cb1_top1 = cutbranch_one[cutbranch_one[:,2]==1][:,1]
weights_cb1_top2 = cutbranch_one[cutbranch_one[:,2]==2][:,1]        # Specify the weights for the topology
weights_cb1_top3 = cutbranch_one[cutbranch_one[:,2]==3][:,1]
weights_cb1_top4 = cutbranch_one[cutbranch_one[:,2]==4][:,1]
weights_cb1_top5 = cutbranch_one[cutbranch_one[:,2]==5][:,1]
weights_cb1_top6 = cutbranch_one[cutbranch_one[:,2]==6][:,1]
weights_cb1_top7 = cutbranch_one[cutbranch_one[:,2]==7][:,1]
weights_cb1_top8 = cutbranch_one[cutbranch_one[:,2]==8][:,1]
weights_cb1_top9 = cutbranch_one[cutbranch_one[:,2]==9][:,1]
weights_cb1_top10 = cutbranch_one[cutbranch_one[:,2]==10][:,1]
weights_cb1_top11 = cutbranch_one[cutbranch_one[:,2]==11][:,1]
#print(weights_cb0_top2)

x_cb1 = [cb1_topology0, cb1_topology1, cb1_topology2, cb1_topology3, cb1_topology4, cb1_topology5, cb1_topology6, cb1_topology7, cb1_topology8, cb1_topology9, cb1_topology10, cb1_topology11]
weights_cb1 = [weights_cb1_top0, weights_cb1_top1, weights_cb1_top2, weights_cb1_top3, weights_cb1_top4, weights_cb1_top5, weights_cb1_top6, weights_cb1_top7, weights_cb1_top8, weights_cb1_top9, weights_cb1_top10, weights_cb1_top11]

fig, ax = plt.subplots()
ax.hist(x_cb1, bins = bins_all, weights = weights_cb1, stacked = True, label=labels_all)
ax.legend(prop={'size': 10})
ax.set_xlim(0,180)
ax.set_ylim(0,150)
plt.title('CC1pi+1pi- enriched sample')
plt.xlabel('Reconstructed ' r'$\delta$$\alpha_{T}$ (deg)')
plt.ylabel('Events per bin')






cutbranch_two = neut_array_dat[neut_array_dat[:,3]==2]             # This is for the CC1pi+Xpi0 enriched sample: cutBranch = 2
#print("This is the signal sample", cutbranch_zero)

cb2_topology0 = cutbranch_two[cutbranch_two[:,2]==0][:,0] 
cb2_topology1 = cutbranch_two[cutbranch_two[:,2]==1][:,0] 
cb2_topology2 = cutbranch_two[cutbranch_two[:,2]==2][:,0]           # Specify the topology: For cutBranch = 0, topology = 2 is selected
cb2_topology3 = cutbranch_two[cutbranch_two[:,2]==3][:,0] 
cb2_topology4 = cutbranch_two[cutbranch_two[:,2]==4][:,0] 
cb2_topology5 = cutbranch_two[cutbranch_two[:,2]==5][:,0] 
cb2_topology6 = cutbranch_two[cutbranch_two[:,2]==6][:,0] 
cb2_topology7 = cutbranch_two[cutbranch_two[:,2]==7][:,0] 
cb2_topology8 = cutbranch_two[cutbranch_two[:,2]==8][:,0] 
cb2_topology9 = cutbranch_two[cutbranch_two[:,2]==9][:,0] 
cb2_topology10 = cutbranch_two[cutbranch_two[:,2]==10][:,0] 
cb2_topology11 = cutbranch_two[cutbranch_two[:,2]==11][:,0] 
#print("This is the topology 2", cb0_topology2)

weights_cb2_top0 = cutbranch_two[cutbranch_two[:,2]==0][:,1]
weights_cb2_top1 = cutbranch_two[cutbranch_two[:,2]==1][:,1]
weights_cb2_top2 = cutbranch_two[cutbranch_two[:,2]==2][:,1]        # Specify the weights for the topology
weights_cb2_top3 = cutbranch_two[cutbranch_two[:,2]==3][:,1]
weights_cb2_top4 = cutbranch_two[cutbranch_two[:,2]==4][:,1]
weights_cb2_top5 = cutbranch_two[cutbranch_two[:,2]==5][:,1]
weights_cb2_top6 = cutbranch_two[cutbranch_two[:,2]==6][:,1]
weights_cb2_top7 = cutbranch_two[cutbranch_two[:,2]==7][:,1]
weights_cb2_top8 = cutbranch_two[cutbranch_two[:,2]==8][:,1]
weights_cb2_top9 = cutbranch_two[cutbranch_two[:,2]==9][:,1]
weights_cb2_top10 = cutbranch_two[cutbranch_two[:,2]==10][:,1]
weights_cb2_top11 = cutbranch_two[cutbranch_two[:,2]==11][:,1]
#print(weights_cb0_top2)

x_cb2 = [cb2_topology0, cb2_topology1, cb2_topology2, cb2_topology3, cb2_topology4, cb2_topology5, cb2_topology6, cb2_topology7, cb2_topology8, cb2_topology9, cb2_topology10, cb2_topology11]
weights_cb2 = [weights_cb2_top0, weights_cb2_top1, weights_cb2_top2, weights_cb2_top3, weights_cb2_top4, weights_cb2_top5, weights_cb2_top6, weights_cb2_top7, weights_cb2_top8, weights_cb2_top9, weights_cb2_top10, weights_cb2_top11]

fig, ax = plt.subplots()
ax.hist(x_cb2, bins = bins_all, weights = weights_cb2, stacked = True, label=labels_all)
ax.legend(prop={'size': 10})
ax.set_xlim(0,180)
ax.set_ylim(0,350)
plt.title('CC1pi+Xpi0 enriched sample')
plt.xlabel('Reconstructed ' r'$\delta$$\alpha_{T}$ (deg)')
plt.ylabel('Events per bin')





cutbranch_three = neut_array_dat[neut_array_dat[:,3]==3]             # This is for the CC-other-Xpi0 enriched sample: cutBranch = 3
#print("This is the signal sample", cutbranch_zero)

cb3_topology0 = cutbranch_three[cutbranch_three[:,2]==0][:,0] 
cb3_topology1 = cutbranch_three[cutbranch_three[:,2]==1][:,0] 
cb3_topology2 = cutbranch_three[cutbranch_three[:,2]==2][:,0]           # Specify the topology: For cutBranch = 3, topology = 2 is selected
cb3_topology3 = cutbranch_three[cutbranch_three[:,2]==3][:,0] 
cb3_topology4 = cutbranch_three[cutbranch_three[:,2]==4][:,0] 
cb3_topology5 = cutbranch_three[cutbranch_three[:,2]==5][:,0] 
cb3_topology6 = cutbranch_three[cutbranch_three[:,2]==6][:,0] 
cb3_topology7 = cutbranch_three[cutbranch_three[:,2]==7][:,0] 
cb3_topology8 = cutbranch_three[cutbranch_three[:,2]==8][:,0] 
cb3_topology9 = cutbranch_three[cutbranch_three[:,2]==9][:,0] 
cb3_topology10 = cutbranch_three[cutbranch_three[:,2]==10][:,0] 
cb3_topology11 = cutbranch_three[cutbranch_three[:,2]==11][:,0] 
#print("This is the topology 2", cb0_topology2)

weights_cb3_top0 = cutbranch_three[cutbranch_three[:,2]==0][:,1]
weights_cb3_top1 = cutbranch_three[cutbranch_three[:,2]==1][:,1]
weights_cb3_top2 = cutbranch_three[cutbranch_three[:,2]==2][:,1]        # Specify the weights for the topology
weights_cb3_top3 = cutbranch_three[cutbranch_three[:,2]==3][:,1]
weights_cb3_top4 = cutbranch_three[cutbranch_three[:,2]==4][:,1]
weights_cb3_top5 = cutbranch_three[cutbranch_three[:,2]==5][:,1]
weights_cb3_top6 = cutbranch_three[cutbranch_three[:,2]==6][:,1]
weights_cb3_top7 = cutbranch_three[cutbranch_three[:,2]==7][:,1]
weights_cb3_top8 = cutbranch_three[cutbranch_three[:,2]==8][:,1]
weights_cb3_top9 = cutbranch_three[cutbranch_three[:,2]==9][:,1]
weights_cb3_top10 = cutbranch_three[cutbranch_three[:,2]==10][:,1]
weights_cb3_top11 = cutbranch_three[cutbranch_three[:,2]==11][:,1]
#print(weights_cb0_top2)

x_cb3 = [cb3_topology0, cb3_topology1, cb3_topology2, cb3_topology3, cb3_topology4, cb3_topology5, cb3_topology6, cb3_topology7, cb3_topology8, cb3_topology9, cb3_topology10, cb3_topology11]
weights_cb3 = [weights_cb3_top0, weights_cb3_top1, weights_cb3_top2, weights_cb3_top3, weights_cb3_top4, weights_cb3_top5, weights_cb3_top6, weights_cb3_top7, weights_cb3_top8, weights_cb3_top9, weights_cb3_top10, weights_cb3_top11]

fig, ax = plt.subplots()
ax.hist(x_cb3, bins = bins_all, weights = weights_cb3, stacked = True, label=labels_all)
ax.legend(prop={'size': 10})
ax.set_xlim(0,180)
ax.set_ylim(0,250)
plt.title('CC-other-Xpi0 enriched sample')
plt.xlabel('Reconstructed ' r'$\delta$$\alpha_{T}$ (deg)')
plt.ylabel('Events per bin')





cutbranch_four = neut_array_dat[neut_array_dat[:,3]==4]             # This is for the CC-other-0pi0 enriched sample: cutBranch = 4
#print("This is the signal sample", cutbranch_zero)

cb4_topology0 = cutbranch_four[cutbranch_four[:,2]==0][:,0] 
cb4_topology1 = cutbranch_four[cutbranch_four[:,2]==1][:,0] 
cb4_topology2 = cutbranch_four[cutbranch_four[:,2]==2][:,0]           # Specify the topology: For cutBranch = 0, topology = 2 is selected
cb4_topology3 = cutbranch_four[cutbranch_four[:,2]==3][:,0] 
cb4_topology4 = cutbranch_four[cutbranch_four[:,2]==4][:,0] 
cb4_topology5 = cutbranch_four[cutbranch_four[:,2]==5][:,0] 
cb4_topology6 = cutbranch_four[cutbranch_four[:,2]==6][:,0] 
cb4_topology7 = cutbranch_four[cutbranch_four[:,2]==7][:,0] 
cb4_topology8 = cutbranch_four[cutbranch_four[:,2]==8][:,0] 
cb4_topology9 = cutbranch_four[cutbranch_four[:,2]==9][:,0] 
cb4_topology10 = cutbranch_four[cutbranch_four[:,2]==10][:,0] 
cb4_topology11 = cutbranch_four[cutbranch_four[:,2]==11][:,0] 
#print("This is the topology 2", cb0_topology2)

weights_cb4_top0 = cutbranch_four[cutbranch_four[:,2]==0][:,1]
weights_cb4_top1 = cutbranch_four[cutbranch_four[:,2]==1][:,1]
weights_cb4_top2 = cutbranch_four[cutbranch_four[:,2]==2][:,1]        # Specify the weights for the topology
weights_cb4_top3 = cutbranch_four[cutbranch_four[:,2]==3][:,1]
weights_cb4_top4 = cutbranch_four[cutbranch_four[:,2]==4][:,1]
weights_cb4_top5 = cutbranch_four[cutbranch_four[:,2]==5][:,1]
weights_cb4_top6 = cutbranch_four[cutbranch_four[:,2]==6][:,1]
weights_cb4_top7 = cutbranch_four[cutbranch_four[:,2]==7][:,1]
weights_cb4_top8 = cutbranch_four[cutbranch_four[:,2]==8][:,1]
weights_cb4_top9 = cutbranch_four[cutbranch_four[:,2]==9][:,1]
weights_cb4_top10 = cutbranch_four[cutbranch_four[:,2]==10][:,1]
weights_cb4_top11 = cutbranch_four[cutbranch_four[:,2]==11][:,1]
#print(weights_cb0_top2)

x_cb4 = [cb4_topology0, cb4_topology1, cb4_topology2, cb4_topology3, cb4_topology4, cb4_topology5, cb4_topology6, cb4_topology7, cb4_topology8, cb4_topology9, cb4_topology10, cb4_topology11]
weights_cb4 = [weights_cb4_top0, weights_cb4_top1, weights_cb4_top2, weights_cb4_top3, weights_cb4_top4, weights_cb4_top5, weights_cb4_top6, weights_cb4_top7, weights_cb4_top8, weights_cb4_top9, weights_cb4_top10, weights_cb4_top11]

fig, ax = plt.subplots()
ax.hist(x_cb4, bins = bins_all, weights = weights_cb4, stacked = True, label=labels_all)
ax.legend(prop={'size': 10})
ax.set_xlim(0,180)
ax.set_ylim(0,100)
plt.title('CC-other-0pi0 enriched sample')
plt.xlabel('Reconstructed ' r'$\delta$$\alpha_{T}$ (deg)')
plt.ylabel('Events per bin')
plt.ylabel('Events per bin')
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# Text(0, 0.5, 'Events per bin')
