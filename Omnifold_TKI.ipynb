# %% [markdown]
# <a href="https://colab.research.google.com/github/kmtsui/SummerProject2021/blob/pwagh/Omnifold_TKI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# install some packages in order to use latex
! sudo apt-get update
! sudo apt-get install texlive-latex-recommended 
! sudo apt-get install dvipng texlive-latex-extra texlive-fonts-recommended  
! wget http://mirrors.ctan.org/macros/latex/contrib/type1cm.zip 
! unzip type1cm.zip -d /tmp/type1cm 
! cd /tmp/type1cm/type1cm/ && sudo latex type1cm.ins
! sudo mkdir /usr/share/texmf/tex/latex/type1cm 
! sudo cp /tmp/type1cm/type1cm/type1cm.sty /usr/share/texmf/tex/latex/type1cm 
! sudo texhash 
! apt install cm-super
! pip install latex


# install uproot
! pip install uproot
# Out:
# Get:1 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease [3,626 B]
# Get:3 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease [15.9 kB]
# Get:4 http://security.ubuntu.com/ubuntu bionic-security/restricted amd64 Packages [543 kB]
# Hit:5 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:6 http://security.ubuntu.com/ubuntu bionic-security/main amd64 Packages [2,294 kB]
# Get:7 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Ign:8 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Hit:9 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Hit:10 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic InRelease
# Get:11 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [74.6 kB]
# Ign:12 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:13 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release
# Hit:14 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Hit:15 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Get:16 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main Sources [1,792 kB]
# Get:17 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 Packages [2,730 kB]
# Get:20 http://archive.ubuntu.com/ubuntu bionic-updates/restricted amd64 Packages [575 kB]
# Get:21 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 Packages [2,196 kB]
# Get:22 http://archive.ubuntu.com/ubuntu bionic-updates/multiverse amd64 Packages [34.4 kB]
# Get:23 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main amd64 Packages [917 kB]
# Fetched 11.4 MB in 2s (5,266 kB/s)
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'sudo apt autoremove' to remove it.
# The following additional packages will be installed:
#   fonts-droid-fallback fonts-lmodern fonts-noto-mono libcupsfilters1
#   libcupsimage2 libgs9 libgs9-common libijs-0.35 libjbig2dec0 libkpathsea6
#   libpotrace0 libptexenc1 libsynctex1 libtexlua52 libtexluajit2 libzzip-0-13
#   lmodern poppler-data t1utils tex-common texlive-base texlive-binaries
#   texlive-latex-base
# Suggested packages:
#   fonts-noto poppler-utils ghostscript fonts-japanese-mincho
#   | fonts-ipafont-mincho fonts-japanese-gothic | fonts-ipafont-gothic
#   fonts-arphic-ukai fonts-arphic-uming fonts-nanum debhelper gv
#   | postscript-viewer perl-tk xpdf-reader | pdf-viewer texlive-latex-base-doc
#   texlive-latex-recommended-doc texlive-pstricks
# The following NEW packages will be installed:
#   fonts-droid-fallback fonts-lmodern fonts-noto-mono libcupsfilters1
#   libcupsimage2 libgs9 libgs9-common libijs-0.35 libjbig2dec0 libkpathsea6
#   libpotrace0 libptexenc1 libsynctex1 libtexlua52 libtexluajit2 libzzip-0-13
#   lmodern poppler-data t1utils tex-common texlive-base texlive-binaries
#   texlive-latex-base texlive-latex-recommended
# 0 upgraded, 24 newly installed, 0 to remove and 49 not upgraded.
# Need to get 68.4 MB of archives.
# After this operation, 223 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/main amd64 fonts-droid-fallback all 1:6.0.1r16-1.1 [1,805 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/main amd64 poppler-data all 0.4.8-2 [1,479 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic/main amd64 tex-common all 6.09 [33.0 kB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic/main amd64 fonts-lmodern all 2.004.5-3 [4,551 kB]
# Get:5 http://archive.ubuntu.com/ubuntu bionic/main amd64 fonts-noto-mono all 20171026-2 [75.5 kB]
# Get:6 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libcupsfilters1 amd64 1.20.2-0ubuntu3.1 [108 kB]
# Get:7 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libcupsimage2 amd64 2.2.7-1ubuntu2.8 [18.6 kB]
# Get:8 http://archive.ubuntu.com/ubuntu bionic/main amd64 libijs-0.35 amd64 0.35-13 [15.5 kB]
# Get:9 http://archive.ubuntu.com/ubuntu bionic/main amd64 libjbig2dec0 amd64 0.13-6 [55.9 kB]
# Get:10 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libgs9-common all 9.26~dfsg+0-0ubuntu0.18.04.14 [5,092 kB]
# Get:11 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libgs9 amd64 9.26~dfsg+0-0ubuntu0.18.04.14 [2,265 kB]
# Get:12 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libkpathsea6 amd64 2017.20170613.44572-8ubuntu0.1 [54.9 kB]
# Get:13 http://archive.ubuntu.com/ubuntu bionic/main amd64 libpotrace0 amd64 1.14-2 [17.4 kB]
# Get:14 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libptexenc1 amd64 2017.20170613.44572-8ubuntu0.1 [34.5 kB]
# Get:15 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libsynctex1 amd64 2017.20170613.44572-8ubuntu0.1 [41.4 kB]
# Get:16 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libtexlua52 amd64 2017.20170613.44572-8ubuntu0.1 [91.2 kB]
# Get:17 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libtexluajit2 amd64 2017.20170613.44572-8ubuntu0.1 [230 kB]
# Get:18 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libzzip-0-13 amd64 0.13.62-3.1ubuntu0.18.04.1 [26.0 kB]
# Get:19 http://archive.ubuntu.com/ubuntu bionic/main amd64 lmodern all 2.004.5-3 [9,631 kB]
# Get:20 http://archive.ubuntu.com/ubuntu bionic/main amd64 t1utils amd64 1.41-2 [56.0 kB]
# Get:21 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 texlive-binaries amd64 2017.20170613.44572-8ubuntu0.1 [8,179 kB]
# Get:22 http://archive.ubuntu.com/ubuntu bionic/main amd64 texlive-base all 2017.20180305-1 [18.7 MB]
# Get:23 http://archive.ubuntu.com/ubuntu bionic/main amd64 texlive-latex-base all 2017.20180305-1 [951 kB]
# Get:24 http://archive.ubuntu.com/ubuntu bionic/main amd64 texlive-latex-recommended all 2017.20180305-1 [14.9 MB]
# Fetched 68.4 MB in 4s (19.0 MB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 24.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package fonts-droid-fallback.
# (Reading database ... 148486 files and directories currently installed.)
# Preparing to unpack .../00-fonts-droid-fallback_1%3a6.0.1r16-1.1_all.deb ...
# Unpacking fonts-droid-fallback (1:6.0.1r16-1.1) ...
# Selecting previously unselected package poppler-data.
# Preparing to unpack .../01-poppler-data_0.4.8-2_all.deb ...
# Unpacking poppler-data (0.4.8-2) ...
# Selecting previously unselected package tex-common.
# Preparing to unpack .../02-tex-common_6.09_all.deb ...
# Unpacking tex-common (6.09) ...
# Selecting previously unselected package fonts-lmodern.
# Preparing to unpack .../03-fonts-lmodern_2.004.5-3_all.deb ...
# Unpacking fonts-lmodern (2.004.5-3) ...
# Selecting previously unselected package fonts-noto-mono.
# Preparing to unpack .../04-fonts-noto-mono_20171026-2_all.deb ...
# Unpacking fonts-noto-mono (20171026-2) ...
# Selecting previously unselected package libcupsfilters1:amd64.
# Preparing to unpack .../05-libcupsfilters1_1.20.2-0ubuntu3.1_amd64.deb ...
# Unpacking libcupsfilters1:amd64 (1.20.2-0ubuntu3.1) ...
# Selecting previously unselected package libcupsimage2:amd64.
# Preparing to unpack .../06-libcupsimage2_2.2.7-1ubuntu2.8_amd64.deb ...
# Unpacking libcupsimage2:amd64 (2.2.7-1ubuntu2.8) ...
# Selecting previously unselected package libijs-0.35:amd64.
# Preparing to unpack .../07-libijs-0.35_0.35-13_amd64.deb ...
# Unpacking libijs-0.35:amd64 (0.35-13) ...
# Selecting previously unselected package libjbig2dec0:amd64.
# Preparing to unpack .../08-libjbig2dec0_0.13-6_amd64.deb ...
# Unpacking libjbig2dec0:amd64 (0.13-6) ...
# Selecting previously unselected package libgs9-common.
# Preparing to unpack .../09-libgs9-common_9.26~dfsg+0-0ubuntu0.18.04.14_all.deb ...
# Unpacking libgs9-common (9.26~dfsg+0-0ubuntu0.18.04.14) ...
# Selecting previously unselected package libgs9:amd64.
# Preparing to unpack .../10-libgs9_9.26~dfsg+0-0ubuntu0.18.04.14_amd64.deb ...
# Unpacking libgs9:amd64 (9.26~dfsg+0-0ubuntu0.18.04.14) ...
# Selecting previously unselected package libkpathsea6:amd64.
# Preparing to unpack .../11-libkpathsea6_2017.20170613.44572-8ubuntu0.1_amd64.deb ...
# Unpacking libkpathsea6:amd64 (2017.20170613.44572-8ubuntu0.1) ...
# Selecting previously unselected package libpotrace0.
# Preparing to unpack .../12-libpotrace0_1.14-2_amd64.deb ...
# Unpacking libpotrace0 (1.14-2) ...
# Selecting previously unselected package libptexenc1:amd64.
# Preparing to unpack .../13-libptexenc1_2017.20170613.44572-8ubuntu0.1_amd64.deb ...
# Unpacking libptexenc1:amd64 (2017.20170613.44572-8ubuntu0.1) ...
# Selecting previously unselected package libsynctex1:amd64.
# Preparing to unpack .../14-libsynctex1_2017.20170613.44572-8ubuntu0.1_amd64.deb ...
# Unpacking libsynctex1:amd64 (2017.20170613.44572-8ubuntu0.1) ...
# Selecting previously unselected package libtexlua52:amd64.
# Preparing to unpack .../15-libtexlua52_2017.20170613.44572-8ubuntu0.1_amd64.deb ...
# Unpacking libtexlua52:amd64 (2017.20170613.44572-8ubuntu0.1) ...
# Selecting previously unselected package libtexluajit2:amd64.
# Preparing to unpack .../16-libtexluajit2_2017.20170613.44572-8ubuntu0.1_amd64.deb ...
# Unpacking libtexluajit2:amd64 (2017.20170613.44572-8ubuntu0.1) ...
# Selecting previously unselected package libzzip-0-13:amd64.
# Preparing to unpack .../17-libzzip-0-13_0.13.62-3.1ubuntu0.18.04.1_amd64.deb ...
# Unpacking libzzip-0-13:amd64 (0.13.62-3.1ubuntu0.18.04.1) ...
# Selecting previously unselected package lmodern.
# Preparing to unpack .../18-lmodern_2.004.5-3_all.deb ...
# Unpacking lmodern (2.004.5-3) ...
# Selecting previously unselected package t1utils.
# Preparing to unpack .../19-t1utils_1.41-2_amd64.deb ...
# Unpacking t1utils (1.41-2) ...
# Selecting previously unselected package texlive-binaries.
# Preparing to unpack .../20-texlive-binaries_2017.20170613.44572-8ubuntu0.1_amd64.deb ...
# Unpacking texlive-binaries (2017.20170613.44572-8ubuntu0.1) ...
# Selecting previously unselected package texlive-base.
# Preparing to unpack .../21-texlive-base_2017.20180305-1_all.deb ...
# Unpacking texlive-base (2017.20180305-1) ...
# Selecting previously unselected package texlive-latex-base.
# Preparing to unpack .../22-texlive-latex-base_2017.20180305-1_all.deb ...
# Unpacking texlive-latex-base (2017.20180305-1) ...
# Selecting previously unselected package texlive-latex-recommended.
# Preparing to unpack .../23-texlive-latex-recommended_2017.20180305-1_all.deb ...
# Unpacking texlive-latex-recommended (2017.20180305-1) ...
# Setting up libgs9-common (9.26~dfsg+0-0ubuntu0.18.04.14) ...
# Setting up libkpathsea6:amd64 (2017.20170613.44572-8ubuntu0.1) ...
# Setting up libtexlua52:amd64 (2017.20170613.44572-8ubuntu0.1) ...
# Setting up fonts-droid-fallback (1:6.0.1r16-1.1) ...
# Setting up libsynctex1:amd64 (2017.20170613.44572-8ubuntu0.1) ...
# Setting up libptexenc1:amd64 (2017.20170613.44572-8ubuntu0.1) ...
# Setting up tex-common (6.09) ...
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76.)
# debconf: falling back to frontend: Readline
# update-language: texlive-base not installed and configured, doing nothing!
# Setting up poppler-data (0.4.8-2) ...
# Setting up fonts-noto-mono (20171026-2) ...
# Setting up libcupsfilters1:amd64 (1.20.2-0ubuntu3.1) ...
# Setting up libcupsimage2:amd64 (2.2.7-1ubuntu2.8) ...
# Setting up libjbig2dec0:amd64 (0.13-6) ...
# Setting up t1utils (1.41-2) ...
# Setting up libijs-0.35:amd64 (0.35-13) ...
# Setting up libpotrace0 (1.14-2) ...
# Setting up libzzip-0-13:amd64 (0.13.62-3.1ubuntu0.18.04.1) ...
# Setting up libgs9:amd64 (9.26~dfsg+0-0ubuntu0.18.04.14) ...
# Setting up libtexluajit2:amd64 (2017.20170613.44572-8ubuntu0.1) ...
# Setting up fonts-lmodern (2.004.5-3) ...
# Setting up texlive-binaries (2017.20170613.44572-8ubuntu0.1) ...
# update-alternatives: using /usr/bin/xdvi-xaw to provide /usr/bin/xdvi.bin (xdvi.bin) in auto mode
# update-alternatives: using /usr/bin/bibtex.original to provide /usr/bin/bibtex (bibtex) in auto mode
# Setting up texlive-base (2017.20180305-1) ...
# mktexlsr: Updating /var/lib/texmf/ls-R-TEXLIVEDIST...
# mktexlsr: Updating /var/lib/texmf/ls-R-TEXMFMAIN...
# mktexlsr: Updating /var/lib/texmf/ls-R...
# mktexlsr: Done.
# tl-paper: setting paper size for dvips to a4: /var/lib/texmf/dvips/config/config-paper.ps
# tl-paper: setting paper size for dvipdfmx to a4: /var/lib/texmf/dvipdfmx/dvipdfmx-paper.cfg
# tl-paper: setting paper size for xdvi to a4: /var/lib/texmf/xdvi/XDvi-paper
# tl-paper: setting paper size for pdftex to a4: /var/lib/texmf/tex/generic/config/pdftexconfig.tex
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76.)
# debconf: falling back to frontend: Readline
# Setting up texlive-latex-base (2017.20180305-1) ...
# Setting up lmodern (2.004.5-3) ...
# Setting up texlive-latex-recommended (2017.20180305-1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1.2) ...
# /sbin/ldconfig.real: /usr/local/lib/python3.7/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link
#
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Processing triggers for fontconfig (2.12.6-0ubuntu2) ...
# Processing triggers for mime-support (3.60ubuntu1) ...
# Processing triggers for tex-common (6.09) ...
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76.)
# debconf: falling back to frontend: Readline
# Running updmap-sys. This may take some time... done.
# Running mktexlsr /var/lib/texmf ... done.
# Building format(s) --all.
# 	This may take some time... done.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'sudo apt autoremove' to remove it.
# The following additional packages will be installed:
#   fonts-lato fonts-texgyre ghostscript gsfonts javascript-common libjs-jquery
#   libruby2.5 preview-latex-style rake ruby ruby-did-you-mean ruby-minitest
#   ruby-net-telnet ruby-power-assert ruby-test-unit ruby2.5
#   rubygems-integration tex-gyre texlive-pictures texlive-plain-generic tipa
# Suggested packages:
#   ghostscript-x apache2 | lighttpd | httpd ri ruby-dev bundler
#   texlive-fonts-recommended-doc python-pygments icc-profiles
#   libfile-which-perl libspreadsheet-parseexcel-perl texlive-latex-extra-doc
#   dot2tex prerex ruby-tcltk | libtcltk-ruby texlive-pictures-doc vprerex
# The following NEW packages will be installed:
#   dvipng fonts-lato fonts-texgyre ghostscript gsfonts javascript-common
#   libjs-jquery libruby2.5 preview-latex-style rake ruby ruby-did-you-mean
#   ruby-minitest ruby-net-telnet ruby-power-assert ruby-test-unit ruby2.5
#   rubygems-integration tex-gyre texlive-fonts-recommended texlive-latex-extra
#   texlive-pictures texlive-plain-generic tipa
# 0 upgraded, 24 newly installed, 0 to remove and 49 not upgraded.
# Need to get 69.8 MB of archives.
# After this operation, 221 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/main amd64 fonts-lato all 2.0-2 [2,698 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 ghostscript amd64 9.26~dfsg+0-0ubuntu0.18.04.14 [51.3 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic/universe amd64 dvipng amd64 1.15-1 [78.2 kB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic/universe amd64 fonts-texgyre all 20160520-1 [8,761 kB]
# Get:5 http://archive.ubuntu.com/ubuntu bionic/main amd64 gsfonts all 1:8.11+urwcyr1.0.7~pre44-4.4 [3,120 kB]
# Get:6 http://archive.ubuntu.com/ubuntu bionic/main amd64 javascript-common all 11 [6,066 B]
# Get:7 http://archive.ubuntu.com/ubuntu bionic/main amd64 libjs-jquery all 3.2.1-1 [152 kB]
# Get:8 http://archive.ubuntu.com/ubuntu bionic/main amd64 rubygems-integration all 1.11 [4,994 B]
# Get:9 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 ruby2.5 amd64 2.5.1-1ubuntu1.10 [48.6 kB]
# Get:10 http://archive.ubuntu.com/ubuntu bionic/main amd64 ruby amd64 1:2.5.1 [5,712 B]
# Get:11 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 rake all 12.3.1-1ubuntu0.1 [44.9 kB]
# Get:12 http://archive.ubuntu.com/ubuntu bionic/main amd64 ruby-did-you-mean all 1.2.0-2 [9,700 B]
# Get:13 http://archive.ubuntu.com/ubuntu bionic/main amd64 ruby-minitest all 5.10.3-1 [38.6 kB]
# Get:14 http://archive.ubuntu.com/ubuntu bionic/main amd64 ruby-net-telnet all 0.1.1-2 [12.6 kB]
# Get:15 http://archive.ubuntu.com/ubuntu bionic/main amd64 ruby-power-assert all 0.3.0-1 [7,952 B]
# Get:16 http://archive.ubuntu.com/ubuntu bionic/main amd64 ruby-test-unit all 3.2.5-1 [61.1 kB]
# Get:17 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libruby2.5 amd64 2.5.1-1ubuntu1.10 [3,071 kB]
# Get:18 http://archive.ubuntu.com/ubuntu bionic/main amd64 preview-latex-style all 11.91-1ubuntu1 [185 kB]
# Get:19 http://archive.ubuntu.com/ubuntu bionic/universe amd64 tex-gyre all 20160520-1 [4,998 kB]
# Get:20 http://archive.ubuntu.com/ubuntu bionic/universe amd64 texlive-fonts-recommended all 2017.20180305-1 [5,262 kB]
# Get:21 http://archive.ubuntu.com/ubuntu bionic/universe amd64 texlive-pictures all 2017.20180305-1 [4,026 kB]
# Get:22 http://archive.ubuntu.com/ubuntu bionic/universe amd64 texlive-latex-extra all 2017.20180305-2 [10.6 MB]
# Get:23 http://archive.ubuntu.com/ubuntu bionic/universe amd64 texlive-plain-generic all 2017.20180305-2 [23.6 MB]
# Get:24 http://archive.ubuntu.com/ubuntu bionic/universe amd64 tipa all 2:1.3-20 [2,978 kB]
# Fetched 69.8 MB in 6s (12.6 MB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 24.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package fonts-lato.
# (Reading database ... 155820 files and directories currently installed.)
# Preparing to unpack .../00-fonts-lato_2.0-2_all.deb ...
# Unpacking fonts-lato (2.0-2) ...
# Selecting previously unselected package ghostscript.
# Preparing to unpack .../01-ghostscript_9.26~dfsg+0-0ubuntu0.18.04.14_amd64.deb ...
# Unpacking ghostscript (9.26~dfsg+0-0ubuntu0.18.04.14) ...
# Selecting previously unselected package dvipng.
# Preparing to unpack .../02-dvipng_1.15-1_amd64.deb ...
# Unpacking dvipng (1.15-1) ...
# Selecting previously unselected package fonts-texgyre.
# Preparing to unpack .../03-fonts-texgyre_20160520-1_all.deb ...
# Unpacking fonts-texgyre (20160520-1) ...
# Selecting previously unselected package gsfonts.
# Preparing to unpack .../04-gsfonts_1%3a8.11+urwcyr1.0.7~pre44-4.4_all.deb ...
# Unpacking gsfonts (1:8.11+urwcyr1.0.7~pre44-4.4) ...
# Selecting previously unselected package javascript-common.
# Preparing to unpack .../05-javascript-common_11_all.deb ...
# Unpacking javascript-common (11) ...
# Selecting previously unselected package libjs-jquery.
# Preparing to unpack .../06-libjs-jquery_3.2.1-1_all.deb ...
# Unpacking libjs-jquery (3.2.1-1) ...
# Selecting previously unselected package rubygems-integration.
# Preparing to unpack .../07-rubygems-integration_1.11_all.deb ...
# Unpacking rubygems-integration (1.11) ...
# Selecting previously unselected package ruby2.5.
# Preparing to unpack .../08-ruby2.5_2.5.1-1ubuntu1.10_amd64.deb ...
# Unpacking ruby2.5 (2.5.1-1ubuntu1.10) ...
# Selecting previously unselected package ruby.
# Preparing to unpack .../09-ruby_1%3a2.5.1_amd64.deb ...
# Unpacking ruby (1:2.5.1) ...
# Selecting previously unselected package rake.
# Preparing to unpack .../10-rake_12.3.1-1ubuntu0.1_all.deb ...
# Unpacking rake (12.3.1-1ubuntu0.1) ...
# Selecting previously unselected package ruby-did-you-mean.
# Preparing to unpack .../11-ruby-did-you-mean_1.2.0-2_all.deb ...
# Unpacking ruby-did-you-mean (1.2.0-2) ...
# Selecting previously unselected package ruby-minitest.
# Preparing to unpack .../12-ruby-minitest_5.10.3-1_all.deb ...
# Unpacking ruby-minitest (5.10.3-1) ...
# Selecting previously unselected package ruby-net-telnet.
# Preparing to unpack .../13-ruby-net-telnet_0.1.1-2_all.deb ...
# Unpacking ruby-net-telnet (0.1.1-2) ...
# Selecting previously unselected package ruby-power-assert.
# Preparing to unpack .../14-ruby-power-assert_0.3.0-1_all.deb ...
# Unpacking ruby-power-assert (0.3.0-1) ...
# Selecting previously unselected package ruby-test-unit.
# Preparing to unpack .../15-ruby-test-unit_3.2.5-1_all.deb ...
# Unpacking ruby-test-unit (3.2.5-1) ...
# Selecting previously unselected package libruby2.5:amd64.
# Preparing to unpack .../16-libruby2.5_2.5.1-1ubuntu1.10_amd64.deb ...
# Unpacking libruby2.5:amd64 (2.5.1-1ubuntu1.10) ...
# Selecting previously unselected package preview-latex-style.
# Preparing to unpack .../17-preview-latex-style_11.91-1ubuntu1_all.deb ...
# Unpacking preview-latex-style (11.91-1ubuntu1) ...
# Selecting previously unselected package tex-gyre.
# Preparing to unpack .../18-tex-gyre_20160520-1_all.deb ...
# Unpacking tex-gyre (20160520-1) ...
# Selecting previously unselected package texlive-fonts-recommended.
# Preparing to unpack .../19-texlive-fonts-recommended_2017.20180305-1_all.deb ...
# Unpacking texlive-fonts-recommended (2017.20180305-1) ...
# Selecting previously unselected package texlive-pictures.
# Preparing to unpack .../20-texlive-pictures_2017.20180305-1_all.deb ...
# Unpacking texlive-pictures (2017.20180305-1) ...
# Selecting previously unselected package texlive-latex-extra.
# Preparing to unpack .../21-texlive-latex-extra_2017.20180305-2_all.deb ...
# Unpacking texlive-latex-extra (2017.20180305-2) ...
# Selecting previously unselected package texlive-plain-generic.
# Preparing to unpack .../22-texlive-plain-generic_2017.20180305-2_all.deb ...
# Unpacking texlive-plain-generic (2017.20180305-2) ...
# Selecting previously unselected package tipa.
# Preparing to unpack .../23-tipa_2%3a1.3-20_all.deb ...
# Unpacking tipa (2:1.3-20) ...
# Setting up libjs-jquery (3.2.1-1) ...
# Setting up gsfonts (1:8.11+urwcyr1.0.7~pre44-4.4) ...
# Setting up texlive-pictures (2017.20180305-1) ...
# Setting up tex-gyre (20160520-1) ...
# Setting up tipa (2:1.3-20) ...
# Regenerating '/var/lib/texmf/fmtutil.cnf-DEBIAN'... done.
# Regenerating '/var/lib/texmf/fmtutil.cnf-TEXLIVEDIST'... done.
# update-fmtutil has updated the following file(s):
# 	/var/lib/texmf/fmtutil.cnf-DEBIAN
# 	/var/lib/texmf/fmtutil.cnf-TEXLIVEDIST
# If you want to activate the changes in the above file(s),
# you should run fmtutil-sys or fmtutil.
# Setting up preview-latex-style (11.91-1ubuntu1) ...
# Setting up ghostscript (9.26~dfsg+0-0ubuntu0.18.04.14) ...
# Setting up fonts-texgyre (20160520-1) ...
# Setting up fonts-lato (2.0-2) ...
# Setting up ruby-did-you-mean (1.2.0-2) ...
# Setting up ruby-net-telnet (0.1.1-2) ...
# Setting up rubygems-integration (1.11) ...
# Setting up javascript-common (11) ...
# Setting up texlive-fonts-recommended (2017.20180305-1) ...
# Setting up texlive-plain-generic (2017.20180305-2) ...
# Setting up ruby-minitest (5.10.3-1) ...
# Setting up ruby-power-assert (0.3.0-1) ...
# Setting up texlive-latex-extra (2017.20180305-2) ...
# Setting up dvipng (1.15-1) ...
# Setting up rake (12.3.1-1ubuntu0.1) ...
# Setting up ruby2.5 (2.5.1-1ubuntu1.10) ...
# Setting up ruby (1:2.5.1) ...
# Setting up ruby-test-unit (3.2.5-1) ...
# Setting up libruby2.5:amd64 (2.5.1-1ubuntu1.10) ...
# Processing triggers for tex-common (6.09) ...
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76.)
# debconf: falling back to frontend: Readline
# Running mktexlsr. This may take some time... done.
# Running updmap-sys. This may take some time... done.
# Running mktexlsr /var/lib/texmf ... done.
# Processing triggers for libc-bin (2.27-3ubuntu1.2) ...
# /sbin/ldconfig.real: /usr/local/lib/python3.7/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link
#
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Processing triggers for fontconfig (2.12.6-0ubuntu2) ...
# --2021-08-17 17:34:04--  http://mirrors.ctan.org/macros/latex/contrib/type1cm.zip
# Resolving mirrors.ctan.org (mirrors.ctan.org)... 5.35.249.60
# Connecting to mirrors.ctan.org (mirrors.ctan.org)|5.35.249.60|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ctan.math.illinois.edu/macros/latex/contrib/type1cm.zip [following]
# --2021-08-17 17:34:04--  https://ctan.math.illinois.edu/macros/latex/contrib/type1cm.zip
# Resolving ctan.math.illinois.edu (ctan.math.illinois.edu)... 192.17.3.223
# Connecting to ctan.math.illinois.edu (ctan.math.illinois.edu)|192.17.3.223|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 328566 (321K) [application/zip]
# Saving to: ‘type1cm.zip’
#
# type1cm.zip         100%[===================>] 320.87K  --.-KB/s    in 0.06s
#
# 2021-08-17 17:34:04 (5.69 MB/s) - ‘type1cm.zip’ saved [328566/328566]
#
# Archive:  type1cm.zip
#    creating: /tmp/type1cm/type1cm/
#   inflating: /tmp/type1cm/type1cm/type1cm.fdd
#   inflating: /tmp/type1cm/type1cm/type1cm.ins
#   inflating: /tmp/type1cm/type1cm/type1cm.txt
#   inflating: /tmp/type1cm/type1cm/type1cm-doc.pdf
#   inflating: /tmp/type1cm/type1cm/type1cm-doc.tex
# This is pdfTeX, Version 3.14159265-2.6-1.40.18 (TeX Live 2017/Debian) (preloaded format=latex)
#  restricted \write18 enabled.
# entering extended mode
# (./type1cm.ins
# LaTeX2e <2017-04-15>
# Babel <3.18> and hyphenation patterns for 3 language(s) loaded.
# (/usr/share/texlive/texmf-dist/tex/latex/base/docstrip.tex
# Utility: `docstrip' 2.5e <2014/09/29>
# English documentation    <2017/03/13>
#
# **********************************************************
# * This program converts documented macro-files into fast *
# * loadable files by stripping off (nearly) all comments! *
# **********************************************************
#
# ********************************************************
# * No Configuration file found, using default settings. *
# ********************************************************
#
# (./type1cm.ins
#
# Generating file(s) ./type1cm.sty
#
# Processing file type1cm.fdd (package,ams) -> type1cm.sty
# Lines  processed: 410
# Comments removed: 25
# Comments  passed: 7
# Codelines passed: 263
#
# ) ) )
# No pages of output.
# Transcript written on type1cm.log.
# texhash: Updating /usr/local/share/texmf/ls-R...
# texhash: Updating /var/lib/texmf/ls-R-TEXLIVEDIST...
# texhash: Updating /var/lib/texmf/ls-R-TEXMFMAIN...
# texhash: Updating /var/lib/texmf/ls-R...
# texhash: Done.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# The following additional packages will be installed:
#   cm-super-minimal pfb2t1c2pfb
# The following NEW packages will be installed:
#   cm-super cm-super-minimal pfb2t1c2pfb
# 0 upgraded, 3 newly installed, 0 to remove and 49 not upgraded.
# Need to get 24.5 MB of archives.
# After this operation, 59.9 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 cm-super-minimal all 0.3.4-11 [5,810 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/universe amd64 pfb2t1c2pfb amd64 0.3-11 [9,342 B]
# Get:3 http://archive.ubuntu.com/ubuntu bionic/universe amd64 cm-super all 0.3.4-11 [18.7 MB]
# Fetched 24.5 MB in 2s (12.7 MB/s)
# Selecting previously unselected package cm-super-minimal.
# (Reading database ... 174364 files and directories currently installed.)
# Preparing to unpack .../cm-super-minimal_0.3.4-11_all.deb ...
# Unpacking cm-super-minimal (0.3.4-11) ...
# Selecting previously unselected package pfb2t1c2pfb.
# Preparing to unpack .../pfb2t1c2pfb_0.3-11_amd64.deb ...
# Unpacking pfb2t1c2pfb (0.3-11) ...
# Selecting previously unselected package cm-super.
# Preparing to unpack .../cm-super_0.3.4-11_all.deb ...
# Unpacking cm-super (0.3.4-11) ...
# Setting up pfb2t1c2pfb (0.3-11) ...
# Setting up cm-super-minimal (0.3.4-11) ...
# Setting up cm-super (0.3.4-11) ...
# Creating fonts. This may take some time... done.
# Processing triggers for fontconfig (2.12.6-0ubuntu2) ...
# Processing triggers for tex-common (6.09) ...
# Running mktexlsr. This may take some time... done.
# Running updmap-sys. This may take some time... done.
# Running mktexlsr /var/lib/texmf ... done.
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Collecting latex
#   Downloading latex-0.7.0.tar.gz (6.5 kB)
# Collecting tempdir
#   Downloading tempdir-0.7.1.tar.gz (5.9 kB)
# Collecting data
#   Downloading data-0.4.tar.gz (7.0 kB)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from latex) (0.16.0)
# Collecting shutilwhich
#   Downloading shutilwhich-1.1.0.tar.gz (2.3 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from data->latex) (1.15.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.7/dist-packages (from data->latex) (4.4.2)
# Collecting funcsigs
#   Downloading funcsigs-1.0.2-py2.py3-none-any.whl (17 kB)
# Building wheels for collected packages: latex, data, shutilwhich, tempdir
#   Building wheel for latex (setup.py) ... done
#   Created wheel for latex: filename=latex-0.7.0-py3-none-any.whl size=7606 sha256=bf5aa6bc3eab39455f49a0590e213f176739afc2d56166cd4861abae607616a3
#   Stored in directory: /root/.cache/pip/wheels/57/d6/11/5d5718227890d9e479b6137cb406410c37a0b84b2ab35b872b
#   Building wheel for data (setup.py) ... done
#   Created wheel for data: filename=data-0.4-py3-none-any.whl size=7245 sha256=63cd3c8e43cc688687fcde4a228302423ad6a3847e1d8f8bad466a6a41c7ca47
#   Stored in directory: /root/.cache/pip/wheels/28/76/4b/7db27e02c1de4d2181559d108fcdfed1680ff7d3534553d460
#   Building wheel for shutilwhich (setup.py) ... done
#   Created wheel for shutilwhich: filename=shutilwhich-1.1.0-py3-none-any.whl size=2782 sha256=833fdd5b9a997a7e7229ebec6543f7960487144b63792e9f136d128488dc59a2
#   Stored in directory: /root/.cache/pip/wheels/4c/c0/ce/5a47f35186acbe73e38811df30daaf798c81a7599bb2d5995a
#   Building wheel for tempdir (setup.py) ... done
#   Created wheel for tempdir: filename=tempdir-0.7.1-py3-none-any.whl size=2213 sha256=1d9d034dc3542b0220f6de9ff23a770c673e25933d08c44a7a4a57af11393ff9
#   Stored in directory: /root/.cache/pip/wheels/7a/f1/d7/124b54c21a9ba4973bc60fcda6cdc264271f3c4d607be0486d
# Successfully built latex data shutilwhich tempdir
# Installing collected packages: funcsigs, tempdir, shutilwhich, data, latex
# Successfully installed data-0.4 funcsigs-1.0.2 latex-0.7.0 shutilwhich-1.1.0 tempdir-0.7.1
# Collecting uproot
#   Downloading uproot-4.0.11-py2.py3-none-any.whl (245 kB)
#      |████████████████████████████████| 245 kB 36.5 MB/s
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from uproot) (57.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from uproot) (1.19.5)
# Installing collected packages: uproot
# Successfully installed uproot-4.0.11

# %%
from __future__ import absolute_import, division, print_function

import numpy as np
import uproot
from matplotlib import pyplot as plt

from sklearn.model_selection import train_test_split

import tensorflow as tf
from keras.layers import Dense, Input
from keras.models import Model
from keras.callbacks import EarlyStopping

# %%
# Define default plot styles  

from matplotlib import rc
import matplotlib.font_manager

rc('font', family='serif')
rc('text', usetex=True)
rc('font', size=22)
rc('xtick', labelsize=15)
rc('ytick', labelsize=15)
rc('legend', fontsize=15)

plot_style_0 = {
    'histtype': 'step',
    'color': 'black',
    'linewidth': 2,
    'linestyle': '--',
    'density': False
}

plot_style_1 = {
    'histtype': 'step',
    'color': 'black',
    'linewidth': 2,
    'density': False
}

plot_style_2 = {'alpha': 0.5, 'density': False}

# %%
# Check Versions
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.6.0

# %% [markdown]
# OmniFold Gaussian Toy Example Setup the Datasets

# %%
! git clone https://github.com/kmtsui/SummerProject2021

def getarray(filename):
    f = uproot.open(filename)
    t = f["selectedEvents"]
    array = np.transpose(np.asarray(t.arrays(["dptt_rec", "weight", "topology", "cutBranch"], library="np", how=tuple)))
    return array
# Out:
# Cloning into 'SummerProject2021'...
# remote: Enumerating objects: 26, done.
# remote: Counting objects: 100% (26/26), done.
# remote: Compressing objects: 100% (26/26), done.
# remote: Total 26 (delta 7), reused 4 (delta 0), pack-reused 0
# Unpacking objects: 100% (26/26), done.

# %%
neut_array_dptt = getarray("SummerProject2021/neut_flattree.root")
genie_array_dptt = getarray("SummerProject2021/genie_flattree.root")

cutbranch_zero_neut = neut_array_dptt[neut_array_dptt[:,3]==0] 
cb0_neut_topology2 = cutbranch_zero_neut[cutbranch_zero_neut[:,2]==2][:,0]           # Specify the topology: For cutBranch = 0, topology = 2 is selected
cb0_neut_topology3 = cutbranch_zero_neut[cutbranch_zero_neut[:,2]==3][:,0]
synthetic_signal = np.concatenate([cb0_neut_topology2,cb0_neut_topology3])
#print(len(cb0_neut_topology2))
#print(len(cb0_neut_topology3))
#print(len(synthetic_signal))

cutbranch_zero_genie = genie_array_dptt[genie_array_dptt[:,3]==0] 
cb0_genie_topology2 = cutbranch_zero_genie[cutbranch_zero_genie[:,2]==2][:,0]           # Specify the topology: For cutBranch = 0, topology = 2 is selected
cb0_genie_topology3 = cutbranch_zero_genie[cutbranch_zero_genie[:,2]==3][:,0]
natural_signal = np.concatenate([cb0_genie_topology2,cb0_genie_topology3])

# %%
# Defining the background for the synthetic and natural samples

# Synthetic
cb0_neut_topology0 = cutbranch_zero_neut[cutbranch_zero_neut[:,2]==0][:,0] 
cb0_neut_topology1 = cutbranch_zero_neut[cutbranch_zero_neut[:,2]==1][:,0] 
cb0_neut_topology2 = cutbranch_zero_neut[cutbranch_zero_neut[:,2]==2][:,0]           # Specify the topology: For cutBranch = 0, topology = 2 is selected
cb0_neut_topology3 = cutbranch_zero_neut[cutbranch_zero_neut[:,2]==3][:,0] 
cb0_neut_topology4 = cutbranch_zero_neut[cutbranch_zero_neut[:,2]==4][:,0] 
cb0_neut_topology5 = cutbranch_zero_neut[cutbranch_zero_neut[:,2]==5][:,0] 
cb0_neut_topology6 = cutbranch_zero_neut[cutbranch_zero_neut[:,2]==6][:,0] 
cb0_neut_topology7 = cutbranch_zero_neut[cutbranch_zero_neut[:,2]==7][:,0] 
cb0_neut_topology8 = cutbranch_zero_neut[cutbranch_zero_neut[:,2]==8][:,0] 
cb0_neut_topology9 = cutbranch_zero_neut[cutbranch_zero_neut[:,2]==9][:,0] 
cb0_neut_topology10 = cutbranch_zero_neut[cutbranch_zero_neut[:,2]==10][:,0] 
cb0_neut_topology11 = cutbranch_zero_neut[cutbranch_zero_neut[:,2]==11][:,0] 
synthetic_background = np.concatenate([cb0_neut_topology0,cb0_neut_topology1,cb0_neut_topology4,cb0_neut_topology5,cb0_neut_topology6,cb0_neut_topology7,cb0_neut_topology8,cb0_neut_topology9,cb0_neut_topology10,cb0_neut_topology11])


# Natural
cb0_genie_topology0 = cutbranch_zero_genie[cutbranch_zero_genie[:,2]==0][:,0] 
cb0_genie_topology1 = cutbranch_zero_genie[cutbranch_zero_genie[:,2]==1][:,0] 
cb0_genie_topology2 = cutbranch_zero_genie[cutbranch_zero_genie[:,2]==2][:,0]           # Specify the topology: For cutBranch = 0, topology = 2 is selected
cb0_genie_topology3 = cutbranch_zero_genie[cutbranch_zero_genie[:,2]==3][:,0] 
cb0_genie_topology4 = cutbranch_zero_genie[cutbranch_zero_genie[:,2]==4][:,0] 
cb0_genie_topology5 = cutbranch_zero_genie[cutbranch_zero_genie[:,2]==5][:,0] 
cb0_genie_topology6 = cutbranch_zero_genie[cutbranch_zero_genie[:,2]==6][:,0] 
cb0_genie_topology7 = cutbranch_zero_genie[cutbranch_zero_genie[:,2]==7][:,0] 
cb0_genie_topology8 = cutbranch_zero_genie[cutbranch_zero_genie[:,2]==8][:,0] 
cb0_genie_topology9 = cutbranch_zero_genie[cutbranch_zero_genie[:,2]==9][:,0] 
cb0_genie_topology10 = cutbranch_zero_genie[cutbranch_zero_genie[:,2]==10][:,0] 
cb0_genie_topology11 = cutbranch_zero_genie[cutbranch_zero_genie[:,2]==11][:,0] 
natural_background = np.concatenate([cb0_genie_topology0,cb0_genie_topology1,cb0_genie_topology4,cb0_genie_topology5,cb0_genie_topology6,cb0_genie_topology7,cb0_genie_topology8,cb0_genie_topology9,cb0_genie_topology10,cb0_genie_topology11])


#print(len(synthetic_background))
#print(len(natural_background))

# %%
N = 10**5
# param = (mu, sigma)
epsilon = 0.5  # Smearing width

dummyval = -10 #a value for examples that don't pass one of the measured/ideal selections


#Synthetic
theta0_G = np.random.multivariate_normal(theta0_param[0], theta0_param[1],N)  # Generator-level synthetic sample
theta0_S = np.array([(x + np.random.normal(0, epsilon)) for x in theta0_G])  # Detector smearing for synthetic sample
pass_reco = np.random.binomial(1,1.-eff,len(theta0_G)) # truth events that do not pass reco
pass_truth = np.random.binomial(1,1.-fake,len(theta0_G)) # reco events that are not true
theta0_S[pass_reco==0] = dummyval
theta0_G[pass_truth==0] = dummyval

theta0_background = np.random.multivariate_normal(background_param[0],background_param[1], int(N*back))
theta0_S_withback = np.concatenate([theta0_S,theta0_background])
theta0_G_withback = np.concatenate([theta0_G,-np.ones((int(N*back),2))*dummyval])

theta0 = np.stack([theta0_G, theta0_S], axis=1)
labels0 = np.zeros(len(theta0))


#Natural
theta_unknown_G = np.random.multivariate_normal(theta_unknown_param[0],theta_unknown_param[1], N)
theta_unknown_S = np.array([(x + np.random.normal(0, epsilon)) for x in theta_unknown_G]) 
pass_reco = np.random.binomial(1,1.-eff,len(theta_unknown_G))
pass_truth = np.random.binomial(1,1.-fake,len(theta_unknown_G))
theta_unknown_S[pass_reco==0] = dummyval
theta_unknown_G[pass_truth==0] = dummyval

theta_background = np.random.multivariate_normal(background_param[0],background_param[1], int(N*back))
theta_unknown_S_withback = np.concatenate([theta_unknown_S,theta_background])
theta_unknown_G_withback = np.concatenate([theta_unknown_G,-np.ones((int(N*back),2))*dummyval])

theta_unknown = np.stack([theta_unknown_G, theta_unknown_S], axis=1)
labels_unknown = np.ones(len(theta_unknown))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:26: RuntimeWarning: covariance is not positive-semidefinite.

# %%
bins = np.linspace(-11, 11, 41)

fig, ax = plt.subplots(3,
                       2,
                       figsize=(12, 15),
                       #constrained_layout=True,
                       sharey='row')

# plot the x1 and x2 variables
for i in range(2):
        ax[i,0].set_xlabel('$x$'+str(i+1))
        ax[i,0].set_ylabel('Events per bin')
        ax[i,0].hist(theta0_G[theta0_G[:,i]!=dummyval][:,i], bins=bins, **plot_style_2, label='Generation') # This is the MC truth distribution
        ax[i,0].hist(theta0_S_withback[theta0_S_withback[:,i]!=dummyval][:,i], bins=bins, **plot_style_2, label='Simulation') # MC reco distribution with background
        ax[i,0].hist(theta0_S_withback[theta0_G_withback[:,i]==-dummyval][:,i], bins=bins, color="darkorange", label='Background') # MC background prediction
        legend = ax[i,0].legend(
            title='Synthetic\n($\mu$, $\sigma$) = {}'.format(theta0_param),
            loc='upper left',
            frameon=False)
        plt.setp(legend.get_title(), multialignment='center')

        ax[i,1].set_xlabel('$x2$')
        ax[i,1].hist(theta_unknown_G[theta_unknown_G[:,i]!=dummyval][:,i], bins=bins, **plot_style_2, label='Truth',color="green") # Real data truth distribution
        ax[i,1].hist(theta_unknown_S_withback[theta_unknown_S_withback[:,i]!=dummyval][:,i], bins=bins, **plot_style_2, label='Data',color="black") # Real data reco distribution with background
        ax[i,1].hist(theta_unknown_S_withback[theta_unknown_G_withback[:,i]==-dummyval][:,i], bins=bins, label='Background',color="black") # Real data background
        legend = ax[i,1].legend(
            title='Natural\n($\mu$, $\sigma$) = {}'.format(theta_unknown_param),
            loc='upper left',
            frameon=False)
        plt.setp(legend.get_title(), multialignment='center')

ax[2,0].set_xlabel('$x1$')
ax[2,0].set_ylabel('$x2$')
h1 = ax[2,0].hist2d(theta0_G[theta0_G[:,0]!=dummyval][:,0], theta0_G[theta0_G[:,1]!=dummyval][:,1] , bins=(bins,bins),label='Generation')
fig.colorbar(h1[3],ax=ax[2,0])
legend = ax[2,0].legend(
    title='Synthetic\n($\mu$, $\sigma$) = {}'.format(theta0_param),
    loc='upper left',
    frameon=False)
plt.setp(legend.get_title(), multialignment='center')

ax[2,1].set_xlabel('$x1$')
ax[2,1].set_ylabel('$x2$')
theta0_S_withback_plot1=theta_unknown_S_withback[:,1]
h2 = ax[2,1].hist2d(theta_unknown_G[theta_unknown_G[:,0]!=dummyval][:,0], theta_unknown_G[theta_unknown_G[:,1]!=dummyval][:,1] , bins=(bins,bins),label='Truth')
fig.colorbar(h2[3],ax=ax[2,1])
legend = ax[2,1].legend(
    title='Natural\n($\mu$, $\sigma$) = {}'.format(theta_unknown_param),
    loc='upper left',
    frameon=False)
plt.setp(legend.get_title(), multialignment='center')

fig.tight_layout()

fig.show()
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %% [markdown]
# Unfold Data

# %%
iterations = 4

# %%
xvals_1 = np.concatenate((theta0_S, theta_unknown_S))
yvals_1 = np.concatenate((labels0, labels_unknown))

xvals_2 = np.concatenate((theta0_G, theta0_G))
yvals_2 = np.concatenate((labels0, labels_unknown))

weights = np.empty(shape=(iterations, 2, len(theta0)))
# shape = (iteration, step, event)

inputs = Input((2, ))
hidden_layer_1 = Dense(50, activation='relu')(inputs)
hidden_layer_2 = Dense(50, activation='relu')(hidden_layer_1)
hidden_layer_3 = Dense(50, activation='relu')(hidden_layer_2)
outputs = Dense(1, activation='sigmoid')(hidden_layer_3)

model = Model(inputs=inputs, outputs=outputs)

earlystopping = EarlyStopping(patience=10,
                              verbose=1,
                              restore_best_weights=True)

# %%
# from NN (DCTR)
def reweight(events):
    f = model.predict(events, batch_size=10000)
    weights = f / (1. - f)
    return np.squeeze(np.nan_to_num(weights))

# %%
#We can do the background subtraction as part of the iterative unfolding, but it is easier to do it first.

x_data_and_MCback = np.concatenate([theta0_S_withback[theta0_G_withback[:,0]==-dummyval],
                                    theta_unknown_S_withback[theta_unknown_S_withback[:,0]!=dummyval],
                                    theta_unknown_S_withback[theta_unknown_S_withback[:,0]!=dummyval]])
    
y_data_and_MCback = np.concatenate([np.ones(len(theta0_S_withback[theta0_G_withback[:,0]==-dummyval])),
                                    np.ones(len(theta_unknown_S_withback[theta_unknown_S_withback[:,0]!=dummyval])),
                                    np.zeros(len(theta_unknown_S_withback[theta_unknown_S_withback[:,0]!=dummyval]))])

W_data_and_MCback = np.concatenate([-1.*np.ones(len(theta0_S_withback[theta0_G_withback[:,0]==-dummyval])),
                                    np.ones(len(theta_unknown_S_withback[theta_unknown_S_withback[:,0]!=dummyval])),
                                    np.ones(len(theta_unknown_S_withback[theta_unknown_S_withback[:,0]!=dummyval]))])

X_train_1, X_test_1, Y_train_1, Y_test_1, w_train_1, w_test_1 = train_test_split(
    x_data_and_MCback, y_data_and_MCback, W_data_and_MCback)

    
model.compile(loss='binary_crossentropy',
              optimizer='Adam',
              metrics=['accuracy'])
model.fit(X_train_1,
          Y_train_1,
          sample_weight=w_train_1,
          epochs=200,
          batch_size=10000,
          validation_data=(X_test_1, Y_test_1, w_test_1),
          callbacks=[earlystopping],
          verbose=1)
# Out:
# Epoch 1/200
# 16/16 [==============================] - 21s 427ms/step - loss: 0.6701 - accuracy: 0.4971 - val_loss: 0.6234 - val_accuracy: 0.4781
# Epoch 2/200
# 16/16 [==============================] - 0s 24ms/step - loss: 0.6252 - accuracy: 0.4776 - val_loss: 0.6196 - val_accuracy: 0.4746
# Epoch 3/200
# 16/16 [==============================] - 0s 23ms/step - loss: 0.6208 - accuracy: 0.4748 - val_loss: 0.6127 - val_accuracy: 0.4766
# Epoch 4/200
# 16/16 [==============================] - 0s 24ms/step - loss: 0.6141 - accuracy: 0.4746 - val_loss: 0.6066 - val_accuracy: 0.4776
# Epoch 5/200
# 16/16 [==============================] - 0s 23ms/step - loss: 0.6077 - accuracy: 0.4763 - val_loss: 0.6021 - val_accuracy: 0.4776
# Epoch 6/200
# 16/16 [==============================] - 0s 24ms/step - loss: 0.6049 - accuracy: 0.4751 - val_loss: 0.5993 - val_accuracy: 0.4780
# Epoch 7/200
# 16/16 [==============================] - 0s 24ms/step - loss: 0.6021 - accuracy: 0.4749 - val_loss: 0.5974 - val_accuracy: 0.4779
# Epoch 8/200
# 16/16 [==============================] - 0s 23ms/step - loss: 0.6035 - accuracy: 0.4760 - val_loss: 0.5965 - val_accuracy: 0.4776
# Epoch 9/200
# 16/16 [==============================] - 0s 24ms/step - loss: 0.6028 - accuracy: 0.4766 - val_loss: 0.5958 - val_accuracy: 0.4749
# Epoch 10/200
# 16/16 [==============================] - 0s 24ms/step - loss: 0.6033 - accuracy: 0.4753 - val_loss: 0.5953 - val_accuracy: 0.4749
# Epoch 11/200
# 16/16 [==============================] - 0s 23ms/step - loss: 0.6031 - accuracy: 0.4785 - val_loss: 0.5953 - val_accuracy: 0.4748
# Epoch 12/200
# 16/16 [==============================] - 0s 25ms/step - loss: 0.6033 - accuracy: 0.4752 - val_loss: 0.5949 - val_accuracy: 0.4743
# Epoch 13/200
# 16/16 [==============================] - 0s 24ms/step - loss: 0.6012 - accuracy: 0.4767 - val_loss: 0.5946 - val_accuracy: 0.4747
# Epoch 14/200
# 16/16 [==============================] - 0s 23ms/step - loss: 0.6049 - accuracy: 0.4750 - val_loss: 0.5944 - val_accuracy: 0.4746
# Epoch 15/200
# 16/16 [==============================] - 0s 24ms/step - loss: 0.5954 - accuracy: 0.4774 - val_loss: 0.5940 - val_accuracy: 0.4749
# Epoch 16/200
# 16/16 [==============================] - 0s 25ms/step - loss: 0.5989 - accuracy: 0.4780 - val_loss: 0.5942 - val_accuracy: 0.4757
# Epoch 17/200
# 16/16 [==============================] - 0s 24ms/step - loss: 0.6010 - accuracy: 0.4748 - val_loss: 0.5941 - val_accuracy: 0.4766
# Epoch 18/200
# 16/16 [==============================] - 0s 23ms/step - loss: 0.5993 - accuracy: 0.4775 - val_loss: 0.5939 - val_accuracy: 0.4771
# Epoch 19/200
# 16/16 [==============================] - 0s 25ms/step - loss: 0.6023 - accuracy: 0.4787 - val_loss: 0.5938 - val_accuracy: 0.4752
# Epoch 20/200
# 16/16 [==============================] - 0s 23ms/step - loss: 0.5966 - accuracy: 0.4755 - val_loss: 0.5934 - val_accuracy: 0.4740
# Epoch 21/200
# 16/16 [==============================] - 0s 23ms/step - loss: 0.5955 - accuracy: 0.4748 - val_loss: 0.5935 - val_accuracy: 0.4754
# Epoch 22/200
# 16/16 [==============================] - 0s 24ms/step - loss: 0.5981 - accuracy: 0.4758 - val_loss: 0.5935 - val_accuracy: 0.4763
# Epoch 23/200
# 16/16 [==============================] - 0s 24ms/step - loss: 0.5992 - accuracy: 0.4755 - val_loss: 0.5935 - val_accuracy: 0.4714
# Epoch 24/200
# 16/16 [==============================] - 0s 23ms/step - loss: 0.6039 - accuracy: 0.4762 - val_loss: 0.5937 - val_accuracy: 0.4740
# Epoch 25/200
# 16/16 [==============================] - 0s 23ms/step - loss: 0.5985 - accuracy: 0.4768 - val_loss: 0.5932 - val_accuracy: 0.4765
# Epoch 26/200
# 16/16 [==============================] - 0s 22ms/step - loss: 0.5967 - accuracy: 0.4765 - val_loss: 0.5931 - val_accuracy: 0.4740
# Epoch 27/200
# 16/16 [==============================] - 0s 24ms/step - loss: 0.5945 - accuracy: 0.4789 - val_loss: 0.5931 - val_accuracy: 0.4739
# Epoch 28/200
# 16/16 [==============================] - 0s 25ms/step - loss: 0.5951 - accuracy: 0.4780 - val_loss: 0.5933 - val_accuracy: 0.4739
# Epoch 29/200
# 16/16 [==============================] - 0s 24ms/step - loss: 0.6028 - accuracy: 0.4758 - val_loss: 0.5936 - val_accuracy: 0.4765
# Epoch 30/200
# 16/16 [==============================] - 0s 26ms/step - loss: 0.5944 - accuracy: 0.4759 - val_loss: 0.5927 - val_accuracy: 0.4740
# Epoch 31/200
# 16/16 [==============================] - 0s 24ms/step - loss: 0.5972 - accuracy: 0.4766 - val_loss: 0.5931 - val_accuracy: 0.4767
# Epoch 32/200
# 16/16 [==============================] - 0s 23ms/step - loss: 0.5972 - accuracy: 0.4762 - val_loss: 0.5930 - val_accuracy: 0.4705
# Epoch 33/200
# 16/16 [==============================] - 0s 24ms/step - loss: 0.6040 - accuracy: 0.4759 - val_loss: 0.5931 - val_accuracy: 0.4740
# Epoch 34/200
# 16/16 [==============================] - 0s 23ms/step - loss: 0.5981 - accuracy: 0.4776 - val_loss: 0.5924 - val_accuracy: 0.4703
# Epoch 35/200
# 16/16 [==============================] - 0s 24ms/step - loss: 0.5972 - accuracy: 0.4787 - val_loss: 0.5924 - val_accuracy: 0.4759
# Epoch 36/200
# 16/16 [==============================] - 0s 25ms/step - loss: 0.5948 - accuracy: 0.4756 - val_loss: 0.5923 - val_accuracy: 0.4765
# Epoch 37/200
# 16/16 [==============================] - 0s 24ms/step - loss: 0.5989 - accuracy: 0.4757 - val_loss: 0.5931 - val_accuracy: 0.4739
# Epoch 38/200
# 16/16 [==============================] - 0s 25ms/step - loss: 0.5983 - accuracy: 0.4760 - val_loss: 0.5923 - val_accuracy: 0.4752
# Epoch 39/200
# 16/16 [==============================] - 0s 24ms/step - loss: 0.5969 - accuracy: 0.4800 - val_loss: 0.5920 - val_accuracy: 0.4740
# Epoch 40/200
# 16/16 [==============================] - 0s 24ms/step - loss: 0.5997 - accuracy: 0.4788 - val_loss: 0.5925 - val_accuracy: 0.4739
# Epoch 41/200
# 16/16 [==============================] - 0s 25ms/step - loss: 0.5933 - accuracy: 0.4758 - val_loss: 0.5920 - val_accuracy: 0.4764
# Epoch 42/200
# 16/16 [==============================] - 0s 25ms/step - loss: 0.5987 - accuracy: 0.4742 - val_loss: 0.5921 - val_accuracy: 0.4719
# Epoch 43/200
# 16/16 [==============================] - 0s 24ms/step - loss: 0.5972 - accuracy: 0.4769 - val_loss: 0.5921 - val_accuracy: 0.4740
# Epoch 44/200
# 16/16 [==============================] - 0s 24ms/step - loss: 0.5944 - accuracy: 0.4768 - val_loss: 0.5923 - val_accuracy: 0.4761
# Epoch 45/200
# 16/16 [==============================] - 0s 24ms/step - loss: 0.5934 - accuracy: 0.4762 - val_loss: 0.5921 - val_accuracy: 0.4740
# Epoch 46/200
# 16/16 [==============================] - 0s 25ms/step - loss: 0.5917 - accuracy: 0.4773 - val_loss: 0.5920 - val_accuracy: 0.4764
# Epoch 47/200
# 16/16 [==============================] - 0s 23ms/step - loss: 0.5998 - accuracy: 0.4732 - val_loss: 0.5925 - val_accuracy: 0.4739
# Epoch 48/200
# 16/16 [==============================] - 0s 24ms/step - loss: 0.5957 - accuracy: 0.4795 - val_loss: 0.5916 - val_accuracy: 0.4766
# Epoch 49/200
# 16/16 [==============================] - 0s 24ms/step - loss: 0.6003 - accuracy: 0.4775 - val_loss: 0.5921 - val_accuracy: 0.4740
# Epoch 50/200
# 16/16 [==============================] - 0s 24ms/step - loss: 0.5976 - accuracy: 0.4791 - val_loss: 0.5917 - val_accuracy: 0.4759
# Epoch 51/200
# 16/16 [==============================] - 0s 24ms/step - loss: 0.5966 - accuracy: 0.4767 - val_loss: 0.5914 - val_accuracy: 0.4739
# Epoch 52/200
# 16/16 [==============================] - 0s 24ms/step - loss: 0.5964 - accuracy: 0.4775 - val_loss: 0.5917 - val_accuracy: 0.4758
# Epoch 53/200
# 16/16 [==============================] - 0s 24ms/step - loss: 0.5979 - accuracy: 0.4772 - val_loss: 0.5918 - val_accuracy: 0.4739
# Epoch 54/200
# 16/16 [==============================] - 0s 23ms/step - loss: 0.5972 - accuracy: 0.4773 - val_loss: 0.5915 - val_accuracy: 0.4758
# Epoch 55/200
# 16/16 [==============================] - 0s 23ms/step - loss: 0.5949 - accuracy: 0.4749 - val_loss: 0.5917 - val_accuracy: 0.4734
# Epoch 56/200
# 16/16 [==============================] - 0s 22ms/step - loss: 0.5988 - accuracy: 0.4774 - val_loss: 0.5913 - val_accuracy: 0.4739
# Epoch 57/200
# 16/16 [==============================] - 0s 24ms/step - loss: 0.5966 - accuracy: 0.4772 - val_loss: 0.5912 - val_accuracy: 0.4719
# Epoch 58/200
# 16/16 [==============================] - 0s 23ms/step - loss: 0.5970 - accuracy: 0.4764 - val_loss: 0.5911 - val_accuracy: 0.4759
# Epoch 59/200
# 16/16 [==============================] - 0s 24ms/step - loss: 0.5975 - accuracy: 0.4768 - val_loss: 0.5913 - val_accuracy: 0.4735
# Epoch 60/200
# 16/16 [==============================] - 0s 23ms/step - loss: 0.5952 - accuracy: 0.4757 - val_loss: 0.5917 - val_accuracy: 0.4761
# Epoch 61/200
# 16/16 [==============================] - 0s 24ms/step - loss: 0.6019 - accuracy: 0.4742 - val_loss: 0.5911 - val_accuracy: 0.4733
# Epoch 62/200
# 16/16 [==============================] - 0s 24ms/step - loss: 0.5949 - accuracy: 0.4769 - val_loss: 0.5911 - val_accuracy: 0.4722
# Epoch 63/200
# 16/16 [==============================] - 0s 25ms/step - loss: 0.5933 - accuracy: 0.4766 - val_loss: 0.5911 - val_accuracy: 0.4721
# Epoch 64/200
# 16/16 [==============================] - 0s 24ms/step - loss: 0.5977 - accuracy: 0.4793 - val_loss: 0.5912 - val_accuracy: 0.4728
# Epoch 65/200
# 16/16 [==============================] - 0s 24ms/step - loss: 0.5980 - accuracy: 0.4788 - val_loss: 0.5911 - val_accuracy: 0.4740
# Epoch 66/200
# 16/16 [==============================] - 0s 25ms/step - loss: 0.6005 - accuracy: 0.4747 - val_loss: 0.5907 - val_accuracy: 0.4727
# Epoch 67/200
# 16/16 [==============================] - 0s 25ms/step - loss: 0.5980 - accuracy: 0.4752 - val_loss: 0.5915 - val_accuracy: 0.4740
# Epoch 68/200
# 16/16 [==============================] - 0s 25ms/step - loss: 0.5993 - accuracy: 0.4765 - val_loss: 0.5909 - val_accuracy: 0.4717
# Epoch 69/200
# 16/16 [==============================] - 0s 24ms/step - loss: 0.6031 - accuracy: 0.4780 - val_loss: 0.5910 - val_accuracy: 0.4747
# Epoch 70/200
# 16/16 [==============================] - 0s 26ms/step - loss: 0.5982 - accuracy: 0.4795 - val_loss: 0.5906 - val_accuracy: 0.4707
# Epoch 71/200
# 16/16 [==============================] - 0s 24ms/step - loss: 0.5931 - accuracy: 0.4765 - val_loss: 0.5909 - val_accuracy: 0.4721
# Epoch 72/200
# 16/16 [==============================] - 0s 25ms/step - loss: 0.5951 - accuracy: 0.4752 - val_loss: 0.5910 - val_accuracy: 0.4740
# Epoch 73/200
# 16/16 [==============================] - 0s 25ms/step - loss: 0.6001 - accuracy: 0.4754 - val_loss: 0.5913 - val_accuracy: 0.4740
# Epoch 74/200
# 16/16 [==============================] - 0s 23ms/step - loss: 0.5991 - accuracy: 0.4764 - val_loss: 0.5907 - val_accuracy: 0.4754
# Epoch 75/200
# 16/16 [==============================] - 0s 24ms/step - loss: 0.5951 - accuracy: 0.4764 - val_loss: 0.5901 - val_accuracy: 0.4743
# Epoch 76/200
# 16/16 [==============================] - 0s 24ms/step - loss: 0.6045 - accuracy: 0.4771 - val_loss: 0.5911 - val_accuracy: 0.4740
# Epoch 77/200
# 16/16 [==============================] - 0s 25ms/step - loss: 0.6011 - accuracy: 0.4776 - val_loss: 0.5909 - val_accuracy: 0.4716
# Epoch 78/200
# 16/16 [==============================] - 0s 24ms/step - loss: 0.5903 - accuracy: 0.4775 - val_loss: 0.5901 - val_accuracy: 0.4730
# Epoch 79/200
# 16/16 [==============================] - 0s 24ms/step - loss: 0.5967 - accuracy: 0.4776 - val_loss: 0.5908 - val_accuracy: 0.4747
# Epoch 80/200
# 16/16 [==============================] - 0s 25ms/step - loss: 0.5957 - accuracy: 0.4755 - val_loss: 0.5903 - val_accuracy: 0.4709
# Epoch 81/200
# 16/16 [==============================] - 0s 24ms/step - loss: 0.5950 - accuracy: 0.4783 - val_loss: 0.5905 - val_accuracy: 0.4697
# Epoch 82/200
# 16/16 [==============================] - 0s 23ms/step - loss: 0.5987 - accuracy: 0.4753 - val_loss: 0.5906 - val_accuracy: 0.4708
# Epoch 83/200
# 16/16 [==============================] - 0s 24ms/step - loss: 0.5909 - accuracy: 0.4784 - val_loss: 0.5900 - val_accuracy: 0.4693
# Epoch 84/200
# 16/16 [==============================] - 0s 25ms/step - loss: 0.5957 - accuracy: 0.4771 - val_loss: 0.5908 - val_accuracy: 0.4740
# Epoch 85/200
# 16/16 [==============================] - 0s 24ms/step - loss: 0.5949 - accuracy: 0.4752 - val_loss: 0.5904 - val_accuracy: 0.4755
# Epoch 86/200
# 16/16 [==============================] - 0s 24ms/step - loss: 0.5919 - accuracy: 0.4744 - val_loss: 0.5905 - val_accuracy: 0.4764
# Epoch 87/200
# 16/16 [==============================] - 0s 23ms/step - loss: 0.5945 - accuracy: 0.4765 - val_loss: 0.5903 - val_accuracy: 0.4728
# Epoch 88/200
# 16/16 [==============================] - 0s 24ms/step - loss: 0.5986 - accuracy: 0.4773 - val_loss: 0.5907 - val_accuracy: 0.4749
# Epoch 89/200
# 16/16 [==============================] - 0s 24ms/step - loss: 0.5963 - accuracy: 0.4766 - val_loss: 0.5902 - val_accuracy: 0.4738
# Epoch 90/200
# 16/16 [==============================] - 0s 25ms/step - loss: 0.5942 - accuracy: 0.4774 - val_loss: 0.5903 - val_accuracy: 0.4738
# Epoch 91/200
# 16/16 [==============================] - 0s 23ms/step - loss: 0.5960 - accuracy: 0.4766 - val_loss: 0.5905 - val_accuracy: 0.4730
# Epoch 92/200
# 16/16 [==============================] - 0s 23ms/step - loss: 0.6001 - accuracy: 0.4776 - val_loss: 0.5902 - val_accuracy: 0.4739
# Epoch 93/200
# 16/16 [==============================] - 0s 23ms/step - loss: 0.5962 - accuracy: 0.4757 - val_loss: 0.5900 - val_accuracy: 0.4700
# Restoring model weights from the end of the best epoch.
# Epoch 00093: early stopping

# %%
w_data = reweight(theta_unknown_S_withback[theta_unknown_S_withback[:,0]!=dummyval])

# %%
bins = np.linspace(-11, 11, 41)

fig, ax = plt.subplots(5,
                       2,
                       figsize=(12, 25),
                       #constrained_layout=True,
                       sharey='row')

for i in range(2):
        ax[i,0].set_xlabel('$x$')
        ax[i,0].set_ylabel('Events per bin')
        ax[i,0].hist(theta0_G[theta0_G[:,0]!=dummyval][:,i], bins=bins, **plot_style_2, label='Generation') # MC event at generation
        ax[i,0].hist(theta0_S[theta0_S[:,0]!=dummyval][:,i], bins=bins, **plot_style_2, label='Simulation (no back.)') # MC event after reco
        legend = ax[i,0].legend(
            title='Synthetic\n($\mu$, $\sigma$) = {}'.format(theta0_param),
            loc='upper left',
            frameon=False)
        plt.setp(legend.get_title(), multialignment='center')

        ax[i,1].set_xlabel('$x$')
        ax[i,1].hist(theta_unknown_G[theta_unknown_G[:,0]!=dummyval][:,i], bins=bins, **plot_style_2, label='Truth',color="green") # Real event at generation
        ax[i,1].hist(theta_unknown_S[theta_unknown_S[:,0]!=dummyval][:,i], bins=bins, **plot_style_2, label='Data (no back.)',color="black") # Real event after reco
        ax[i,1].hist(theta_unknown_S_withback[theta_unknown_S_withback[:,0]!=dummyval][:,i], bins=bins, histtype="step", label='Data (reweighted)',color="black",weights=w_data) # Reweighing background-included real reco event to subtract background
        legend = ax[i,1].legend(
            title='Natural\n($\mu$, $\sigma$) = {}'.format(theta_unknown_param),
            loc='upper left',
            frameon=False)
        plt.setp(legend.get_title(), multialignment='center')

ax[2,0].set_xlabel('$x1$')
ax[2,0].set_ylabel('$x2$')
h1 = ax[2,0].hist2d(theta0_G[theta0_G[:,0]!=dummyval][:,0], theta0_G[theta0_G[:,0]!=dummyval][:,1] , bins=(bins,bins),label='Generation') # MC event at generation
fig.colorbar(h1[3],ax=ax[2,0])
legend = ax[2,0].legend(
    title='Generation\n($\mu$, $\sigma$) = {}'.format(theta0_param),
    loc='upper left',
    frameon=False)
plt.setp(legend.get_title(), multialignment='center')

ax[2,1].set_xlabel('$x1$')
ax[2,1].set_ylabel('$x2$')
h2 = ax[2,1].hist2d(theta_unknown_G[theta_unknown_G[:,0]!=dummyval][:,0], theta_unknown_G[theta_unknown_G[:,0]!=dummyval][:,1] , bins=(bins,bins),label='Simulation (no back.)') # MC event after reco
fig.colorbar(h2[3],ax=ax[2,1])
legend = ax[2,1].legend(
    title='Simulation (no back.)\n($\mu$, $\sigma$) = {}'.format(theta0_param),
    loc='upper left',
    frameon=False)
plt.setp(legend.get_title(), multialignment='center')

ax[3,0].set_xlabel('$x1$')
ax[3,0].set_ylabel('$x2$')
h3 = ax[3,0].hist2d(theta_unknown_G[theta_unknown_G[:,0]!=dummyval][:,0], theta_unknown_G[theta_unknown_G[:,0]!=dummyval][:,1] , bins=(bins,bins),label='Truth') # Real event at generation
fig.colorbar(h1[3],ax=ax[3,0])
legend = ax[3,0].legend(
    title='Truth\n($\mu$, $\sigma$) = {}'.format(theta_unknown_param),
    loc='upper left',
    frameon=False)
plt.setp(legend.get_title(), multialignment='center')

ax[3,1].set_xlabel('$x1$')
ax[3,1].set_ylabel('$x2$')
h4 = ax[3,1].hist2d(theta_unknown_S[theta_unknown_S[:,0]!=dummyval][:,0], theta_unknown_S[theta_unknown_S[:,0]!=dummyval][:,1] , bins=(bins,bins),label='Data (no back.)') # Real event after reco
fig.colorbar(h4[3],ax=ax[3,1])
legend = ax[3,1].legend(
    title='Data (no back.)\n($\mu$, $\sigma$) = {}'.format(theta_unknown_param),
    loc='upper left',
    frameon=False)
plt.setp(legend.get_title(), multialignment='center')

ax[4,0].set_xlabel('$x1$')
ax[4,0].set_ylabel('$x2$')
h5 = ax[4,0].hist2d(theta_unknown_S_withback[theta_unknown_S_withback[:,0]!=dummyval][:,0], theta_unknown_S_withback[theta_unknown_S_withback[:,0]!=dummyval][:,1] , bins=(bins,bins),label='Data (with back.)') # Real event after reco + background
fig.colorbar(h5[3],ax=ax[4,0])
legend = ax[4,0].legend(
    title='Data (with back.)\n($\mu$, $\sigma$) = {}'.format(theta_unknown_param),
    loc='upper left',
    frameon=False)
plt.setp(legend.get_title(), multialignment='center')

ax[4,1].set_xlabel('$x1$')
ax[4,1].set_ylabel('$x2$')
h6 = ax[4,1].hist2d(theta_unknown_S_withback[theta_unknown_S_withback[:,0]!=dummyval][:,0], theta_unknown_S_withback[theta_unknown_S_withback[:,0]!=dummyval][:,1] , bins=(bins,bins),label='Data (reweighted)',weights=w_data) # Reweighing background-included real reco event to subtract background
fig.colorbar(h6[3],ax=ax[4,1])
legend = ax[4,1].legend(
    title='Data (reweighted)\n($\mu$, $\sigma$) = {}'.format(theta_unknown_param),
    loc='upper left',
    frameon=False)
plt.setp(legend.get_title(), multialignment='center')

fig.tight_layout()

fig.show()
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %%
# initial iterative weights are ones
weights_pull = np.ones(len(theta0_S))
weights_push = np.ones(len(theta0_S))

# %%
xvals_1 = np.concatenate((theta0_S, theta_unknown_S_withback[theta_unknown_S_withback[:,0]!=dummyval]))
yvals_1 = np.concatenate((labels0, np.ones(len(theta_unknown_S_withback[theta_unknown_S_withback[:,0]!=dummyval]))))

# %%
for i in range(iterations):
    print("\nITERATION: {}\n".format(i + 1))

    # STEP 1: classify Sim. (which is reweighted by weights_push) to Data
    # weights reweighted Sim. --> Data
    print("STEP 1\n")

    weights_1 = np.concatenate((weights_push, w_data))
    # actual weights for Sim., ones for Data (not MC weights)

    X_train_1, X_test_1, Y_train_1, Y_test_1, w_train_1, w_test_1 = train_test_split(
        xvals_1, yvals_1, weights_1)

    model.compile(loss='binary_crossentropy',
                  optimizer='Adam',
                  metrics=['accuracy'])
    model.fit(X_train_1[X_train_1[:,0]!=dummyval], # Classification at reco level
              Y_train_1[X_train_1[:,0]!=dummyval],
              sample_weight=w_train_1[X_train_1[:,0]!=dummyval],
              epochs=200,
              batch_size=10000,
              validation_data=(X_test_1[X_test_1[:,0]!=dummyval], Y_test_1[X_test_1[:,0]!=dummyval], w_test_1[X_test_1[:,0]!=dummyval]),
              callbacks=[earlystopping],
              verbose=1)

    weights_pull = weights_push * reweight(theta0_S)
    
    ###
    #Need to do something with events that don't pass reco.
    
    #One option is to take the prior:
    #weights_pull[theta0_S==dummyval] = 1. 
    
    #Another option is to assign the average weight: <w|x_true>.  To do this, we need to estimate this quantity.
    # Training for events that don't pass reco
    xvals_1b = np.concatenate([theta0_G[theta0_S[:,0]!=dummyval],theta0_G[theta0_S[:,0]!=dummyval]])
    yvals_1b = np.concatenate([np.ones(len(theta0_G[theta0_S[:,0]!=dummyval])),np.zeros(len(theta0_G[theta0_S[:,0]!=dummyval]))])
    weights_1b = np.concatenate([weights_pull[theta0_S[:,0]!=dummyval],np.ones(len(theta0_G[theta0_S[:,0]!=dummyval]))])
    
    X_train_1b, X_test_1b, Y_train_1b, Y_test_1b, w_train_1b, w_test_1b = train_test_split(
        xvals_1b, yvals_1b, weights_1b)    
    
    model.compile(loss='binary_crossentropy',
                  optimizer='Adam',
                  metrics=['accuracy'])
    model.fit(X_train_1b,
              Y_train_1b,
              sample_weight=w_train_1b,
              epochs=200,
              batch_size=10000,
              validation_data=(X_test_1b, Y_test_1b, w_test_1b),
              callbacks=[earlystopping],
              verbose=1)
    
    average_vals = reweight(theta0_G[theta0_S[:,0]==dummyval])
    weights_pull[theta0_S[:,0]==dummyval] = average_vals
    ###
    
    weights[i, :1, :] = weights_pull

    # STEP 2: classify Gen. to reweighted Gen. (which is reweighted by weights_pull)
    # weights Gen. --> reweighted Gen.
    print("\nSTEP 2\n")

    weights_2 = np.concatenate((np.ones(len(theta0_G)), weights_pull))
    # ones for Gen. (not MC weights), actual weights for (reweighted) Gen.

    X_train_2, X_test_2, Y_train_2, Y_test_2, w_train_2, w_test_2 = train_test_split(
        xvals_2, yvals_2, weights_2)

    model.compile(loss='binary_crossentropy',
                  optimizer='Adam',
                  metrics=['accuracy'])
    model.fit(X_train_2,
              Y_train_2,
              sample_weight=w_train_2,
              epochs=200,
              batch_size=2000,
              validation_data=(X_test_2, Y_test_2, w_test_2),
              callbacks=[earlystopping],
              verbose=1)

    weights_push = reweight(theta0_G)
    ###
    #Need to do something with events that don't pass truth    
    
    #One option is to take the prior:
    #weights_push[theta0_G==dummyval] = 1. 
    
    #Another option is to assign the average weight: <w|x_reco>.  To do this, we need to estimate this quantity.
    xvals_1b = np.concatenate([theta0_S[theta0_G[:,0]!=dummyval],theta0_S[theta0_G[:,0]!=dummyval]])
    yvals_1b = np.concatenate([np.ones(len(theta0_S[theta0_G[:,0]!=dummyval])),np.zeros(len(theta0_S[theta0_G[:,0]!=dummyval]))])
    weights_1b = np.concatenate([weights_push[theta0_G[:,0]!=dummyval],np.ones(len(theta0_S[theta0_G[:,0]!=dummyval]))])
    
    X_train_1b, X_test_1b, Y_train_1b, Y_test_1b, w_train_1b, w_test_1b = train_test_split(
        xvals_1b, yvals_1b, weights_1b)    
    
    model.compile(loss='binary_crossentropy',
                  optimizer='Adam',
                  metrics=['accuracy'])
    model.fit(X_train_1b,
              Y_train_1b,
              sample_weight=w_train_1b,
              epochs=200,
              batch_size=10000,
              validation_data=(X_test_1b, Y_test_1b, w_test_1b),
              callbacks=[earlystopping],
              verbose=1)
    
    average_vals = reweight(theta0_S[theta0_G[:,0]==dummyval])
    weights_push[theta0_G[:,0]==dummyval] = average_vals
    ###    
    
    weights[i, 1:2, :] = weights_push
# Out:
# ITERATION: 1
#
# STEP 1
#
# Epoch 1/200
# 15/15 [==============================] - 7s 401ms/step - loss: 0.3461 - accuracy: 0.8208 - val_loss: 0.1287 - val_accuracy: 0.9051
# Epoch 2/200
# 15/15 [==============================] - 0s 22ms/step - loss: 0.1108 - accuracy: 0.9140 - val_loss: 0.0811 - val_accuracy: 0.9220
# Epoch 3/200
# 15/15 [==============================] - 0s 23ms/step - loss: 0.0792 - accuracy: 0.9233 - val_loss: 0.0731 - val_accuracy: 0.9218
# Epoch 4/200
# 15/15 [==============================] - 0s 25ms/step - loss: 0.0722 - accuracy: 0.9235 - val_loss: 0.0700 - val_accuracy: 0.9222
# Epoch 5/200
# 15/15 [==============================] - 0s 22ms/step - loss: 0.0694 - accuracy: 0.9236 - val_loss: 0.0685 - val_accuracy: 0.9221
# Epoch 6/200
# 15/15 [==============================] - 0s 22ms/step - loss: 0.0691 - accuracy: 0.9238 - val_loss: 0.0676 - val_accuracy: 0.9221
# Epoch 7/200
# 15/15 [==============================] - 0s 24ms/step - loss: 0.0669 - accuracy: 0.9254 - val_loss: 0.0671 - val_accuracy: 0.9222
# Epoch 8/200
# 15/15 [==============================] - 0s 24ms/step - loss: 0.0663 - accuracy: 0.9248 - val_loss: 0.0666 - val_accuracy: 0.9223
# Epoch 9/200
# 15/15 [==============================] - 0s 23ms/step - loss: 0.0668 - accuracy: 0.9244 - val_loss: 0.0663 - val_accuracy: 0.9222
# Epoch 10/200
# 15/15 [==============================] - 0s 23ms/step - loss: 0.0657 - accuracy: 0.9258 - val_loss: 0.0661 - val_accuracy: 0.9222
# Epoch 11/200
# 15/15 [==============================] - 0s 23ms/step - loss: 0.0661 - accuracy: 0.9238 - val_loss: 0.0660 - val_accuracy: 0.9222
# Epoch 12/200
# 15/15 [==============================] - 0s 23ms/step - loss: 0.0644 - accuracy: 0.9248 - val_loss: 0.0657 - val_accuracy: 0.9222
# Epoch 13/200
# 15/15 [==============================] - 0s 23ms/step - loss: 0.0655 - accuracy: 0.9240 - val_loss: 0.0656 - val_accuracy: 0.9223
# Epoch 14/200
# 15/15 [==============================] - 0s 22ms/step - loss: 0.0666 - accuracy: 0.9243 - val_loss: 0.0654 - val_accuracy: 0.9221
# Epoch 15/200
# 15/15 [==============================] - 0s 22ms/step - loss: 0.0649 - accuracy: 0.9246 - val_loss: 0.0653 - val_accuracy: 0.9221
# Epoch 16/200
# 15/15 [==============================] - 0s 23ms/step - loss: 0.0644 - accuracy: 0.9247 - val_loss: 0.0652 - val_accuracy: 0.9223
# Epoch 17/200
# 15/15 [==============================] - 0s 22ms/step - loss: 0.0647 - accuracy: 0.9251 - val_loss: 0.0652 - val_accuracy: 0.9225
# Epoch 18/200
# 15/15 [==============================] - 0s 22ms/step - loss: 0.0641 - accuracy: 0.9246 - val_loss: 0.0651 - val_accuracy: 0.9225
# Epoch 19/200
# 15/15 [==============================] - 0s 23ms/step - loss: 0.0639 - accuracy: 0.9258 - val_loss: 0.0649 - val_accuracy: 0.9221
# Epoch 20/200
# 15/15 [==============================] - 0s 23ms/step - loss: 0.0650 - accuracy: 0.9248 - val_loss: 0.0649 - val_accuracy: 0.9222
# Epoch 21/200
# 15/15 [==============================] - 0s 22ms/step - loss: 0.0640 - accuracy: 0.9247 - val_loss: 0.0648 - val_accuracy: 0.9224
# Epoch 22/200
# 15/15 [==============================] - 0s 23ms/step - loss: 0.0655 - accuracy: 0.9239 - val_loss: 0.0648 - val_accuracy: 0.9221
# Epoch 23/200
# 15/15 [==============================] - 0s 22ms/step - loss: 0.0651 - accuracy: 0.9253 - val_loss: 0.0652 - val_accuracy: 0.9221
# Epoch 24/200
# 15/15 [==============================] - 0s 22ms/step - loss: 0.0642 - accuracy: 0.9246 - val_loss: 0.0647 - val_accuracy: 0.9222
# Epoch 25/200
# 15/15 [==============================] - 0s 23ms/step - loss: 0.0645 - accuracy: 0.9246 - val_loss: 0.0650 - val_accuracy: 0.9220
# Epoch 26/200
# 15/15 [==============================] - 0s 21ms/step - loss: 0.0640 - accuracy: 0.9248 - val_loss: 0.0648 - val_accuracy: 0.9226
# Epoch 27/200
# 15/15 [==============================] - 0s 22ms/step - loss: 0.0641 - accuracy: 0.9243 - val_loss: 0.0647 - val_accuracy: 0.9223
# Epoch 28/200
# 15/15 [==============================] - 0s 24ms/step - loss: 0.0640 - accuracy: 0.9250 - val_loss: 0.0646 - val_accuracy: 0.9224
# Epoch 29/200
# 15/15 [==============================] - 0s 22ms/step - loss: 0.0645 - accuracy: 0.9242 - val_loss: 0.0646 - val_accuracy: 0.9224
# Epoch 30/200
# 15/15 [==============================] - 0s 23ms/step - loss: 0.0642 - accuracy: 0.9240 - val_loss: 0.0646 - val_accuracy: 0.9224
# Epoch 31/200
# 15/15 [==============================] - 0s 23ms/step - loss: 0.0649 - accuracy: 0.9249 - val_loss: 0.0647 - val_accuracy: 0.9226
# Epoch 32/200
# 15/15 [==============================] - 0s 23ms/step - loss: 0.0642 - accuracy: 0.9238 - val_loss: 0.0646 - val_accuracy: 0.9224
# Epoch 33/200
# 15/15 [==============================] - 0s 22ms/step - loss: 0.0638 - accuracy: 0.9248 - val_loss: 0.0648 - val_accuracy: 0.9220
# Epoch 34/200
# 15/15 [==============================] - 0s 22ms/step - loss: 0.0654 - accuracy: 0.9238 - val_loss: 0.0646 - val_accuracy: 0.9224
# Epoch 35/200
# 15/15 [==============================] - 0s 22ms/step - loss: 0.0640 - accuracy: 0.9239 - val_loss: 0.0647 - val_accuracy: 0.9220
# Epoch 36/200
# 15/15 [==============================] - 0s 22ms/step - loss: 0.0645 - accuracy: 0.9253 - val_loss: 0.0645 - val_accuracy: 0.9223
# Epoch 37/200
# 15/15 [==============================] - 0s 23ms/step - loss: 0.0637 - accuracy: 0.9247 - val_loss: 0.0645 - val_accuracy: 0.9224
# Epoch 38/200
# 15/15 [==============================] - 0s 22ms/step - loss: 0.0637 - accuracy: 0.9254 - val_loss: 0.0648 - val_accuracy: 0.9220
# Epoch 39/200
# 15/15 [==============================] - 0s 23ms/step - loss: 0.0639 - accuracy: 0.9240 - val_loss: 0.0647 - val_accuracy: 0.9226
# Epoch 40/200
# 15/15 [==============================] - 0s 23ms/step - loss: 0.0647 - accuracy: 0.9240 - val_loss: 0.0646 - val_accuracy: 0.9220
# Epoch 41/200
# 15/15 [==============================] - 0s 22ms/step - loss: 0.0639 - accuracy: 0.9246 - val_loss: 0.0646 - val_accuracy: 0.9220
# Epoch 42/200
# 15/15 [==============================] - 0s 23ms/step - loss: 0.0641 - accuracy: 0.9249 - val_loss: 0.0645 - val_accuracy: 0.9225
# Epoch 43/200
# 15/15 [==============================] - 0s 22ms/step - loss: 0.0639 - accuracy: 0.9240 - val_loss: 0.0645 - val_accuracy: 0.9225
# Epoch 44/200
# 15/15 [==============================] - 0s 22ms/step - loss: 0.0631 - accuracy: 0.9256 - val_loss: 0.0645 - val_accuracy: 0.9225
# Epoch 45/200
# 15/15 [==============================] - 0s 22ms/step - loss: 0.0631 - accuracy: 0.9246 - val_loss: 0.0645 - val_accuracy: 0.9224
# Epoch 46/200
# 15/15 [==============================] - 0s 23ms/step - loss: 0.0643 - accuracy: 0.9246 - val_loss: 0.0645 - val_accuracy: 0.9223
# Epoch 47/200
# 15/15 [==============================] - 0s 25ms/step - loss: 0.0643 - accuracy: 0.9239 - val_loss: 0.0645 - val_accuracy: 0.9224
# Epoch 48/200
# 15/15 [==============================] - 0s 23ms/step - loss: 0.0655 - accuracy: 0.9244 - val_loss: 0.0652 - val_accuracy: 0.9225
# Epoch 49/200
# 15/15 [==============================] - 0s 22ms/step - loss: 0.0635 - accuracy: 0.9246 - val_loss: 0.0646 - val_accuracy: 0.9220
# Epoch 50/200
# 15/15 [==============================] - 0s 23ms/step - loss: 0.0635 - accuracy: 0.9247 - val_loss: 0.0648 - val_accuracy: 0.9220
# Epoch 51/200
# 15/15 [==============================] - 0s 24ms/step - loss: 0.0636 - accuracy: 0.9252 - val_loss: 0.0645 - val_accuracy: 0.9225
# Epoch 52/200
# 15/15 [==============================] - 0s 22ms/step - loss: 0.0640 - accuracy: 0.9242 - val_loss: 0.0649 - val_accuracy: 0.9224
# Epoch 53/200
# 15/15 [==============================] - 0s 23ms/step - loss: 0.0639 - accuracy: 0.9248 - val_loss: 0.0646 - val_accuracy: 0.9221
# Epoch 54/200
# 15/15 [==============================] - 0s 24ms/step - loss: 0.0639 - accuracy: 0.9243 - val_loss: 0.0645 - val_accuracy: 0.9221
# Epoch 55/200
# 15/15 [==============================] - 0s 23ms/step - loss: 0.0646 - accuracy: 0.9239 - val_loss: 0.0645 - val_accuracy: 0.9225
# Epoch 56/200
# 15/15 [==============================] - 0s 21ms/step - loss: 0.0645 - accuracy: 0.9247 - val_loss: 0.0646 - val_accuracy: 0.9226
# Epoch 57/200
# 15/15 [==============================] - 0s 23ms/step - loss: 0.0645 - accuracy: 0.9243 - val_loss: 0.0648 - val_accuracy: 0.9221
# Epoch 58/200
# 15/15 [==============================] - 0s 22ms/step - loss: 0.0635 - accuracy: 0.9242 - val_loss: 0.0645 - val_accuracy: 0.9224
# Epoch 59/200
# 15/15 [==============================] - 0s 23ms/step - loss: 0.0638 - accuracy: 0.9250 - val_loss: 0.0645 - val_accuracy: 0.9224
# Epoch 60/200
# 15/15 [==============================] - 0s 24ms/step - loss: 0.0642 - accuracy: 0.9240 - val_loss: 0.0645 - val_accuracy: 0.9225
# Epoch 61/200
# 15/15 [==============================] - 0s 23ms/step - loss: 0.0632 - accuracy: 0.9246 - val_loss: 0.0646 - val_accuracy: 0.9226
# Epoch 62/200
# 15/15 [==============================] - 0s 22ms/step - loss: 0.0646 - accuracy: 0.9239 - val_loss: 0.0645 - val_accuracy: 0.9224
# Epoch 63/200
# 15/15 [==============================] - 0s 27ms/step - loss: 0.0640 - accuracy: 0.9239 - val_loss: 0.0645 - val_accuracy: 0.9225
# Epoch 64/200
# 15/15 [==============================] - 0s 22ms/step - loss: 0.0645 - accuracy: 0.9241 - val_loss: 0.0644 - val_accuracy: 0.9224
# Epoch 65/200
# 15/15 [==============================] - 0s 22ms/step - loss: 0.0646 - accuracy: 0.9242 - val_loss: 0.0645 - val_accuracy: 0.9222
# Epoch 66/200
# 15/15 [==============================] - 0s 22ms/step - loss: 0.0636 - accuracy: 0.9248 - val_loss: 0.0645 - val_accuracy: 0.9224
# Epoch 67/200
# 15/15 [==============================] - 0s 22ms/step - loss: 0.0627 - accuracy: 0.9261 - val_loss: 0.0647 - val_accuracy: 0.9220
# Epoch 68/200
# 15/15 [==============================] - 0s 23ms/step - loss: 0.0646 - accuracy: 0.9246 - val_loss: 0.0645 - val_accuracy: 0.9225
# Epoch 69/200
# 15/15 [==============================] - 0s 23ms/step - loss: 0.0646 - accuracy: 0.9241 - val_loss: 0.0645 - val_accuracy: 0.9225
# Epoch 70/200
# 15/15 [==============================] - 0s 24ms/step - loss: 0.0641 - accuracy: 0.9248 - val_loss: 0.0649 - val_accuracy: 0.9220
# Epoch 71/200
# 15/15 [==============================] - 0s 23ms/step - loss: 0.0640 - accuracy: 0.9245 - val_loss: 0.0645 - val_accuracy: 0.9223
# Epoch 72/200
# 15/15 [==============================] - 0s 24ms/step - loss: 0.0642 - accuracy: 0.9246 - val_loss: 0.0645 - val_accuracy: 0.9226
# Epoch 73/200
# 15/15 [==============================] - 0s 23ms/step - loss: 0.0635 - accuracy: 0.9246 - val_loss: 0.0646 - val_accuracy: 0.9222
# Epoch 74/200
# 15/15 [==============================] - 0s 22ms/step - loss: 0.0645 - accuracy: 0.9240 - val_loss: 0.0645 - val_accuracy: 0.9225
# Restoring model weights from the end of the best epoch.
# Epoch 00074: early stopping
# Epoch 1/200
# 14/14 [==============================] - 6s 402ms/step - loss: 1.0616 - accuracy: 0.5014 - val_loss: 0.2885 - val_accuracy: 0.5009
# Epoch 2/200
# 14/14 [==============================] - 0s 23ms/step - loss: 0.5546 - accuracy: 0.4985 - val_loss: 0.1532 - val_accuracy: 0.5001
# Epoch 3/200
# 14/14 [==============================] - 0s 23ms/step - loss: 0.1705 - accuracy: 0.5007 - val_loss: 0.1511 - val_accuracy: 0.5008
# Epoch 4/200
# 14/14 [==============================] - 0s 23ms/step - loss: 0.1467 - accuracy: 0.5010 - val_loss: 0.1301 - val_accuracy: 0.5007
# Epoch 5/200
# 14/14 [==============================] - 0s 23ms/step - loss: 0.1577 - accuracy: 0.4996 - val_loss: 0.1321 - val_accuracy: 0.5002
# Epoch 6/200
# 14/14 [==============================] - 0s 23ms/step - loss: 0.1612 - accuracy: 0.5004 - val_loss: 0.1298 - val_accuracy: 0.5006
# Epoch 7/200
# 14/14 [==============================] - 0s 25ms/step - loss: 0.1390 - accuracy: 0.4988 - val_loss: 0.1327 - val_accuracy: 0.5009
# Epoch 8/200
# 14/14 [==============================] - 0s 24ms/step - loss: 0.1451 - accuracy: 0.4990 - val_loss: 0.1298 - val_accuracy: 0.5000
# Epoch 9/200
# 14/14 [==============================] - 0s 25ms/step - loss: 0.1562 - accuracy: 0.4995 - val_loss: 0.1505 - val_accuracy: 0.5010
# Epoch 10/200
# 14/14 [==============================] - 0s 23ms/step - loss: 0.1426 - accuracy: 0.5007 - val_loss: 0.1289 - val_accuracy: 0.5007
# Epoch 11/200
# 14/14 [==============================] - 0s 23ms/step - loss: 0.1495 - accuracy: 0.5012 - val_loss: 0.1389 - val_accuracy: 0.4998
# Epoch 12/200
# 14/14 [==============================] - 0s 24ms/step - loss: 0.1662 - accuracy: 0.4989 - val_loss: 0.1298 - val_accuracy: 0.5009
# Epoch 13/200
# 14/14 [==============================] - 0s 24ms/step - loss: 0.1477 - accuracy: 0.5020 - val_loss: 0.1452 - val_accuracy: 0.5002
# Epoch 14/200
# 14/14 [==============================] - 0s 22ms/step - loss: 0.1467 - accuracy: 0.5006 - val_loss: 0.1285 - val_accuracy: 0.5005
# Epoch 15/200
# 14/14 [==============================] - 0s 23ms/step - loss: 0.1578 - accuracy: 0.5007 - val_loss: 0.1341 - val_accuracy: 0.5005
# Epoch 16/200
# 14/14 [==============================] - 0s 24ms/step - loss: 0.1534 - accuracy: 0.4987 - val_loss: 0.1296 - val_accuracy: 0.5000
# Epoch 17/200
# 14/14 [==============================] - 0s 24ms/step - loss: 0.1680 - accuracy: 0.4987 - val_loss: 0.1293 - val_accuracy: 0.5009
# Epoch 18/200
# 14/14 [==============================] - 0s 23ms/step - loss: 0.1617 - accuracy: 0.4988 - val_loss: 0.1306 - val_accuracy: 0.5006
# Epoch 19/200
# 14/14 [==============================] - 0s 25ms/step - loss: 0.1363 - accuracy: 0.5025 - val_loss: 0.1303 - val_accuracy: 0.5007
# Epoch 20/200
# 14/14 [==============================] - 0s 25ms/step - loss: 0.1408 - accuracy: 0.5004 - val_loss: 0.1345 - val_accuracy: 0.5006
# Epoch 21/200
# 14/14 [==============================] - 0s 24ms/step - loss: 0.1418 - accuracy: 0.4998 - val_loss: 0.1298 - val_accuracy: 0.5005
# Epoch 22/200
# 14/14 [==============================] - 0s 24ms/step - loss: 0.1407 - accuracy: 0.5007 - val_loss: 0.1292 - val_accuracy: 0.5004
# Epoch 23/200
# 14/14 [==============================] - 0s 24ms/step - loss: 0.1775 - accuracy: 0.4990 - val_loss: 0.1285 - val_accuracy: 0.5004
# Epoch 24/200
# 14/14 [==============================] - 0s 23ms/step - loss: 0.1579 - accuracy: 0.4997 - val_loss: 0.1312 - val_accuracy: 0.5007
# Epoch 25/200
# 14/14 [==============================] - 0s 23ms/step - loss: 0.1438 - accuracy: 0.5018 - val_loss: 0.1345 - val_accuracy: 0.5006
# Epoch 26/200
# 14/14 [==============================] - 0s 24ms/step - loss: 0.1595 - accuracy: 0.4986 - val_loss: 0.1296 - val_accuracy: 0.5003
# Epoch 27/200
# 14/14 [==============================] - 0s 23ms/step - loss: 0.1406 - accuracy: 0.4989 - val_loss: 0.1355 - val_accuracy: 0.5008
# Epoch 28/200
# 14/14 [==============================] - 0s 25ms/step - loss: 0.1512 - accuracy: 0.4985 - val_loss: 0.1284 - val_accuracy: 0.5005
# Epoch 29/200
# 14/14 [==============================] - 0s 23ms/step - loss: 0.1566 - accuracy: 0.5012 - val_loss: 0.1382 - val_accuracy: 0.5001
# Epoch 30/200
# 14/14 [==============================] - 0s 25ms/step - loss: 0.1521 - accuracy: 0.4998 - val_loss: 0.1289 - val_accuracy: 0.5007
# Epoch 31/200
# 14/14 [==============================] - 0s 23ms/step - loss: 0.1466 - accuracy: 0.4969 - val_loss: 0.1351 - val_accuracy: 0.5007
# Epoch 32/200
# 14/14 [==============================] - 0s 24ms/step - loss: 0.1467 - accuracy: 0.4995 - val_loss: 0.1313 - val_accuracy: 0.5001
# Epoch 33/200
# 14/14 [==============================] - 0s 24ms/step - loss: 0.1358 - accuracy: 0.4997 - val_loss: 0.1333 - val_accuracy: 0.5008
# Epoch 34/200
# 14/14 [==============================] - 0s 23ms/step - loss: 0.1439 - accuracy: 0.4980 - val_loss: 0.1300 - val_accuracy: 0.5000
# Epoch 35/200
# 14/14 [==============================] - 0s 24ms/step - loss: 0.1359 - accuracy: 0.5003 - val_loss: 0.1368 - val_accuracy: 0.5006
# Epoch 36/200
# 14/14 [==============================] - 0s 25ms/step - loss: 0.1452 - accuracy: 0.5003 - val_loss: 0.1285 - val_accuracy: 0.5005
# Epoch 37/200
# 14/14 [==============================] - 0s 23ms/step - loss: 0.1390 - accuracy: 0.4986 - val_loss: 0.1415 - val_accuracy: 0.5003
# Epoch 38/200
# 14/14 [==============================] - 0s 24ms/step - loss: 0.1541 - accuracy: 0.4988 - val_loss: 0.1294 - val_accuracy: 0.5008
# Restoring model weights from the end of the best epoch.
# Epoch 00038: early stopping
#
# STEP 2
#
# Epoch 1/200
# 75/75 [==============================] - 7s 83ms/step - loss: 0.1490 - accuracy: 0.4982 - val_loss: 0.2070 - val_accuracy: 0.5000
# Epoch 2/200
# 75/75 [==============================] - 1s 7ms/step - loss: 0.1476 - accuracy: 0.5006 - val_loss: 0.1967 - val_accuracy: 0.4992
# Epoch 3/200
# 75/75 [==============================] - 1s 8ms/step - loss: 0.1359 - accuracy: 0.5018 - val_loss: 0.1671 - val_accuracy: 0.4997
# Epoch 4/200
# 75/75 [==============================] - 1s 7ms/step - loss: 0.1374 - accuracy: 0.5008 - val_loss: 0.1831 - val_accuracy: 0.4999
# Epoch 5/200
# 75/75 [==============================] - 1s 8ms/step - loss: 0.1284 - accuracy: 0.4994 - val_loss: 0.1564 - val_accuracy: 0.5006
# Epoch 6/200
# 75/75 [==============================] - 1s 8ms/step - loss: 0.1445 - accuracy: 0.5011 - val_loss: 0.1727 - val_accuracy: 0.4995
# Epoch 7/200
# 75/75 [==============================] - 1s 7ms/step - loss: 0.1420 - accuracy: 0.4984 - val_loss: 0.1696 - val_accuracy: 0.4993
# Epoch 8/200
# 75/75 [==============================] - 1s 7ms/step - loss: 0.1346 - accuracy: 0.4994 - val_loss: 0.2109 - val_accuracy: 0.4997
# Epoch 9/200
# 75/75 [==============================] - 1s 8ms/step - loss: 0.1360 - accuracy: 0.5008 - val_loss: 0.1806 - val_accuracy: 0.4993
# Epoch 10/200
# 75/75 [==============================] - 1s 8ms/step - loss: 0.1347 - accuracy: 0.5017 - val_loss: 0.1946 - val_accuracy: 0.4995
# Epoch 11/200
# 75/75 [==============================] - 1s 7ms/step - loss: 0.1263 - accuracy: 0.4994 - val_loss: 0.1709 - val_accuracy: 0.5004
# Epoch 12/200
# 75/75 [==============================] - 1s 8ms/step - loss: 0.1354 - accuracy: 0.4987 - val_loss: 0.1568 - val_accuracy: 0.4994
# Epoch 13/200
# 75/75 [==============================] - 1s 8ms/step - loss: 0.1390 - accuracy: 0.5014 - val_loss: 0.1716 - val_accuracy: 0.4993
# Epoch 14/200
# 75/75 [==============================] - 1s 7ms/step - loss: 0.1330 - accuracy: 0.5006 - val_loss: 0.1626 - val_accuracy: 0.4994
# Epoch 15/200
# 75/75 [==============================] - 1s 8ms/step - loss: 0.1437 - accuracy: 0.5016 - val_loss: 0.1717 - val_accuracy: 0.4993
# Restoring model weights from the end of the best epoch.
# Epoch 00015: early stopping
# Epoch 1/200
# 14/14 [==============================] - 6s 423ms/step - loss: 0.1594 - accuracy: 0.5000 - val_loss: 0.1552 - val_accuracy: 0.5024
# Epoch 2/200
# 14/14 [==============================] - 0s 26ms/step - loss: 0.1525 - accuracy: 0.5003 - val_loss: 0.1520 - val_accuracy: 0.5025
# Epoch 3/200
# 14/14 [==============================] - 0s 24ms/step - loss: 0.1532 - accuracy: 0.4992 - val_loss: 0.1531 - val_accuracy: 0.5022
# Epoch 4/200
# 14/14 [==============================] - 0s 24ms/step - loss: 0.1431 - accuracy: 0.5004 - val_loss: 0.1532 - val_accuracy: 0.5023
# Epoch 5/200
# 14/14 [==============================] - 0s 24ms/step - loss: 0.1510 - accuracy: 0.4982 - val_loss: 0.1526 - val_accuracy: 0.5019
# Epoch 6/200
# 14/14 [==============================] - 0s 24ms/step - loss: 0.1539 - accuracy: 0.4974 - val_loss: 0.1520 - val_accuracy: 0.5024
# Epoch 7/200
# 14/14 [==============================] - 0s 24ms/step - loss: 0.1565 - accuracy: 0.4994 - val_loss: 0.1546 - val_accuracy: 0.5021
# Epoch 8/200
# 14/14 [==============================] - 0s 23ms/step - loss: 0.1514 - accuracy: 0.4982 - val_loss: 0.1526 - val_accuracy: 0.5023
# Epoch 9/200
# 14/14 [==============================] - 0s 22ms/step - loss: 0.1530 - accuracy: 0.4988 - val_loss: 0.1517 - val_accuracy: 0.5023
# Epoch 10/200
# 14/14 [==============================] - 0s 23ms/step - loss: 0.1445 - accuracy: 0.4999 - val_loss: 0.1546 - val_accuracy: 0.5022
# Epoch 11/200
# 14/14 [==============================] - 0s 24ms/step - loss: 0.1528 - accuracy: 0.4972 - val_loss: 0.1551 - val_accuracy: 0.5021
# Epoch 12/200
# 14/14 [==============================] - 0s 23ms/step - loss: 0.1456 - accuracy: 0.4971 - val_loss: 0.1542 - val_accuracy: 0.5020
# Epoch 13/200
# 14/14 [==============================] - 0s 23ms/step - loss: 0.1507 - accuracy: 0.4975 - val_loss: 0.1521 - val_accuracy: 0.5020
# Epoch 14/200
# 14/14 [==============================] - 0s 24ms/step - loss: 0.1528 - accuracy: 0.4975 - val_loss: 0.1524 - val_accuracy: 0.5019
# Epoch 15/200
# 14/14 [==============================] - 0s 24ms/step - loss: 0.1498 - accuracy: 0.4987 - val_loss: 0.1526 - val_accuracy: 0.5023
# Epoch 16/200
# 14/14 [==============================] - 0s 23ms/step - loss: 0.1495 - accuracy: 0.5013 - val_loss: 0.1523 - val_accuracy: 0.5021
# Epoch 17/200
# 14/14 [==============================] - 0s 25ms/step - loss: 0.1532 - accuracy: 0.4985 - val_loss: 0.1539 - val_accuracy: 0.5019
# Epoch 18/200
# 14/14 [==============================] - 0s 24ms/step - loss: 0.1467 - accuracy: 0.4979 - val_loss: 0.1540 - val_accuracy: 0.5018
# Epoch 19/200
# 14/14 [==============================] - 0s 27ms/step - loss: 0.1520 - accuracy: 0.5005 - val_loss: 0.1558 - val_accuracy: 0.5024
# Restoring model weights from the end of the best epoch.
# Epoch 00019: early stopping
#
# ITERATION: 2
#
# STEP 1
#
# Epoch 1/200
# 15/15 [==============================] - 6s 397ms/step - loss: 0.2101 - accuracy: 0.9149 - val_loss: 0.1358 - val_accuracy: 0.9218
# Epoch 2/200
# 15/15 [==============================] - 0s 22ms/step - loss: 0.1545 - accuracy: 0.9200 - val_loss: 0.1438 - val_accuracy: 0.8978
# Epoch 3/200
# 15/15 [==============================] - 0s 24ms/step - loss: 0.1769 - accuracy: 0.8874 - val_loss: 0.1340 - val_accuracy: 0.8539
# Epoch 4/200
# 15/15 [==============================] - 0s 24ms/step - loss: 0.1373 - accuracy: 0.8505 - val_loss: 0.1402 - val_accuracy: 0.8345
# Epoch 5/200
# 15/15 [==============================] - 0s 22ms/step - loss: 0.1681 - accuracy: 0.8269 - val_loss: 0.1326 - val_accuracy: 0.8292
# Epoch 6/200
# 15/15 [==============================] - 0s 23ms/step - loss: 0.1455 - accuracy: 0.8412 - val_loss: 0.1369 - val_accuracy: 0.8667
# Epoch 7/200
# 15/15 [==============================] - 0s 22ms/step - loss: 0.1540 - accuracy: 0.8677 - val_loss: 0.1274 - val_accuracy: 0.8679
# Epoch 8/200
# 15/15 [==============================] - 0s 22ms/step - loss: 0.1524 - accuracy: 0.8720 - val_loss: 0.1282 - val_accuracy: 0.8770
# Epoch 9/200
# 15/15 [==============================] - 0s 22ms/step - loss: 0.1554 - accuracy: 0.8720 - val_loss: 0.1272 - val_accuracy: 0.8751
# Epoch 10/200
# 15/15 [==============================] - 0s 24ms/step - loss: 0.1408 - accuracy: 0.8781 - val_loss: 0.1267 - val_accuracy: 0.8696
# Epoch 11/200
# 15/15 [==============================] - 0s 25ms/step - loss: 0.1294 - accuracy: 0.8718 - val_loss: 0.1365 - val_accuracy: 0.8809
# Epoch 12/200
# 15/15 [==============================] - 0s 23ms/step - loss: 0.1487 - accuracy: 0.8718 - val_loss: 0.1262 - val_accuracy: 0.8631
# Epoch 13/200
# 15/15 [==============================] - 0s 23ms/step - loss: 0.1334 - accuracy: 0.8700 - val_loss: 0.1294 - val_accuracy: 0.8843
# Epoch 14/200
# 15/15 [==============================] - 0s 23ms/step - loss: 0.1354 - accuracy: 0.8843 - val_loss: 0.1319 - val_accuracy: 0.8745
# Epoch 15/200
# 15/15 [==============================] - 0s 24ms/step - loss: 0.1354 - accuracy: 0.8696 - val_loss: 0.1285 - val_accuracy: 0.8754
# Epoch 16/200
# 15/15 [==============================] - 0s 23ms/step - loss: 0.1528 - accuracy: 0.8706 - val_loss: 0.1294 - val_accuracy: 0.8667
# Epoch 17/200
# 15/15 [==============================] - 0s 25ms/step - loss: 0.1460 - accuracy: 0.8750 - val_loss: 0.1268 - val_accuracy: 0.8783
# Epoch 18/200
# 15/15 [==============================] - 0s 24ms/step - loss: 0.1504 - accuracy: 0.8727 - val_loss: 0.1270 - val_accuracy: 0.8730
# Epoch 19/200
# 15/15 [==============================] - 0s 24ms/step - loss: 0.1460 - accuracy: 0.8797 - val_loss: 0.1271 - val_accuracy: 0.8747
# Epoch 20/200
# 15/15 [==============================] - 0s 23ms/step - loss: 0.1466 - accuracy: 0.8693 - val_loss: 0.1262 - val_accuracy: 0.8669
# Epoch 21/200
# 15/15 [==============================] - 0s 24ms/step - loss: 0.1432 - accuracy: 0.8723 - val_loss: 0.1283 - val_accuracy: 0.8783
# Epoch 22/200
# 15/15 [==============================] - 0s 23ms/step - loss: 0.1391 - accuracy: 0.8766 - val_loss: 0.1292 - val_accuracy: 0.8720
# Restoring model weights from the end of the best epoch.
# Epoch 00022: early stopping
# Epoch 1/200
# 14/14 [==============================] - 6s 410ms/step - loss: 0.7522 - accuracy: 0.5008 - val_loss: 0.1367 - val_accuracy: 0.4979
# Epoch 2/200
# 14/14 [==============================] - 0s 22ms/step - loss: 0.1494 - accuracy: 0.4984 - val_loss: 0.1275 - val_accuracy: 0.4998
# Epoch 3/200
# 14/14 [==============================] - 0s 24ms/step - loss: 0.1342 - accuracy: 0.5004 - val_loss: 0.1083 - val_accuracy: 0.4997
# Epoch 4/200
# 14/14 [==============================] - 0s 24ms/step - loss: 0.1194 - accuracy: 0.5009 - val_loss: 0.1131 - val_accuracy: 0.4997
# Epoch 5/200
# 14/14 [==============================] - 0s 24ms/step - loss: 0.1345 - accuracy: 0.5002 - val_loss: 0.1144 - val_accuracy: 0.4997
# Epoch 6/200
# 14/14 [==============================] - 0s 23ms/step - loss: 0.1278 - accuracy: 0.5017 - val_loss: 0.1056 - val_accuracy: 0.4997
# Epoch 7/200
# 14/14 [==============================] - 0s 24ms/step - loss: 0.1261 - accuracy: 0.4999 - val_loss: 0.1110 - val_accuracy: 0.4997
# Epoch 8/200
# 14/14 [==============================] - 0s 24ms/step - loss: 0.1223 - accuracy: 0.5001 - val_loss: 0.1092 - val_accuracy: 0.4998
# Epoch 9/200
# 14/14 [==============================] - 0s 24ms/step - loss: 0.1778 - accuracy: 0.4983 - val_loss: 0.1035 - val_accuracy: 0.4998
# Epoch 10/200
# 14/14 [==============================] - 0s 25ms/step - loss: 0.1594 - accuracy: 0.4990 - val_loss: 0.1144 - val_accuracy: 0.4997
# Epoch 11/200
# 14/14 [==============================] - 0s 23ms/step - loss: 0.1259 - accuracy: 0.4988 - val_loss: 0.1102 - val_accuracy: 0.4997
# Epoch 12/200
# 14/14 [==============================] - 0s 23ms/step - loss: 0.1606 - accuracy: 0.4984 - val_loss: 0.1137 - val_accuracy: 0.4999
# Epoch 13/200
# 14/14 [==============================] - 0s 24ms/step - loss: 0.1710 - accuracy: 0.5016 - val_loss: 0.0969 - val_accuracy: 0.4978
# Epoch 14/200
# 14/14 [==============================] - 0s 25ms/step - loss: 0.1374 - accuracy: 0.4988 - val_loss: 0.1104 - val_accuracy: 0.4996
# Epoch 15/200
# 14/14 [==============================] - 0s 23ms/step - loss: 0.1772 - accuracy: 0.4984 - val_loss: 0.1105 - val_accuracy: 0.4997
# Epoch 16/200
# 14/14 [==============================] - 0s 25ms/step - loss: 0.1135 - accuracy: 0.5002 - val_loss: 0.0960 - val_accuracy: 0.4978
# Epoch 17/200
# 14/14 [==============================] - 0s 24ms/step - loss: 0.1141 - accuracy: 0.5011 - val_loss: 0.1506 - val_accuracy: 0.4998
# Epoch 18/200
# 14/14 [==============================] - 0s 24ms/step - loss: 0.1493 - accuracy: 0.4995 - val_loss: 0.1037 - val_accuracy: 0.4998
# Epoch 19/200
# 14/14 [==============================] - 0s 24ms/step - loss: 0.1843 - accuracy: 0.4982 - val_loss: 0.1003 - val_accuracy: 0.4979
# Epoch 20/200
# 14/14 [==============================] - 0s 24ms/step - loss: 0.1386 - accuracy: 0.5009 - val_loss: 0.1085 - val_accuracy: 0.4997
# Epoch 21/200
# 14/14 [==============================] - 0s 24ms/step - loss: 0.1183 - accuracy: 0.5006 - val_loss: 0.1056 - val_accuracy: 0.4998
# Epoch 22/200
# 14/14 [==============================] - 0s 25ms/step - loss: 0.1837 - accuracy: 0.4990 - val_loss: 0.1125 - val_accuracy: 0.4997
# Epoch 23/200
# 14/14 [==============================] - 0s 24ms/step - loss: 0.1481 - accuracy: 0.4997 - val_loss: 0.0989 - val_accuracy: 0.4978
# Epoch 24/200
# 14/14 [==============================] - 0s 24ms/step - loss: 0.1467 - accuracy: 0.4991 - val_loss: 0.1050 - val_accuracy: 0.4997
# Epoch 25/200
# 14/14 [==============================] - 0s 25ms/step - loss: 0.1096 - accuracy: 0.5000 - val_loss: 0.0996 - val_accuracy: 0.4979
# Epoch 26/200
# 14/14 [==============================] - 0s 25ms/step - loss: 0.1253 - accuracy: 0.4996 - val_loss: 0.1175 - val_accuracy: 0.4996
# Restoring model weights from the end of the best epoch.
# Epoch 00026: early stopping
#
# STEP 2
#
# Epoch 1/200
# 75/75 [==============================] - 7s 83ms/step - loss: 0.1043 - accuracy: 0.4983 - val_loss: 0.3012 - val_accuracy: 0.5014
# Epoch 2/200
# 75/75 [==============================] - 1s 9ms/step - loss: 0.1024 - accuracy: 0.4986 - val_loss: 0.2115 - val_accuracy: 0.5011
# Epoch 3/200
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0983 - accuracy: 0.4997 - val_loss: 0.3912 - val_accuracy: 0.5012
# Epoch 4/200
# 75/75 [==============================] - 1s 8ms/step - loss: 0.1327 - accuracy: 0.4989 - val_loss: 0.2801 - val_accuracy: 0.5012
# Epoch 5/200
# 75/75 [==============================] - 1s 7ms/step - loss: 0.1137 - accuracy: 0.4977 - val_loss: 0.2113 - val_accuracy: 0.5013
# Epoch 6/200
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0994 - accuracy: 0.5005 - val_loss: 0.2387 - val_accuracy: 0.5012
# Epoch 7/200
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0965 - accuracy: 0.4993 - val_loss: 0.2275 - val_accuracy: 0.5012
# Epoch 8/200
# 75/75 [==============================] - 1s 8ms/step - loss: 0.1026 - accuracy: 0.5000 - val_loss: 0.2345 - val_accuracy: 0.5011
# Epoch 9/200
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0961 - accuracy: 0.5011 - val_loss: 0.2364 - val_accuracy: 0.5013
# Epoch 10/200
# 75/75 [==============================] - 1s 7ms/step - loss: 0.1057 - accuracy: 0.4997 - val_loss: 0.2500 - val_accuracy: 0.5013
# Epoch 11/200
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0996 - accuracy: 0.4985 - val_loss: 0.2200 - val_accuracy: 0.5011
# Epoch 12/200
# 75/75 [==============================] - 1s 7ms/step - loss: 0.1075 - accuracy: 0.4991 - val_loss: 0.2774 - val_accuracy: 0.5015
# Epoch 13/200
# 75/75 [==============================] - 1s 8ms/step - loss: 0.1053 - accuracy: 0.4997 - val_loss: 0.2281 - val_accuracy: 0.5011
# Epoch 14/200
# 75/75 [==============================] - 1s 8ms/step - loss: 0.1053 - accuracy: 0.4990 - val_loss: 0.3120 - val_accuracy: 0.5013
# Epoch 15/200
# 75/75 [==============================] - 1s 8ms/step - loss: 0.1135 - accuracy: 0.4992 - val_loss: 0.2735 - val_accuracy: 0.5014
# Restoring model weights from the end of the best epoch.
# Epoch 00015: early stopping
# Epoch 1/200
# 14/14 [==============================] - 6s 402ms/step - loss: 0.1685 - accuracy: 0.4995 - val_loss: 0.1598 - val_accuracy: 0.5005
# Epoch 2/200
# 14/14 [==============================] - 0s 23ms/step - loss: 0.1678 - accuracy: 0.5018 - val_loss: 0.1497 - val_accuracy: 0.5000
# Epoch 3/200
# 14/14 [==============================] - 0s 23ms/step - loss: 0.1663 - accuracy: 0.4992 - val_loss: 0.1591 - val_accuracy: 0.5000
# Epoch 4/200
# 14/14 [==============================] - 0s 24ms/step - loss: 0.1604 - accuracy: 0.5016 - val_loss: 0.1528 - val_accuracy: 0.5001
# Epoch 5/200
# 14/14 [==============================] - 0s 24ms/step - loss: 0.1583 - accuracy: 0.4998 - val_loss: 0.1581 - val_accuracy: 0.5000
# Epoch 6/200
# 14/14 [==============================] - 0s 26ms/step - loss: 0.1646 - accuracy: 0.4988 - val_loss: 0.1496 - val_accuracy: 0.5002
# Epoch 7/200
# 14/14 [==============================] - 0s 23ms/step - loss: 0.1546 - accuracy: 0.4995 - val_loss: 0.1548 - val_accuracy: 0.5001
# Epoch 8/200
# 14/14 [==============================] - 0s 27ms/step - loss: 0.1551 - accuracy: 0.5012 - val_loss: 0.1637 - val_accuracy: 0.4997
# Epoch 9/200
# 14/14 [==============================] - 0s 24ms/step - loss: 0.1597 - accuracy: 0.5011 - val_loss: 0.1562 - val_accuracy: 0.5002
# Epoch 10/200
# 14/14 [==============================] - 0s 23ms/step - loss: 0.1616 - accuracy: 0.4997 - val_loss: 0.1542 - val_accuracy: 0.5003
# Epoch 11/200
# 14/14 [==============================] - 0s 27ms/step - loss: 0.1631 - accuracy: 0.4992 - val_loss: 0.1592 - val_accuracy: 0.4996
# Epoch 12/200
# 14/14 [==============================] - 0s 24ms/step - loss: 0.1635 - accuracy: 0.5011 - val_loss: 0.1524 - val_accuracy: 0.5001
# Epoch 13/200
# 14/14 [==============================] - 0s 24ms/step - loss: 0.1592 - accuracy: 0.5006 - val_loss: 0.1577 - val_accuracy: 0.5001
# Epoch 14/200
# 14/14 [==============================] - 0s 23ms/step - loss: 0.1599 - accuracy: 0.4996 - val_loss: 0.1540 - val_accuracy: 0.5002
# Epoch 15/200
# 14/14 [==============================] - 0s 24ms/step - loss: 0.1591 - accuracy: 0.5008 - val_loss: 0.1511 - val_accuracy: 0.5002
# Epoch 16/200
# 14/14 [==============================] - 0s 24ms/step - loss: 0.1739 - accuracy: 0.5001 - val_loss: 0.1509 - val_accuracy: 0.5000
# Restoring model weights from the end of the best epoch.
# Epoch 00016: early stopping
#
# ITERATION: 3
#
# STEP 1
#
# Epoch 1/200
# 15/15 [==============================] - 6s 394ms/step - loss: 0.4524 - accuracy: 0.9109 - val_loss: 0.2499 - val_accuracy: 0.8879
# Epoch 2/200
# 15/15 [==============================] - 0s 22ms/step - loss: 0.2472 - accuracy: 0.8951 - val_loss: 0.2523 - val_accuracy: 0.8942
# Epoch 3/200
# 15/15 [==============================] - 0s 23ms/step - loss: 0.2284 - accuracy: 0.8759 - val_loss: 0.2437 - val_accuracy: 0.8302
# Epoch 4/200
# 15/15 [==============================] - 0s 24ms/step - loss: 0.2096 - accuracy: 0.8169 - val_loss: 0.2390 - val_accuracy: 0.7957
# Epoch 5/200
# 15/15 [==============================] - 0s 23ms/step - loss: 0.1870 - accuracy: 0.7986 - val_loss: 0.2337 - val_accuracy: 0.8008
# Epoch 6/200
# 15/15 [==============================] - 0s 23ms/step - loss: 0.2029 - accuracy: 0.8063 - val_loss: 0.2459 - val_accuracy: 0.8335
# Epoch 7/200
# 15/15 [==============================] - 0s 24ms/step - loss: 0.2301 - accuracy: 0.8265 - val_loss: 0.2558 - val_accuracy: 0.8253
# Epoch 8/200
# 15/15 [==============================] - 0s 24ms/step - loss: 0.2178 - accuracy: 0.8290 - val_loss: 0.2368 - val_accuracy: 0.8456
# Epoch 9/200
# 15/15 [==============================] - 0s 24ms/step - loss: 0.2125 - accuracy: 0.8346 - val_loss: 0.2484 - val_accuracy: 0.8079
# Epoch 10/200
# 15/15 [==============================] - 0s 25ms/step - loss: 0.1995 - accuracy: 0.8276 - val_loss: 0.2336 - val_accuracy: 0.8513
# Epoch 11/200
# 15/15 [==============================] - 0s 24ms/step - loss: 0.2149 - accuracy: 0.8449 - val_loss: 0.2444 - val_accuracy: 0.8313
# Epoch 12/200
# 15/15 [==============================] - 0s 25ms/step - loss: 0.2228 - accuracy: 0.8289 - val_loss: 0.2389 - val_accuracy: 0.8191
# Epoch 13/200
# 15/15 [==============================] - 0s 27ms/step - loss: 0.1970 - accuracy: 0.8250 - val_loss: 0.2361 - val_accuracy: 0.8366
# Epoch 14/200
# 15/15 [==============================] - 0s 23ms/step - loss: 0.1896 - accuracy: 0.8382 - val_loss: 0.2294 - val_accuracy: 0.8352
# Epoch 15/200
# 15/15 [==============================] - 0s 25ms/step - loss: 0.2214 - accuracy: 0.8279 - val_loss: 0.2435 - val_accuracy: 0.8238
# Epoch 16/200
# 15/15 [==============================] - 0s 24ms/step - loss: 0.2183 - accuracy: 0.8290 - val_loss: 0.2399 - val_accuracy: 0.8371
# Epoch 17/200
# 15/15 [==============================] - 0s 24ms/step - loss: 0.2066 - accuracy: 0.8379 - val_loss: 0.2377 - val_accuracy: 0.8167
# Epoch 18/200
# 15/15 [==============================] - 0s 26ms/step - loss: 0.2017 - accuracy: 0.8132 - val_loss: 0.2320 - val_accuracy: 0.8059
# Epoch 19/200
# 15/15 [==============================] - 0s 23ms/step - loss: 0.2003 - accuracy: 0.8125 - val_loss: 0.2362 - val_accuracy: 0.8375
# Epoch 20/200
# 15/15 [==============================] - 0s 24ms/step - loss: 0.1928 - accuracy: 0.8444 - val_loss: 0.2286 - val_accuracy: 0.8185
# Epoch 21/200
# 15/15 [==============================] - 0s 23ms/step - loss: 0.1917 - accuracy: 0.8087 - val_loss: 0.2336 - val_accuracy: 0.8159
# Epoch 22/200
# 15/15 [==============================] - 0s 22ms/step - loss: 0.1995 - accuracy: 0.8262 - val_loss: 0.2337 - val_accuracy: 0.8303
# Epoch 23/200
# 15/15 [==============================] - 0s 22ms/step - loss: 0.1863 - accuracy: 0.8276 - val_loss: 0.2326 - val_accuracy: 0.8193
# Epoch 24/200
# 15/15 [==============================] - 0s 23ms/step - loss: 0.2035 - accuracy: 0.8157 - val_loss: 0.2335 - val_accuracy: 0.8127
# Epoch 25/200
# 15/15 [==============================] - 0s 23ms/step - loss: 0.1932 - accuracy: 0.8159 - val_loss: 0.2381 - val_accuracy: 0.8461
# Epoch 26/200
# 15/15 [==============================] - 0s 24ms/step - loss: 0.1880 - accuracy: 0.8466 - val_loss: 0.2344 - val_accuracy: 0.8078
# Epoch 27/200
# 15/15 [==============================] - 0s 22ms/step - loss: 0.1908 - accuracy: 0.8001 - val_loss: 0.2298 - val_accuracy: 0.8224
# Epoch 28/200
# 15/15 [==============================] - 0s 23ms/step - loss: 0.1895 - accuracy: 0.8305 - val_loss: 0.2315 - val_accuracy: 0.8230
# Epoch 29/200
# 15/15 [==============================] - 0s 24ms/step - loss: 0.1784 - accuracy: 0.8229 - val_loss: 0.2268 - val_accuracy: 0.8177
# Epoch 30/200
# 15/15 [==============================] - 0s 24ms/step - loss: 0.1960 - accuracy: 0.8144 - val_loss: 0.2431 - val_accuracy: 0.8278
# Epoch 31/200
# 15/15 [==============================] - 0s 24ms/step - loss: 0.1918 - accuracy: 0.8326 - val_loss: 0.2323 - val_accuracy: 0.8038
# Epoch 32/200
# 15/15 [==============================] - 0s 24ms/step - loss: 0.1838 - accuracy: 0.8145 - val_loss: 0.2289 - val_accuracy: 0.8335
# Epoch 33/200
# 15/15 [==============================] - 0s 23ms/step - loss: 0.2132 - accuracy: 0.8067 - val_loss: 0.2566 - val_accuracy: 0.7916
# Epoch 34/200
# 15/15 [==============================] - 0s 23ms/step - loss: 0.1914 - accuracy: 0.8109 - val_loss: 0.2331 - val_accuracy: 0.8385
# Epoch 35/200
# 15/15 [==============================] - 0s 25ms/step - loss: 0.2251 - accuracy: 0.8258 - val_loss: 0.2729 - val_accuracy: 0.8134
# Epoch 36/200
# 15/15 [==============================] - 0s 23ms/step - loss: 0.1986 - accuracy: 0.8325 - val_loss: 0.2306 - val_accuracy: 0.8217
# Epoch 37/200
# 15/15 [==============================] - 0s 23ms/step - loss: 0.1973 - accuracy: 0.8069 - val_loss: 0.2408 - val_accuracy: 0.8115
# Epoch 38/200
# 15/15 [==============================] - 0s 25ms/step - loss: 0.1783 - accuracy: 0.8267 - val_loss: 0.2295 - val_accuracy: 0.8151
# Epoch 39/200
# 15/15 [==============================] - 0s 24ms/step - loss: 0.1940 - accuracy: 0.8056 - val_loss: 0.2342 - val_accuracy: 0.8386
# Restoring model weights from the end of the best epoch.
# Epoch 00039: early stopping
# Epoch 1/200
# 14/14 [==============================] - 6s 415ms/step - loss: 0.3435 - accuracy: 0.4980 - val_loss: 0.6952 - val_accuracy: 0.5003
# Epoch 2/200
# 14/14 [==============================] - 0s 24ms/step - loss: 0.1062 - accuracy: 0.4995 - val_loss: 0.1726 - val_accuracy: 0.5005
# Epoch 3/200
# 14/14 [==============================] - 0s 25ms/step - loss: 0.0626 - accuracy: 0.4993 - val_loss: 0.2739 - val_accuracy: 0.5002
# Epoch 4/200
# 14/14 [==============================] - 0s 25ms/step - loss: 0.0602 - accuracy: 0.4996 - val_loss: 0.2252 - val_accuracy: 0.5003
# Epoch 5/200
# 14/14 [==============================] - 0s 26ms/step - loss: 0.0655 - accuracy: 0.5002 - val_loss: 0.2377 - val_accuracy: 0.5003
# Epoch 6/200
# 14/14 [==============================] - 0s 24ms/step - loss: 0.0642 - accuracy: 0.5003 - val_loss: 0.2151 - val_accuracy: 0.5003
# Epoch 7/200
# 14/14 [==============================] - 0s 25ms/step - loss: 0.0577 - accuracy: 0.4979 - val_loss: 0.2611 - val_accuracy: 0.5004
# Epoch 8/200
# 14/14 [==============================] - 0s 25ms/step - loss: 0.0598 - accuracy: 0.5003 - val_loss: 0.1911 - val_accuracy: 0.5003
# Epoch 9/200
# 14/14 [==============================] - 0s 24ms/step - loss: 0.0629 - accuracy: 0.5004 - val_loss: 0.2315 - val_accuracy: 0.5003
# Epoch 10/200
# 14/14 [==============================] - 0s 25ms/step - loss: 0.0643 - accuracy: 0.4993 - val_loss: 0.2263 - val_accuracy: 0.5003
# Epoch 11/200
# 14/14 [==============================] - 0s 24ms/step - loss: 0.0686 - accuracy: 0.4994 - val_loss: 0.2459 - val_accuracy: 0.5003
# Epoch 12/200
# 14/14 [==============================] - 0s 24ms/step - loss: 0.0619 - accuracy: 0.5005 - val_loss: 0.2053 - val_accuracy: 0.5003
# Restoring model weights from the end of the best epoch.
# Epoch 00012: early stopping
#
# STEP 2
#
# Epoch 1/200
# 75/75 [==============================] - 7s 82ms/step - loss: 0.1129 - accuracy: 0.5010 - val_loss: 0.0595 - val_accuracy: 0.4987
# Epoch 2/200
# 75/75 [==============================] - 1s 8ms/step - loss: 0.1198 - accuracy: 0.5001 - val_loss: 0.0750 - val_accuracy: 0.4986
# Epoch 3/200
# 75/75 [==============================] - 1s 8ms/step - loss: 0.2766 - accuracy: 0.4992 - val_loss: 0.0611 - val_accuracy: 0.4984
# Epoch 4/200
# 75/75 [==============================] - 1s 8ms/step - loss: 0.2742 - accuracy: 0.4986 - val_loss: 0.0600 - val_accuracy: 0.4984
# Epoch 5/200
# 75/75 [==============================] - 1s 9ms/step - loss: 0.0966 - accuracy: 0.4993 - val_loss: 0.2657 - val_accuracy: 0.4986
# Epoch 6/200
# 75/75 [==============================] - 1s 8ms/step - loss: 0.1656 - accuracy: 0.5006 - val_loss: 0.0591 - val_accuracy: 0.4986
# Epoch 7/200
# 75/75 [==============================] - 1s 8ms/step - loss: 0.1293 - accuracy: 0.4995 - val_loss: 0.2000 - val_accuracy: 0.4985
# Epoch 8/200
# 75/75 [==============================] - 1s 8ms/step - loss: 0.1695 - accuracy: 0.5003 - val_loss: 0.0982 - val_accuracy: 0.4985
# Epoch 9/200
# 75/75 [==============================] - 1s 9ms/step - loss: 0.1643 - accuracy: 0.5035 - val_loss: 0.0598 - val_accuracy: 0.4987
# Epoch 10/200
# 75/75 [==============================] - 1s 8ms/step - loss: 0.1534 - accuracy: 0.5003 - val_loss: 0.0691 - val_accuracy: 0.4986
# Epoch 11/200
# 75/75 [==============================] - 1s 8ms/step - loss: 0.1650 - accuracy: 0.5021 - val_loss: 0.0602 - val_accuracy: 0.4987
# Epoch 12/200
# 75/75 [==============================] - 1s 8ms/step - loss: 0.1444 - accuracy: 0.5001 - val_loss: 0.0645 - val_accuracy: 0.4984
# Epoch 13/200
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0934 - accuracy: 0.5016 - val_loss: 0.1813 - val_accuracy: 0.4985
# Epoch 14/200
# 75/75 [==============================] - 1s 9ms/step - loss: 0.2304 - accuracy: 0.5002 - val_loss: 0.0721 - val_accuracy: 0.4986
# Epoch 15/200
# 75/75 [==============================] - 1s 8ms/step - loss: 0.1356 - accuracy: 0.5021 - val_loss: 0.0593 - val_accuracy: 0.4984
# Epoch 16/200
# 75/75 [==============================] - 1s 8ms/step - loss: 0.1044 - accuracy: 0.5005 - val_loss: 0.1563 - val_accuracy: 0.4984
# Restoring model weights from the end of the best epoch.
# Epoch 00016: early stopping
# Epoch 1/200
# 14/14 [==============================] - 6s 406ms/step - loss: 0.0833 - accuracy: 0.4985 - val_loss: 0.1193 - val_accuracy: 0.5030
# Epoch 2/200
# 14/14 [==============================] - 0s 23ms/step - loss: 0.0891 - accuracy: 0.5000 - val_loss: 0.1201 - val_accuracy: 0.5030
# Epoch 3/200
# 14/14 [==============================] - 0s 24ms/step - loss: 0.0790 - accuracy: 0.4983 - val_loss: 0.1133 - val_accuracy: 0.5026
# Epoch 4/200
# 14/14 [==============================] - 0s 24ms/step - loss: 0.0785 - accuracy: 0.4991 - val_loss: 0.1263 - val_accuracy: 0.5026
# Epoch 5/200
# 14/14 [==============================] - 0s 24ms/step - loss: 0.0735 - accuracy: 0.4988 - val_loss: 0.1078 - val_accuracy: 0.5026
# Epoch 6/200
# 14/14 [==============================] - 0s 23ms/step - loss: 0.0815 - accuracy: 0.4973 - val_loss: 0.1381 - val_accuracy: 0.5026
# Epoch 7/200
# 14/14 [==============================] - 0s 25ms/step - loss: 0.0869 - accuracy: 0.4994 - val_loss: 0.1303 - val_accuracy: 0.5026
# Epoch 8/200
# 14/14 [==============================] - 0s 24ms/step - loss: 0.0822 - accuracy: 0.4988 - val_loss: 0.1132 - val_accuracy: 0.5026
# Epoch 9/200
# 14/14 [==============================] - 0s 24ms/step - loss: 0.0766 - accuracy: 0.4985 - val_loss: 0.1178 - val_accuracy: 0.5031
# Epoch 10/200
# 14/14 [==============================] - 0s 25ms/step - loss: 0.0754 - accuracy: 0.5014 - val_loss: 0.1114 - val_accuracy: 0.5030
# Epoch 11/200
# 14/14 [==============================] - 0s 24ms/step - loss: 0.0821 - accuracy: 0.4992 - val_loss: 0.1140 - val_accuracy: 0.5027
# Epoch 12/200
# 14/14 [==============================] - 0s 24ms/step - loss: 0.0810 - accuracy: 0.4991 - val_loss: 0.1163 - val_accuracy: 0.5027
# Epoch 13/200
# 14/14 [==============================] - 0s 24ms/step - loss: 0.0750 - accuracy: 0.5007 - val_loss: 0.1139 - val_accuracy: 0.5027
# Epoch 14/200
# 14/14 [==============================] - 0s 25ms/step - loss: 0.0756 - accuracy: 0.5002 - val_loss: 0.1099 - val_accuracy: 0.5026
# Epoch 15/200
# 14/14 [==============================] - 0s 26ms/step - loss: 0.0772 - accuracy: 0.5000 - val_loss: 0.1193 - val_accuracy: 0.5026
# Restoring model weights from the end of the best epoch.
# Epoch 00015: early stopping
#
# ITERATION: 4
#
# STEP 1
#
# Epoch 1/200
# 15/15 [==============================] - 7s 431ms/step - loss: 0.1703 - accuracy: 0.9193 - val_loss: 0.1984 - val_accuracy: 0.9045
# Epoch 2/200
# 15/15 [==============================] - 0s 27ms/step - loss: 0.1309 - accuracy: 0.9037 - val_loss: 0.2049 - val_accuracy: 0.8158
# Epoch 3/200
# 15/15 [==============================] - 0s 26ms/step - loss: 0.1327 - accuracy: 0.7911 - val_loss: 0.2027 - val_accuracy: 0.7421
# Epoch 4/200
# 15/15 [==============================] - 0s 27ms/step - loss: 0.1096 - accuracy: 0.7471 - val_loss: 0.1793 - val_accuracy: 0.8147
# Epoch 5/200
# 15/15 [==============================] - 0s 25ms/step - loss: 0.1224 - accuracy: 0.8050 - val_loss: 0.1905 - val_accuracy: 0.7997
# Epoch 6/200
# 15/15 [==============================] - 0s 26ms/step - loss: 0.1274 - accuracy: 0.7945 - val_loss: 0.2096 - val_accuracy: 0.6680
# Epoch 7/200
# 15/15 [==============================] - 0s 27ms/step - loss: 0.1283 - accuracy: 0.7093 - val_loss: 0.1887 - val_accuracy: 0.7657
# Epoch 8/200
# 15/15 [==============================] - 0s 26ms/step - loss: 0.1236 - accuracy: 0.7208 - val_loss: 0.1819 - val_accuracy: 0.7339
# Epoch 9/200
# 15/15 [==============================] - 0s 28ms/step - loss: 0.1247 - accuracy: 0.7251 - val_loss: 0.2035 - val_accuracy: 0.6867
# Epoch 10/200
# 15/15 [==============================] - 0s 26ms/step - loss: 0.1036 - accuracy: 0.7189 - val_loss: 0.1769 - val_accuracy: 0.7540
# Epoch 11/200
# 15/15 [==============================] - 0s 26ms/step - loss: 0.1282 - accuracy: 0.7079 - val_loss: 0.2097 - val_accuracy: 0.6608
# Epoch 12/200
# 15/15 [==============================] - 0s 25ms/step - loss: 0.1135 - accuracy: 0.7437 - val_loss: 0.1836 - val_accuracy: 0.8469
# Epoch 13/200
# 15/15 [==============================] - 0s 25ms/step - loss: 0.1106 - accuracy: 0.7708 - val_loss: 0.1778 - val_accuracy: 0.7567
# Epoch 14/200
# 15/15 [==============================] - 0s 27ms/step - loss: 0.1301 - accuracy: 0.7310 - val_loss: 0.2262 - val_accuracy: 0.6385
# Epoch 15/200
# 15/15 [==============================] - 0s 26ms/step - loss: 0.1277 - accuracy: 0.6789 - val_loss: 0.1892 - val_accuracy: 0.7144
# Epoch 16/200
# 15/15 [==============================] - 0s 26ms/step - loss: 0.1242 - accuracy: 0.6935 - val_loss: 0.1883 - val_accuracy: 0.7261
# Epoch 17/200
# 15/15 [==============================] - 0s 26ms/step - loss: 0.1198 - accuracy: 0.7287 - val_loss: 0.2076 - val_accuracy: 0.6584
# Epoch 18/200
# 15/15 [==============================] - 0s 24ms/step - loss: 0.1181 - accuracy: 0.6902 - val_loss: 0.1824 - val_accuracy: 0.7589
# Epoch 19/200
# 15/15 [==============================] - 0s 25ms/step - loss: 0.1199 - accuracy: 0.7081 - val_loss: 0.1915 - val_accuracy: 0.7247
# Epoch 20/200
# 15/15 [==============================] - 0s 29ms/step - loss: 0.1174 - accuracy: 0.7563 - val_loss: 0.1927 - val_accuracy: 0.7146
# Restoring model weights from the end of the best epoch.
# Epoch 00020: early stopping
# Epoch 1/200
# 14/14 [==============================] - 6s 415ms/step - loss: 0.2622 - accuracy: 0.5004 - val_loss: 0.4647 - val_accuracy: 0.4986
# Epoch 2/200
# 14/14 [==============================] - 0s 24ms/step - loss: 0.0854 - accuracy: 0.5002 - val_loss: 0.7274 - val_accuracy: 0.4984
# Epoch 3/200
# 14/14 [==============================] - 0s 25ms/step - loss: 0.0669 - accuracy: 0.4986 - val_loss: 0.3393 - val_accuracy: 0.4984
# Epoch 4/200
# 14/14 [==============================] - 0s 27ms/step - loss: 0.0597 - accuracy: 0.5012 - val_loss: 0.3892 - val_accuracy: 0.4983
# Epoch 5/200
# 14/14 [==============================] - 0s 25ms/step - loss: 0.0595 - accuracy: 0.5004 - val_loss: 0.4440 - val_accuracy: 0.4983
# Epoch 6/200
# 14/14 [==============================] - 0s 25ms/step - loss: 0.0564 - accuracy: 0.4983 - val_loss: 0.3863 - val_accuracy: 0.4984
# Epoch 7/200
# 14/14 [==============================] - 0s 25ms/step - loss: 0.0585 - accuracy: 0.5014 - val_loss: 0.3544 - val_accuracy: 0.4983
# Epoch 8/200
# 14/14 [==============================] - 0s 26ms/step - loss: 0.0572 - accuracy: 0.4986 - val_loss: 0.3557 - val_accuracy: 0.4984
# Epoch 9/200
# 14/14 [==============================] - 0s 27ms/step - loss: 0.0579 - accuracy: 0.4990 - val_loss: 0.3964 - val_accuracy: 0.4983
# Epoch 10/200
# 14/14 [==============================] - 0s 27ms/step - loss: 0.0620 - accuracy: 0.5019 - val_loss: 0.4661 - val_accuracy: 0.4984
# Epoch 11/200
# 14/14 [==============================] - 0s 27ms/step - loss: 0.0686 - accuracy: 0.5022 - val_loss: 0.5798 - val_accuracy: 0.4983
# Epoch 12/200
# 14/14 [==============================] - 0s 27ms/step - loss: 0.0675 - accuracy: 0.4994 - val_loss: 0.4074 - val_accuracy: 0.4984
# Epoch 13/200
# 14/14 [==============================] - 0s 26ms/step - loss: 0.0596 - accuracy: 0.4982 - val_loss: 0.4630 - val_accuracy: 0.4983
# Restoring model weights from the end of the best epoch.
# Epoch 00013: early stopping
#
# STEP 2
#
# Epoch 1/200
# 75/75 [==============================] - 7s 82ms/step - loss: 0.1308 - accuracy: 0.5003 - val_loss: 0.0625 - val_accuracy: 0.4999
# Epoch 2/200
# 75/75 [==============================] - 1s 8ms/step - loss: 0.1719 - accuracy: 0.5000 - val_loss: 0.0714 - val_accuracy: 0.4999
# Epoch 3/200
# 75/75 [==============================] - 1s 9ms/step - loss: 0.1320 - accuracy: 0.4997 - val_loss: 0.4675 - val_accuracy: 0.4998
# Epoch 4/200
# 75/75 [==============================] - 1s 8ms/step - loss: 0.3017 - accuracy: 0.4971 - val_loss: 0.0621 - val_accuracy: 0.4999
# Epoch 5/200
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0781 - accuracy: 0.5008 - val_loss: 0.4422 - val_accuracy: 0.4998
# Epoch 6/200
# 75/75 [==============================] - 1s 8ms/step - loss: 0.4968 - accuracy: 0.4975 - val_loss: 0.5046 - val_accuracy: 0.4998
# Epoch 7/200
# 75/75 [==============================] - 1s 9ms/step - loss: 0.3716 - accuracy: 0.4996 - val_loss: 0.3528 - val_accuracy: 0.4998
# Epoch 8/200
# 75/75 [==============================] - 1s 8ms/step - loss: 0.2619 - accuracy: 0.5002 - val_loss: 0.0648 - val_accuracy: 0.4999
# Epoch 9/200
# 75/75 [==============================] - 1s 8ms/step - loss: 0.1129 - accuracy: 0.4999 - val_loss: 0.3650 - val_accuracy: 0.4997
# Epoch 10/200
# 75/75 [==============================] - 1s 9ms/step - loss: 0.2645 - accuracy: 0.4994 - val_loss: 0.0647 - val_accuracy: 0.4998
# Epoch 11/200
# 75/75 [==============================] - 1s 9ms/step - loss: 0.0877 - accuracy: 0.5016 - val_loss: 0.3888 - val_accuracy: 0.4998
# Epoch 12/200
# 75/75 [==============================] - 1s 8ms/step - loss: 0.3174 - accuracy: 0.5006 - val_loss: 0.0649 - val_accuracy: 0.4999
# Epoch 13/200
# 75/75 [==============================] - 1s 8ms/step - loss: 0.1466 - accuracy: 0.4975 - val_loss: 0.2958 - val_accuracy: 0.4996
# Epoch 14/200
# 75/75 [==============================] - 1s 8ms/step - loss: 0.2309 - accuracy: 0.5021 - val_loss: 0.2133 - val_accuracy: 0.4997
# Restoring model weights from the end of the best epoch.
# Epoch 00014: early stopping
# Epoch 1/200
# 14/14 [==============================] - 6s 418ms/step - loss: 0.0941 - accuracy: 0.5018 - val_loss: 0.1606 - val_accuracy: 0.4998
# Epoch 2/200
# 14/14 [==============================] - 0s 25ms/step - loss: 0.0867 - accuracy: 0.4993 - val_loss: 0.1594 - val_accuracy: 0.4998
# Epoch 3/200
# 14/14 [==============================] - 0s 28ms/step - loss: 0.0826 - accuracy: 0.5015 - val_loss: 0.1178 - val_accuracy: 0.4997
# Epoch 4/200
# 14/14 [==============================] - 0s 25ms/step - loss: 0.0873 - accuracy: 0.4999 - val_loss: 0.1418 - val_accuracy: 0.4997
# Epoch 5/200
# 14/14 [==============================] - 0s 30ms/step - loss: 0.0802 - accuracy: 0.5018 - val_loss: 0.1166 - val_accuracy: 0.4997
# Epoch 6/200
# 14/14 [==============================] - 0s 25ms/step - loss: 0.0828 - accuracy: 0.4995 - val_loss: 0.1514 - val_accuracy: 0.4998
# Epoch 7/200
# 14/14 [==============================] - 0s 28ms/step - loss: 0.0784 - accuracy: 0.4998 - val_loss: 0.1191 - val_accuracy: 0.4997
# Epoch 8/200
# 14/14 [==============================] - 0s 25ms/step - loss: 0.0831 - accuracy: 0.4989 - val_loss: 0.1363 - val_accuracy: 0.4997
# Epoch 9/200
# 14/14 [==============================] - 0s 26ms/step - loss: 0.0894 - accuracy: 0.5014 - val_loss: 0.1352 - val_accuracy: 0.4998
# Epoch 10/200
# 14/14 [==============================] - 0s 25ms/step - loss: 0.0742 - accuracy: 0.4997 - val_loss: 0.1225 - val_accuracy: 0.4999
# Epoch 11/200
# 14/14 [==============================] - 0s 27ms/step - loss: 0.0861 - accuracy: 0.5030 - val_loss: 0.1399 - val_accuracy: 0.4998
# Epoch 12/200
# 14/14 [==============================] - 0s 27ms/step - loss: 0.0870 - accuracy: 0.5017 - val_loss: 0.1295 - val_accuracy: 0.4997
# Epoch 13/200
# 14/14 [==============================] - 0s 25ms/step - loss: 0.0784 - accuracy: 0.4997 - val_loss: 0.1212 - val_accuracy: 0.4997
# Epoch 14/200
# 14/14 [==============================] - 0s 25ms/step - loss: 0.0829 - accuracy: 0.5009 - val_loss: 0.1475 - val_accuracy: 0.4997
# Epoch 15/200
# 14/14 [==============================] - 0s 26ms/step - loss: 0.0837 - accuracy: 0.4979 - val_loss: 0.1344 - val_accuracy: 0.4998
# Restoring model weights from the end of the best epoch.
# Epoch 00015: early stopping

# %%
bins = np.linspace(-11, 11, 41)

plt.figure(figsize=(12, 5))

fig, ax = plt.subplots(3,
                       2,
                       figsize=(12, 18),
                       #constrained_layout=True,
                       sharey='row')

for ix in range(2):
        #Detector-level
        ax[ix,0].set_title("Initialization, Detector-level",style='italic',loc='right')
        hist0 = ax[ix,0].hist(theta0_S[theta0_S[:,0]!=dummyval][:,ix], # initial MC reco 
                        bins=bins,
                        color="orange",
                        label=r'($\mu$, $\sigma$) = {}'.format(theta0_param),
                        **plot_style_2)

        _,_,_= ax[ix,0].hist(
            theta0_S[theta0_S[:,0]!=dummyval][:,ix], # MC reco after reweight
            bins=bins,
            label='($\mu$, $\sigma$) = {}\nDCTR wgt.'.format(theta0_param),
            **plot_style_1)
        _,_,_= ax[ix,0].hist(theta_unknown_S[theta_unknown_S[:,0]!=dummyval][:,ix], # data reco
                        bins=bins,
                        label=r'($\mu$, $\sigma$) = ?',
                        #weights=weights[i, 0, :][theta_unknown_S[:,0]!=dummyval],
                        **plot_style_2,
                        color="black")
        ax[ix,0].legend(frameon=False)
        ax[ix,0].set_xlabel(r"$x_S$"+str(ix+1))
        ax[ix,0].set_ylabel("Events per bin")

        #Particle-level
        ax[ix,1].set_title("Initialization, Particle-level",style='italic',loc='right')
        _,_,_=ax[ix,1].hist(theta0_G[theta0_G[:,0]!=dummyval][:,ix], # initial MC truth
                        bins=bins,
                        label=r'($\mu$, $\sigma$) = {}'.format(theta0_param),
                        **plot_style_2)

        _,_,_= ax[ix,1].hist(
            theta0_G[theta0_G[:,0]!=dummyval][:,ix],
            bins=bins,
            label='($\mu$, $\sigma$) = {}\nDCTR wgt.'.format(theta0_param), # MC truth after reweight
            **plot_style_1)
        _,_,_= ax[ix,1].hist(theta_unknown_G[theta_unknown_G[:,0]!=dummyval][:,ix], # real data truth
                        bins=bins,
                        label=r'($\mu$, $\sigma$) = ?',
                        **plot_style_2,
                        color="green")
        ax[ix,1].legend(frameon=False)
        ax[ix,1].set_xlabel(r"$x_G$"+str(ix+1))
        ax[ix,1].set_ylabel("Events per bin")

ax[2,0].set_title("Initialization, Particle-level",style='italic',loc='right')
ax[2,0].set_xlabel('$x1$')
ax[2,0].set_ylabel('$x2$')
h5 = ax[2,0].hist2d(theta0_G[theta0_G[:,0]!=dummyval][:,0], theta0_G[theta0_G[:,0]!=dummyval][:,1] , bins=(bins,bins),label='($\mu$, $\sigma$) = {}\nDCTR wgt.'.format(theta0_param)) # MC truth after reweight
fig.colorbar(h5[3],ax=ax[2,0])
legend = ax[2,0].legend(
    title='($\mu$, $\sigma$) = {}\nDCTR wgt.'.format(theta0_param),
    loc='upper left',
    frameon=False)
plt.setp(legend.get_title(), multialignment='center')

ax[2,1].set_title("Initialization, Particle-level",style='italic',loc='right')
ax[2,1].set_xlabel('$x1$')
ax[2,1].set_ylabel('$x2$')
h6 = ax[2,1].hist2d(theta_unknown_G[theta_unknown_G[:,0]!=dummyval][:,0], theta_unknown_G[theta_unknown_G[:,0]!=dummyval][:,1] , bins=(bins,bins),label=r'($\mu$, $\sigma$) = ?') # real data truth
fig.colorbar(h6[3],ax=ax[2,1])
legend = ax[2,1].legend(
    title=r'($\mu$, $\sigma$) = ?',
    loc='upper left',
    frameon=False)
plt.setp(legend.get_title(), multialignment='center')

fig.tight_layout()


#Iterations
for i in range(iterations):
    print("ITERATION {}:".format(i + 1))
    plt.figure(figsize=(12, 4
                        ))
    
    fig, ax = plt.subplots(3,2,
                       figsize=(12, 18),
                       #constrained_layout=True,
                       sharey='row')
    
    for ix in range(2):
            #Detector-level
            ax[ix,0].set_title("Iteration " +str(i+1)+ ", Step 1",style='italic',loc='right')
            hist0 = ax[ix,0].hist(theta0_S[theta0_S[:,0]!=dummyval][:,ix], # initial MC reco 
                            bins=bins,
                            color="orange",
                            label=r'($\mu$, $\sigma$) = {}'.format(theta0_param),
                            **plot_style_2)

            _,_,_= ax[ix,0].hist(
                theta0_S[theta0_S[:,0]!=dummyval][:,ix], # MC reco after reweight 
                bins=bins,
                label='($\mu$, $\sigma$) = {}\nDCTR wgt.'.format(theta0_param),
                weights=weights[i, 0, :][theta0_S[:,0]!=dummyval],
                **plot_style_1)
            _,_,_= ax[ix,0].hist(theta_unknown_S[theta_unknown_S[:,0]!=dummyval][:,ix], # real data reco
                            bins=bins,
                            label=r'($\mu$, $\sigma$) = ?',
                            #weights=weights[i, 0, :][theta_unknown_S[:,0]!=dummyval],
                            **plot_style_2,
                            color="black")
            ax[ix,0].legend(frameon=False)
            ax[ix,0].set_xlabel(r"$x_S$"+str(ix+1))
            ax[ix,0].set_ylabel("Events per bin")

            #Particle-level
            ax[ix,1].set_title("Iteration " +str(i+1)+ ", Step 2",style='italic',loc='right')
            _,_,_=ax[ix,1].hist(theta0_G[theta0_G[:,0]!=dummyval][:,ix], # initial MC truth 
                            bins=bins,
                            label=r'($\mu$, $\sigma$) = {}'.format(theta0_param),
                            **plot_style_2)

            _,_,_= ax[ix,1].hist(
                theta0_G[theta0_G[:,0]!=dummyval][:,ix],
                bins=bins,
                label='($\mu$, $\sigma$) = {}\nDCTR wgt.'.format(theta0_param), # MC truth after reweight
                weights=weights[i, 1, :][theta0_G[:,0]!=dummyval],
                **plot_style_1)
            _,_,_= ax[ix,1].hist(theta_unknown_G[theta_unknown_G[:,0]!=dummyval][:,ix], # real data truth
                            bins=bins,
                            label=r'($\mu$, $\sigma$) = ?',
                            **plot_style_2,
                            color="green")
            ax[ix,1].legend(frameon=False)
            ax[ix,1].set_xlabel(r"$x_G$"+str(ix+1))
            ax[ix,1].set_ylabel("Events per bin")

    ax[2,0].set_title("Iteration " +str(i+1)+ ", Particle-level",style='italic',loc='right')
    ax[2,0].set_xlabel('$x1$')
    ax[2,0].set_ylabel('$x2$')
    h5 = ax[2,0].hist2d(theta0_G[theta0_G[:,0]!=dummyval][:,0], theta0_G[theta0_G[:,0]!=dummyval][:,1], # MC truth after reweight
                        bins=(bins,bins),label='($\mu$, $\sigma$) = {}\nDCTR wgt.'.format(theta0_param),weights=weights[i, 1, :][theta0_G[:,0]!=dummyval])
    fig.colorbar(h5[3],ax=ax[2,0])
    legend = ax[2,0].legend(
        title='($\mu$, $\sigma$) = {}\nDCTR wgt.'.format(theta0_param),
        loc='upper left',
        frameon=False)
    plt.setp(legend.get_title(), multialignment='center')

    ax[2,1].set_title("Iteration " +str(i+1)+ ", Particle-level",style='italic',loc='right')
    ax[2,1].set_xlabel('$x1$')
    ax[2,1].set_ylabel('$x2$')
    h6 = ax[2,1].hist2d(theta_unknown_G[theta_unknown_G[:,0]!=dummyval][:,0], theta_unknown_G[theta_unknown_G[:,0]!=dummyval][:,1] , bins=(bins,bins),label=r'($\mu$, $\sigma$) = ?') # real data truth
    fig.colorbar(h6[3],ax=ax[2,1])
    legend = ax[2,1].legend(
        title=r'($\mu$, $\sigma$) = ?',
        loc='upper left',
        frameon=False)
    plt.setp(legend.get_title(), multialignment='center')
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# ITERATION 1:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# ITERATION 2:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# ITERATION 3:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# ITERATION 4:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
